# %% [markdown]
# ## Analyze Website

# %%
import requests
import os

# %%
def get_one_page(url):
    '''
    Get the html for one page
    '''
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    return None

# %%
url = 'https://www.insightdatascience.com/fellows?61ea5d1b_page=1'
html = get_one_page(url)
print(html)

outF = open('./FellowInfo.txt', 'w')
outF.write(html)
outF.write('\n')
outF.close()
# Out:
# <!DOCTYPE html><!-- Last Published: Thu Jun 20 2019 23:58:24 GMT+0000 (UTC) --><html data-wf-domain="www.insightdatascience.com" data-wf-page="5bd3f311a37dacd7c38d6cce" data-wf-site="575a31d2ce5d01dc7a20de45" lang="en"><head><meta charset="utf-8"/><title>Insight Data Science Fellows</title><meta content="Fellows from Insight Data Science are now at over 100 top companies like Facebook, Airbnb, Twitter, Pinterest, Uber, and many more." name="description"/><meta content="Insight Data Science Fellows" property="og:title"/><meta content="Fellows from Insight Data Science are now at over 100 top companies like Facebook, Airbnb, Twitter, Pinterest, Uber, and many more." property="og:description"/><meta content="summary" name="twitter:card"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="https://assets-global.website-files.com/575a31d2ce5d01dc7a20de45/css/data-science.cdd8beaaa.min.css" rel="stylesheet" type="text/css"/><script src="https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script><script type="text/javascript">WebFont.load({  google: {    families: ["Open Sans:300,300italic,400,400italic,600,600italic,700,700italic,800,800italic"]  }});</script><!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js" type="text/javascript"></script><![endif]--><script type="text/javascript">!function(o,c){var n=c.documentElement,t=" w-mod-";n.className+=t+"js",("ontouchstart"in o||o.DocumentTouch&&c instanceof DocumentTouch)&&(n.className+=t+"touch")}(window,document);</script><link href="https://assets-global.website-files.com/575a31d2ce5d01dc7a20de45/57aabe6454eef5b558c45c68_favicon-32x32.png" rel="shortcut icon" type="image/x-icon"/><link href="https://assets-global.website-files.com/575a31d2ce5d01dc7a20de45/57aabe6c1fd32dc352a64134_favicon-256x256.png" rel="apple-touch-icon"/><script type="text/javascript">!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.agent='plwebflow';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');fbq('init', '727689120904384');fbq('track', 'PageView');</script><meta property="og:image" content="http://uploads.webflow.com/575a31d2ce5d01dc7a20de45/575a31d2ce5d01dc7a20ded3_insight_logo.png">
# <meta property="og:site_name" content="Insight Data Science">
#
# <style>
#   .active_item_blue { border-bottom: 3px solid #577ada !important; padding-bottom: 1px !important; }
#   .active_item_green { border-bottom: 3px solid #49a99b !important; padding-bottom: 6px !important; }
#   .active_item_orange { border-bottom: 3px solid #f28d45 !important; padding-bottom: 6px !important; }
#   .circle_container { z-index: 50 !important; }
# </style>
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-29720873-1', 'auto', {allowLinker: true});
#   ga('require', 'linker');
#   ga('send', 'pageview');
#   ga('linker:autoLink', ['blog.insightdatascience.com', 'insightdatascience.com', 'insightdataengineering.com', 'insighthealthdata.com', 'insightdata.ai', 'insightdevops.com', 'insightdatapm.com', 'apply.insightdatascience.com' ,'insightconsensus.com', 'insightsecurityengineering.com']);
#
# </script>
#
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:1286009,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script>
#
# <script id="mcjs">!function(c,h,i,m,p){m=c.createElement(h),p=c.getElementsByTagName(h)[0],m.async=1,m.src=i,p.parentNode.insertBefore(m,p)}(document,"script","https://chimpstatic.com/mcjs-connected/js/users/a8645ecc221949e36988c14be/6c2eb4c831d52afbfee39f383.js");</script><style>
# .fellow_item:hover .fellows_tooltip { display: block; }
# .all_headers_container{ overflow: hidden; white-space: nowrap; vertical-align: top; }
# .slide_container_1 { position: absolute !important; }
# .slide_container_2 { position: absolute !important; }
# .slide_container_3 { position: absolute !important; }
# .slide_container_4 { position: absolute !important; }
# .program_slide_1, .program_slide_2, .program_slide_3, .program_slide_4 { position: absolute !important;}
# .fellows_slide_1, .fellows_slide_2, .fellows_slide_3, .fellows_slide_4, .fellows_slide_5 { position: absolute !important;}
# .mentorship_slide_1, .mentorship_slide_2 { position: absolute !important;}
# .industry_slide_1, .industry_slide_2 { position: absolute !important;}
# .community_slide_1, .community_slide_2 { position: absolute !important;}
# #link_program:hover { color: #5578d6; border-top: 3px solid #efefef; border-left: 3px solid #efefef; border-right: 3px solid #efefef; background: #fafafa; }
# .header_slider { overflow: hidden !important; }
# .apply_now_btn { vertical-align: top;}
# .btn_signup { vertical-align: top;}
# .mobile_nav_button { cursor: pointer; }
# .mobile_active_nav { color: #587adb !important; }
# .program_slide_item { box-sizing: border-box; vertical-align: top;}
# .fellows_slide_item { box-sizing: border-box; vertical-align: top;}
# .mentorship_slide_item { box-sizing: border-box; vertical-align: top;}
# .industry_slide_item { box-sizing: border-box; vertical-align: top;}
# .community_slide_item { box-sizing: border-box; vertical-align: top;}
# .industry_slide1_content { white-space: normal;}
# .it_transparent_text { white-space: normal;}
# .caption_text { white-space: normal;}
# .nav_item_faq:hover .nav_text_item {opacity:1;}
# .faq_category_item {cursor: pointer;}
# .question { vertical-align: middle;}
#
# .blue_link:active, .blue_link:link, .blue_link:visited, .blue_link:hover {color: #577ada;}
#
# .circle { width: 16px; height: 16px; border-radius: 50%; border: 2px solid rgba(255,255,255, 0.5); margin: 0px 8px; display: inline-block; cursor: pointer; -webkit-transition: all 0.2s; -moz-transition: all 0.2s; -ms-transition: all 0.2s; -o-transition: all 0.2s; transition: all 0.2s; }
# .circle:hover { background-color: #FFF; border: 2px solid #FFF; }
# .filled { background-color: #FFF; border: 2px solid #FFF; }
#
# .blue_circle { width: 12px; height: 12px; border-radius:50%; border: 3px solid #aabbea; margin: 0px 8px; display: inline-block; cursor: pointer; -webkit-transition: all 0.2s; -moz-transition: all 0.2s; -ms-transition: all 0.2s; -o-transition: all 0.2s; transition: all 0.2s;}
# .blue_circle:hover { background-color: #5578d6; border: 3px solid #5578d6;}
# .blue_filled { background-color: #5578d6; border: 3px solid #5578d6;}
#
# /* animations */
# .slide_inactive { left: 150% !important; }
# @keyframes slide_from_left_anim {
#     from { left: 150%; }
#     to { left: 50%; }
# }
# .slide_from_left {
# 	animation-fill-mode: forwards;
#     animation-name: slide_from_left_anim;
#     animation-duration: 1s;
# }
#
# @keyframes slide_to_right_anim {
#     from { left: 50%; }
#     to { left: -150%; }
# }
# .slide_to_right {
# 	animation-fill-mode: forwards;
#     animation-name: slide_to_right_anim;
#     animation-duration: 1s;
# }
# /* animations */
#
# /* animations header*/
# .slide_inactive_h { left: 100% !important; }
# @keyframes slide_from_left_anim_h {
#     from { left: 100%; }
#     to { left: 0%; }
# }
# .slide_from_left_h {
# 	animation-fill-mode: forwards;
#     animation-name: slide_from_left_anim_h;
#     animation-duration: 1s;
# }
#
# @keyframes slide_to_right_anim_h {
#     from { left: 0%; }
#     to { left: -100%; }
# }
# .slide_to_right_h {
# 	animation-fill-mode: forwards;
#     animation-name: slide_to_right_anim_h;
#     animation-duration: 1s;
# }
# /* animations header*/
#
# </style></head><body><div id="full_website" class="full_website w-clearfix"><div class="logo_nav"><div id="main-insight-logo" class="upper_header_wrapper-2 w-clearfix"><div class="middle_nav"><a id="header_bt_1" href="/" class="nav_item_data w-node-549be00df0e5-e00df0e3 w-inline-block"><div class="data_nav_text active_text">data science</div></a><a id="header_bt_2" href="https://www.insightdataengineering.com" class="nav_item_data mid w-node-549be00df0e8-e00df0e3 w-inline-block"><div id="main-de-header" class="data_nav_text">data eng</div></a><a href="https://www.insighthealthdata.com" id="header_bt_3" class="nav_item_data mid w-node-549be00df0eb-e00df0e3 w-inline-block"><div class="data_nav_text">health data</div></a><a href="https://www.insightdata.ai/" id="header_bt_3" class="nav_item_data mid w-node-549be00df0ee-e00df0e3 w-inline-block"><div class="data_nav_text">AI</div></a><a href="https://www.insightdatapm.com/" id="header_bt_3" class="nav_item_data mid w-node-549be00df0f1-e00df0e3 w-inline-block"><div class="data_nav_text">Data PM</div></a><a href="https://www.insightdevops.com/" id="header_bt_3" class="nav_item_data mid w-node-549be00df0f4-e00df0e3 w-inline-block"><div class="data_nav_text">DevOPS ENG</div></a><a href="https://www.insightconsensus.com/" id="header_bt_3" class="nav_item_data mid w-node-397981ddfbd0-e00df0e3 w-inline-block"><div class="data_nav_text">Consensus</div></a><a href="https://www.insightsecurityengineering.com/" id="header_bt_3" class="nav_item_data mid w-node-a42c9f0263b4-e00df0e3 w-inline-block"><div class="data_nav_text">security</div></a></div><div class="right_nav"><a id="header_bt_5" href="https://www.insightdatascience.com/fellows" class="right_nav_item-2 teal_nav w-inline-block"><div id="main-header-fellows" class="right_nav_item_text">fellows</div></a><a id="header_bt_6" href="https://apply.insightdatascience.com/start" target="_blank" class="right_nav_item-2 teal_nav w-inline-block"><div id="main-apply-header" class="right_nav_item_text padding">apply</div></a><a id="header_bt_7" href="/faq" class="right_nav_item-2 teal_nav w-inline-block"><div id="main-header-faq" class="right_nav_item_text padding">FAQ</div></a><a id="header_bt_8" href="http://blog.insightdatascience.com" class="right_nav_item-2 teal_nav w-inline-block"><div class="right_nav_item_text padding">blog</div></a></div><img src="https://assets-global.website-files.com/575a31d2ce5d01dc7a20de45/5bae65567fe6247530522922_blue_mobile_nav_button.png" alt="" class="mobile_nav_button teal_mobile"/><a href="https://www.insightdatascience.com/" class="site_logo w-inline-block"><img src="https://assets-global.website-files.com/575a31d2ce5d01dc7a20de45/575a31d2ce5d01dc7a20ded3_insight_logo.png" alt="" class="image-40"/></a></div></div><div id="header" class="fellows_content"><div class="fellows_title">Insight data science Fellows</div><div class="fellows_subtitle">Insight Fellows are data scientists at over 700 companies in <br/>Silicon Valley, New York City, Boston, Seattle, Toronto, Los Angeles, and across North America.</div><div class="fellows_grid"><div class="fellows_list w-dyn-list"><div class="w-clearfix w-dyn-items w-row"><div class="fellow_item w-dyn-item w-col w-col-2"><div class="fellows_tooltip"><div class="arrow_down"></div><div class="tooltip_header"><div class="tooltip_header_container"><div class="tooltip_name">JP Bida</div><div class="toottip_title">Director of Risk</div><div class="comma">,</div><div class="tooltip_company">Capital One</div></div></div><div class="tooltip_content"><div class="tooltip_title">insight project</div><div class="tooltip_project">Measuring the Impact of Open Source Coders on Github</div><div class="tooltip_title margin">background</div><div class="tooltip_background">Bio-X Games, Stanford, Postdoc</div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576976f76364789c4e58a0e8_JP-Pic.jpg&quot;)" class="fellow_img"><div class="fell ...
# </div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697251e8628b5103c6b117_Doug-Pic.jpg&quot;)" class="fellow_img"><div class="fellow_caption_back"><div class="fellow_name">Douglas Mason</div><div class="fellow_company">Twitter</div></div></div></div><div class="fellow_item w-dyn-item w-col w-col-2"><div class="fellows_tooltip"><div class="arrow_down"></div><div class="tooltip_header"><div class="tooltip_header_container"><div class="tooltip_name">Virot Ta Chiraphadhanakul</div><div class="toottip_title">Data Scientist</div><div class="comma">,</div><div class="tooltip_company">Facebook</div></div></div><div class="tooltip_content"><div class="tooltip_title">insight project</div><div class="tooltip_project">Tweet Timeline: Visualizing the Impact of Social Media</div><div class="tooltip_title margin">background</div><div class="tooltip_background">Operations Research, MIT, PhD</div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769760f6364789c4e589ce7_Ta-Pic.jpg&quot;)" class="fellow_img"><div class="fellow_caption_back"><div class="fellow_name">Virot Ta Chiraphadhanakul</div><div class="fellow_company">Facebook</div></div></div></div><div class="fellow_item w-dyn-item w-col w-col-2"><div class="fellows_tooltip"><div class="arrow_down"></div><div class="tooltip_header"><div class="tooltip_header_container"><div class="tooltip_name">Julia Viladomat</div><div class="toottip_title">Data Scientist</div><div class="comma">,</div><div class="tooltip_company">Adobe</div></div></div><div class="tooltip_content"><div class="tooltip_title">insight project</div><div class="tooltip_project">Sentiment Analysis Based on Social Media</div><div class="tooltip_title margin">background</div><div class="tooltip_background">Statistics, Stanford, Postdoc</div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57685673bc51c12e173d3ba2_Julia%20Pic.jpg&quot;)" class="fellow_img"><div class="fellow_caption_back"><div class="fellow_name">Julia Viladomat</div><div class="fellow_company">Adobe</div></div></div></div><div class="fellow_item w-dyn-item w-col w-col-2"><div class="fellows_tooltip"><div class="arrow_down"></div><div class="tooltip_header"><div class="tooltip_header_container"><div class="tooltip_name">David Freeman</div><div class="toottip_title">Head of Anti-Abuse Engineering</div><div class="comma">,</div><div class="tooltip_company">LinkedIn</div></div></div><div class="tooltip_content"><div class="tooltip_title">insight project</div><div class="tooltip_project">Flight Delay Predictor</div><div class="tooltip_title margin">background</div><div class="tooltip_background">Mathematics, Stanford, Postdoc</div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b885e8628b5103c73621_davidfreeman-main.jpg&quot;)" class="fellow_img"><div class="fellow_caption_back"><div class="fellow_name">David Freeman</div><div class="fellow_company">LinkedIn</div></div></div></div><div class="fellow_item w-dyn-item w-col w-col-2"><div class="fellows_tooltip"><div class="arrow_down"></div><div class="tooltip_header"><div class="tooltip_header_container"><div class="tooltip_name">Jessica ZÃºÃ±iga</div><div class="toottip_title">Senior Data Scientist</div><div class="comma">,</div><div class="tooltip_company">LinkedIn</div></div></div><div class="tooltip_content"><div class="tooltip_title">insight project</div><div class="tooltip_project">Email Contacts Automatically Grouped &amp; Ranked</div><div class="tooltip_title margin">background</div><div class="tooltip_background">Mathematics, Duke, Postdoc</div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bb9322c61e320363317d_Jessica-Pic.jpg&quot;)" class="fellow_img"><div class="fellow_caption_back"><div class=" ...
# <script>
# $(document).ready(function(){
# 	var fellow_width = $(".fellow_img").width();
#   $(".fellow_img").css("height",fellow_width);
#   $(".fellows_tooltip").css("bottom",fellow_width + 20);
#
# $(window).bind('resize', function(e) {
# window.resizeEvt;
# $(window).resize(function() {
# clearTimeout(window.resizeEvt);
# window.resizeEvt = setTimeout(function() {
#
# var fellow_width = $(".fellow_img").width();
# $(".fellow_img").css("height",fellow_width);
# $(".fellows_tooltip").css("bottom",fellow_width + 20);
#
# }, 10);
# });
# });
#
# 	$("#header_bt_1").addClass("active_item_blue");
#   $("#footer_bt_1").addClass("active_item_blue");
#   $("#header_bt_5").addClass("active_item_blue");
#   $("#footer_bt_5").addClass("active_item_blue");
#
#   // mobile side nav
# 	var nav = 0;
#
# 	$(".mobile_nav_button").click(function(){
# 		if ( nav == 1 ) {
# 			$("#full_website").animate({"right":"0%"}, 500);
# 			$("#side_nav_bar").animate({"right":"-80%"}, 500);
# 			nav = 0;
# 		} else {
# 			$("#full_website").animate({"right":"80%"}, 500);
# 			$("#side_nav_bar").animate({"right":"0%"}, 500);
# 			nav = 1;
# 		}
# 	});
#
#   // mobile section nav
#
#   var expanded = 0;
#
#   function expand_close() {
#   	if (expanded == 0) { $(".mobile_sub_nav").css("display","block"); expanded = 1; }
#     else { $(".mobile_sub_nav").css("display","none"); expanded = 0; }
#   }
#
#
#   $("#link_dropdown").click(function(){
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#   });
#
#   $("#mlink_program").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#   });
#
#   $("#mlink_fellows").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#    $("#mlink_mentorship").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#    $("#mlink_industry").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#    $("#mlink_community").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#
# 	window.f_slide = 1;
#   window.p_slide = 1;
#   window.m_slide = 1;
#   window.i_slide = 1;
#   window.c_slide = 1;
#   window.header_slide = 1;
#
# 		$("#link_program, #mlink_program").click(function(){
#   		$("#pslide_inner_container").animate({left:0}, 300);
# 		$("#pcircle_1").addClass("blue_filled");
# 		$("#pcircle_2, #pcircle_3, #pcircle_4, #pcircle_5, #pcircle_6, #pcircle_7, #pcircle_8, #pcircle_9").removeClass("blue_filled");
#
# 		p_slide = 1;
# 		$("#link_program").addClass("active_nav");
# 		$("#link_fellows, #link_mentorship, #link_industry, #link_community").removeClass("active_nav");
# 		$("#program_content").css("display","block");
# 		$("#fellows_content, #mentorship_content, #industry_content, #community_content").css("display","none");
# 	});
#
#   $("#link_fellows, #mlink_fellows").click(function(){
# 		$("#fslide_inner_container").animate({left:0}, 300);
# 		$("#fcircle_1").addClass("blue_filled");
# 		$("#fcircle_2, #fcircle_3, #fcircle_4, #fcircle_5, #fcircle_6, #fcircle_7, #fcircle_8, #fcircle_9").removeClass("blue_filled");
#
# 		f_slide = 1;
# 		$("#link_program, #link_mentorship, #link_industry, #link_community").removeClass("active_nav");
# 		$("#link_fellows").addClass("active_nav");
#
# 		$("#program_content, #mentorship_content, #industry_content, #community_content").css("display","none");
# 		$("#fellows_content").css("display","block");
# 	});
#
#
#
#
#
#
# });
# </script></body></html>

# %% [markdown]
# ## Dealing with Exceptions

# %%
import requests
from requests.exceptions import RequestException

# %%
def get_one_page(url):
    '''
    Get the html for one page
    With the exceptions
    '''
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
        return None
    except RequestException:
        return None

# %%
url = 'https://www.insightdatascience.com/fellows?61ea5d1b_page=1'
html = get_one_page(url)
print(html)
# Out:
# <!DOCTYPE html><!-- Last Published: Thu Jun 20 2019 23:58:24 GMT+0000 (UTC) --><html data-wf-domain="www.insightdatascience.com" data-wf-page="5bd3f311a37dacd7c38d6cce" data-wf-site="575a31d2ce5d01dc7a20de45" lang="en"><head><meta charset="utf-8"/><title>Insight Data Science Fellows</title><meta content="Fellows from Insight Data Science are now at over 100 top companies like Facebook, Airbnb, Twitter, Pinterest, Uber, and many more." name="description"/><meta content="Insight Data Science Fellows" property="og:title"/><meta content="Fellows from Insight Data Science are now at over 100 top companies like Facebook, Airbnb, Twitter, Pinterest, Uber, and many more." property="og:description"/><meta content="summary" name="twitter:card"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="https://assets-global.website-files.com/575a31d2ce5d01dc7a20de45/css/data-science.cdd8beaaa.min.css" rel="stylesheet" type="text/css"/><script src="https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script><script type="text/javascript">WebFont.load({  google: {    families: ["Open Sans:300,300italic,400,400italic,600,600italic,700,700italic,800,800italic"]  }});</script><!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js" type="text/javascript"></script><![endif]--><script type="text/javascript">!function(o,c){var n=c.documentElement,t=" w-mod-";n.className+=t+"js",("ontouchstart"in o||o.DocumentTouch&&c instanceof DocumentTouch)&&(n.className+=t+"touch")}(window,document);</script><link href="https://assets-global.website-files.com/575a31d2ce5d01dc7a20de45/57aabe6454eef5b558c45c68_favicon-32x32.png" rel="shortcut icon" type="image/x-icon"/><link href="https://assets-global.website-files.com/575a31d2ce5d01dc7a20de45/57aabe6c1fd32dc352a64134_favicon-256x256.png" rel="apple-touch-icon"/><script type="text/javascript">!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.agent='plwebflow';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');fbq('init', '727689120904384');fbq('track', 'PageView');</script><meta property="og:image" content="http://uploads.webflow.com/575a31d2ce5d01dc7a20de45/575a31d2ce5d01dc7a20ded3_insight_logo.png">
# <meta property="og:site_name" content="Insight Data Science">
#
# <style>
#   .active_item_blue { border-bottom: 3px solid #577ada !important; padding-bottom: 1px !important; }
#   .active_item_green { border-bottom: 3px solid #49a99b !important; padding-bottom: 6px !important; }
#   .active_item_orange { border-bottom: 3px solid #f28d45 !important; padding-bottom: 6px !important; }
#   .circle_container { z-index: 50 !important; }
# </style>
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-29720873-1', 'auto', {allowLinker: true});
#   ga('require', 'linker');
#   ga('send', 'pageview');
#   ga('linker:autoLink', ['blog.insightdatascience.com', 'insightdatascience.com', 'insightdataengineering.com', 'insighthealthdata.com', 'insightdata.ai', 'insightdevops.com', 'insightdatapm.com', 'apply.insightdatascience.com' ,'insightconsensus.com', 'insightsecurityengineering.com']);
#
# </script>
#
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:1286009,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script>
#
# <script id="mcjs">!function(c,h,i,m,p){m=c.createElement(h),p=c.getElementsByTagName(h)[0],m.async=1,m.src=i,p.parentNode.insertBefore(m,p)}(document,"script","https://chimpstatic.com/mcjs-connected/js/users/a8645ecc221949e36988c14be/6c2eb4c831d52afbfee39f383.js");</script><style>
# .fellow_item:hover .fellows_tooltip { display: block; }
# .all_headers_container{ overflow: hidden; white-space: nowrap; vertical-align: top; }
# .slide_container_1 { position: absolute !important; }
# .slide_container_2 { position: absolute !important; }
# .slide_container_3 { position: absolute !important; }
# .slide_container_4 { position: absolute !important; }
# .program_slide_1, .program_slide_2, .program_slide_3, .program_slide_4 { position: absolute !important;}
# .fellows_slide_1, .fellows_slide_2, .fellows_slide_3, .fellows_slide_4, .fellows_slide_5 { position: absolute !important;}
# .mentorship_slide_1, .mentorship_slide_2 { position: absolute !important;}
# .industry_slide_1, .industry_slide_2 { position: absolute !important;}
# .community_slide_1, .community_slide_2 { position: absolute !important;}
# #link_program:hover { color: #5578d6; border-top: 3px solid #efefef; border-left: 3px solid #efefef; border-right: 3px solid #efefef; background: #fafafa; }
# .header_slider { overflow: hidden !important; }
# .apply_now_btn { vertical-align: top;}
# .btn_signup { vertical-align: top;}
# .mobile_nav_button { cursor: pointer; }
# .mobile_active_nav { color: #587adb !important; }
# .program_slide_item { box-sizing: border-box; vertical-align: top;}
# .fellows_slide_item { box-sizing: border-box; vertical-align: top;}
# .mentorship_slide_item { box-sizing: border-box; vertical-align: top;}
# .industry_slide_item { box-sizing: border-box; vertical-align: top;}
# .community_slide_item { box-sizing: border-box; vertical-align: top;}
# .industry_slide1_content { white-space: normal;}
# .it_transparent_text { white-space: normal;}
# .caption_text { white-space: normal;}
# .nav_item_faq:hover .nav_text_item {opacity:1;}
# .faq_category_item {cursor: pointer;}
# .question { vertical-align: middle;}
#
# .blue_link:active, .blue_link:link, .blue_link:visited, .blue_link:hover {color: #577ada;}
#
# .circle { width: 16px; height: 16px; border-radius: 50%; border: 2px solid rgba(255,255,255, 0.5); margin: 0px 8px; display: inline-block; cursor: pointer; -webkit-transition: all 0.2s; -moz-transition: all 0.2s; -ms-transition: all 0.2s; -o-transition: all 0.2s; transition: all 0.2s; }
# .circle:hover { background-color: #FFF; border: 2px solid #FFF; }
# .filled { background-color: #FFF; border: 2px solid #FFF; }
#
# .blue_circle { width: 12px; height: 12px; border-radius:50%; border: 3px solid #aabbea; margin: 0px 8px; display: inline-block; cursor: pointer; -webkit-transition: all 0.2s; -moz-transition: all 0.2s; -ms-transition: all 0.2s; -o-transition: all 0.2s; transition: all 0.2s;}
# .blue_circle:hover { background-color: #5578d6; border: 3px solid #5578d6;}
# .blue_filled { background-color: #5578d6; border: 3px solid #5578d6;}
#
# /* animations */
# .slide_inactive { left: 150% !important; }
# @keyframes slide_from_left_anim {
#     from { left: 150%; }
#     to { left: 50%; }
# }
# .slide_from_left {
# 	animation-fill-mode: forwards;
#     animation-name: slide_from_left_anim;
#     animation-duration: 1s;
# }
#
# @keyframes slide_to_right_anim {
#     from { left: 50%; }
#     to { left: -150%; }
# }
# .slide_to_right {
# 	animation-fill-mode: forwards;
#     animation-name: slide_to_right_anim;
#     animation-duration: 1s;
# }
# /* animations */
#
# /* animations header*/
# .slide_inactive_h { left: 100% !important; }
# @keyframes slide_from_left_anim_h {
#     from { left: 100%; }
#     to { left: 0%; }
# }
# .slide_from_left_h {
# 	animation-fill-mode: forwards;
#     animation-name: slide_from_left_anim_h;
#     animation-duration: 1s;
# }
#
# @keyframes slide_to_right_anim_h {
#     from { left: 0%; }
#     to { left: -100%; }
# }
# .slide_to_right_h {
# 	animation-fill-mode: forwards;
#     animation-name: slide_to_right_anim_h;
#     animation-duration: 1s;
# }
# /* animations header*/
#
# </style></head><body><div id="full_website" class="full_website w-clearfix"><div class="logo_nav"><div id="main-insight-logo" class="upper_header_wrapper-2 w-clearfix"><div class="middle_nav"><a id="header_bt_1" href="/" class="nav_item_data w-node-549be00df0e5-e00df0e3 w-inline-block"><div class="data_nav_text active_text">data science</div></a><a id="header_bt_2" href="https://www.insightdataengineering.com" class="nav_item_data mid w-node-549be00df0e8-e00df0e3 w-inline-block"><div id="main-de-header" class="data_nav_text">data eng</div></a><a href="https://www.insighthealthdata.com" id="header_bt_3" class="nav_item_data mid w-node-549be00df0eb-e00df0e3 w-inline-block"><div class="data_nav_text">health data</div></a><a href="https://www.insightdata.ai/" id="header_bt_3" class="nav_item_data mid w-node-549be00df0ee-e00df0e3 w-inline-block"><div class="data_nav_text">AI</div></a><a href="https://www.insightdatapm.com/" id="header_bt_3" class="nav_item_data mid w-node-549be00df0f1-e00df0e3 w-inline-block"><div class="data_nav_text">Data PM</div></a><a href="https://www.insightdevops.com/" id="header_bt_3" class="nav_item_data mid w-node-549be00df0f4-e00df0e3 w-inline-block"><div class="data_nav_text">DevOPS ENG</div></a><a href="https://www.insightconsensus.com/" id="header_bt_3" class="nav_item_data mid w-node-397981ddfbd0-e00df0e3 w-inline-block"><div class="data_nav_text">Consensus</div></a><a href="https://www.insightsecurityengineering.com/" id="header_bt_3" class="nav_item_data mid w-node-a42c9f0263b4-e00df0e3 w-inline-block"><div class="data_nav_text">security</div></a></div><div class="right_nav"><a id="header_bt_5" href="https://www.insightdatascience.com/fellows" class="right_nav_item-2 teal_nav w-inline-block"><div id="main-header-fellows" class="right_nav_item_text">fellows</div></a><a id="header_bt_6" href="https://apply.insightdatascience.com/start" target="_blank" class="right_nav_item-2 teal_nav w-inline-block"><div id="main-apply-header" class="right_nav_item_text padding">apply</div></a><a id="header_bt_7" href="/faq" class="right_nav_item-2 teal_nav w-inline-block"><div id="main-header-faq" class="right_nav_item_text padding">FAQ</div></a><a id="header_bt_8" href="http://blog.insightdatascience.com" class="right_nav_item-2 teal_nav w-inline-block"><div class="right_nav_item_text padding">blog</div></a></div><img src="https://assets-global.website-files.com/575a31d2ce5d01dc7a20de45/5bae65567fe6247530522922_blue_mobile_nav_button.png" alt="" class="mobile_nav_button teal_mobile"/><a href="https://www.insightdatascience.com/" class="site_logo w-inline-block"><img src="https://assets-global.website-files.com/575a31d2ce5d01dc7a20de45/575a31d2ce5d01dc7a20ded3_insight_logo.png" alt="" class="image-40"/></a></div></div><div id="header" class="fellows_content"><div class="fellows_title">Insight data science Fellows</div><div class="fellows_subtitle">Insight Fellows are data scientists at over 700 companies in <br/>Silicon Valley, New York City, Boston, Seattle, Toronto, Los Angeles, and across North America.</div><div class="fellows_grid"><div class="fellows_list w-dyn-list"><div class="w-clearfix w-dyn-items w-row"><div class="fellow_item w-dyn-item w-col w-col-2"><div class="fellows_tooltip"><div class="arrow_down"></div><div class="tooltip_header"><div class="tooltip_header_container"><div class="tooltip_name">JP Bida</div><div class="toottip_title">Director of Risk</div><div class="comma">,</div><div class="tooltip_company">Capital One</div></div></div><div class="tooltip_content"><div class="tooltip_title">insight project</div><div class="tooltip_project">Measuring the Impact of Open Source Coders on Github</div><div class="tooltip_title margin">background</div><div class="tooltip_background">Bio-X Games, Stanford, Postdoc</div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576976f76364789c4e58a0e8_JP-Pic.jpg&quot;)" class="fellow_img"><div class="fell ...
# </div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697251e8628b5103c6b117_Doug-Pic.jpg&quot;)" class="fellow_img"><div class="fellow_caption_back"><div class="fellow_name">Douglas Mason</div><div class="fellow_company">Twitter</div></div></div></div><div class="fellow_item w-dyn-item w-col w-col-2"><div class="fellows_tooltip"><div class="arrow_down"></div><div class="tooltip_header"><div class="tooltip_header_container"><div class="tooltip_name">Virot Ta Chiraphadhanakul</div><div class="toottip_title">Data Scientist</div><div class="comma">,</div><div class="tooltip_company">Facebook</div></div></div><div class="tooltip_content"><div class="tooltip_title">insight project</div><div class="tooltip_project">Tweet Timeline: Visualizing the Impact of Social Media</div><div class="tooltip_title margin">background</div><div class="tooltip_background">Operations Research, MIT, PhD</div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769760f6364789c4e589ce7_Ta-Pic.jpg&quot;)" class="fellow_img"><div class="fellow_caption_back"><div class="fellow_name">Virot Ta Chiraphadhanakul</div><div class="fellow_company">Facebook</div></div></div></div><div class="fellow_item w-dyn-item w-col w-col-2"><div class="fellows_tooltip"><div class="arrow_down"></div><div class="tooltip_header"><div class="tooltip_header_container"><div class="tooltip_name">Julia Viladomat</div><div class="toottip_title">Data Scientist</div><div class="comma">,</div><div class="tooltip_company">Adobe</div></div></div><div class="tooltip_content"><div class="tooltip_title">insight project</div><div class="tooltip_project">Sentiment Analysis Based on Social Media</div><div class="tooltip_title margin">background</div><div class="tooltip_background">Statistics, Stanford, Postdoc</div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57685673bc51c12e173d3ba2_Julia%20Pic.jpg&quot;)" class="fellow_img"><div class="fellow_caption_back"><div class="fellow_name">Julia Viladomat</div><div class="fellow_company">Adobe</div></div></div></div><div class="fellow_item w-dyn-item w-col w-col-2"><div class="fellows_tooltip"><div class="arrow_down"></div><div class="tooltip_header"><div class="tooltip_header_container"><div class="tooltip_name">David Freeman</div><div class="toottip_title">Head of Anti-Abuse Engineering</div><div class="comma">,</div><div class="tooltip_company">LinkedIn</div></div></div><div class="tooltip_content"><div class="tooltip_title">insight project</div><div class="tooltip_project">Flight Delay Predictor</div><div class="tooltip_title margin">background</div><div class="tooltip_background">Mathematics, Stanford, Postdoc</div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b885e8628b5103c73621_davidfreeman-main.jpg&quot;)" class="fellow_img"><div class="fellow_caption_back"><div class="fellow_name">David Freeman</div><div class="fellow_company">LinkedIn</div></div></div></div><div class="fellow_item w-dyn-item w-col w-col-2"><div class="fellows_tooltip"><div class="arrow_down"></div><div class="tooltip_header"><div class="tooltip_header_container"><div class="tooltip_name">Jessica ZÃºÃ±iga</div><div class="toottip_title">Senior Data Scientist</div><div class="comma">,</div><div class="tooltip_company">LinkedIn</div></div></div><div class="tooltip_content"><div class="tooltip_title">insight project</div><div class="tooltip_project">Email Contacts Automatically Grouped &amp; Ranked</div><div class="tooltip_title margin">background</div><div class="tooltip_background">Mathematics, Duke, Postdoc</div></div></div><div style="background-image:url(&quot;https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bb9322c61e320363317d_Jessica-Pic.jpg&quot;)" class="fellow_img"><div class="fellow_caption_back"><div class=" ...
# <script>
# $(document).ready(function(){
# 	var fellow_width = $(".fellow_img").width();
#   $(".fellow_img").css("height",fellow_width);
#   $(".fellows_tooltip").css("bottom",fellow_width + 20);
#
# $(window).bind('resize', function(e) {
# window.resizeEvt;
# $(window).resize(function() {
# clearTimeout(window.resizeEvt);
# window.resizeEvt = setTimeout(function() {
#
# var fellow_width = $(".fellow_img").width();
# $(".fellow_img").css("height",fellow_width);
# $(".fellows_tooltip").css("bottom",fellow_width + 20);
#
# }, 10);
# });
# });
#
# 	$("#header_bt_1").addClass("active_item_blue");
#   $("#footer_bt_1").addClass("active_item_blue");
#   $("#header_bt_5").addClass("active_item_blue");
#   $("#footer_bt_5").addClass("active_item_blue");
#
#   // mobile side nav
# 	var nav = 0;
#
# 	$(".mobile_nav_button").click(function(){
# 		if ( nav == 1 ) {
# 			$("#full_website").animate({"right":"0%"}, 500);
# 			$("#side_nav_bar").animate({"right":"-80%"}, 500);
# 			nav = 0;
# 		} else {
# 			$("#full_website").animate({"right":"80%"}, 500);
# 			$("#side_nav_bar").animate({"right":"0%"}, 500);
# 			nav = 1;
# 		}
# 	});
#
#   // mobile section nav
#
#   var expanded = 0;
#
#   function expand_close() {
#   	if (expanded == 0) { $(".mobile_sub_nav").css("display","block"); expanded = 1; }
#     else { $(".mobile_sub_nav").css("display","none"); expanded = 0; }
#   }
#
#
#   $("#link_dropdown").click(function(){
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#   });
#
#   $("#mlink_program").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#   });
#
#   $("#mlink_fellows").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#    $("#mlink_mentorship").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#    $("#mlink_industry").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#    $("#mlink_community").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#
# 	window.f_slide = 1;
#   window.p_slide = 1;
#   window.m_slide = 1;
#   window.i_slide = 1;
#   window.c_slide = 1;
#   window.header_slide = 1;
#
# 		$("#link_program, #mlink_program").click(function(){
#   		$("#pslide_inner_container").animate({left:0}, 300);
# 		$("#pcircle_1").addClass("blue_filled");
# 		$("#pcircle_2, #pcircle_3, #pcircle_4, #pcircle_5, #pcircle_6, #pcircle_7, #pcircle_8, #pcircle_9").removeClass("blue_filled");
#
# 		p_slide = 1;
# 		$("#link_program").addClass("active_nav");
# 		$("#link_fellows, #link_mentorship, #link_industry, #link_community").removeClass("active_nav");
# 		$("#program_content").css("display","block");
# 		$("#fellows_content, #mentorship_content, #industry_content, #community_content").css("display","none");
# 	});
#
#   $("#link_fellows, #mlink_fellows").click(function(){
# 		$("#fslide_inner_container").animate({left:0}, 300);
# 		$("#fcircle_1").addClass("blue_filled");
# 		$("#fcircle_2, #fcircle_3, #fcircle_4, #fcircle_5, #fcircle_6, #fcircle_7, #fcircle_8, #fcircle_9").removeClass("blue_filled");
#
# 		f_slide = 1;
# 		$("#link_program, #link_mentorship, #link_industry, #link_community").removeClass("active_nav");
# 		$("#link_fellows").addClass("active_nav");
#
# 		$("#program_content, #mentorship_content, #industry_content, #community_content").css("display","none");
# 		$("#fellows_content").css("display","block");
# 	});
#
#
#
#
#
#
# });
# </script></body></html>

# %% [markdown]
# ## Using re (regular expression) to identify information

# %%
import requests
from requests.exceptions import RequestException
import re

# %%
def get_one_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
        return None
    except RequestException:
        return None
    
def parse_one_page(html):
    pattern = re.compile('tooltip_name">(.*?)</div>.*?'
                         + 'toottip_title">(.*?)</div>.*?'
                         + 'tooltip_company">(.*?)</div>.*?'
                         + 'tooltip_project">(.*?)</div>.*?'
                         + 'tooltip_background">(.*?)</div>.*?'
                         + '&quot;(.*?)&quot;'
                         ,re.S)
    
    items = re.findall(pattern, html)
    print(items)

# %%
url = 'https://www.insightdatascience.com/fellows?61ea5d1b_page=1'
html = get_one_page(url)
# print(html)
parse_one_page(html)
# Out:
# [('JP Bida', 'Director of Risk', 'Capital One', 'Measuring the Impact of Open Source Coders on Github', 'Bio-X Games, Stanford, Postdoc', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576976f76364789c4e58a0e8_JP-Pic.jpg'), ('Douglas Mason', 'Data Scientist', 'Twitter', 'Email Searcher: Search &amp; Visualize Your Mailbox', 'Physics, Harvard University,Â\xa0PhD\n', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697251e8628b5103c6b117_Doug-Pic.jpg'), ('Virot Ta Chiraphadhanakul', 'Data Scientist', 'Facebook', 'Tweet Timeline: Visualizing the Impact of Social Media', 'Operations Research, MIT, PhD', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769760f6364789c4e589ce7_Ta-Pic.jpg'), ('Julia Viladomat', 'Data Scientist', 'Adobe', 'Sentiment Analysis Based on Social Media', 'Statistics, Stanford, Postdoc', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57685673bc51c12e173d3ba2_Julia%20Pic.jpg'), ('David Freeman', 'Head of Anti-Abuse Engineering', 'LinkedIn', 'Flight Delay Predictor', 'Mathematics, Stanford, Postdoc', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b885e8628b5103c73621_davidfreeman-main.jpg'), ('Jessica ZÃºÃ±iga', 'Senior Data Scientist', 'LinkedIn', 'Email Contacts Automatically Grouped &amp; Ranked', 'Mathematics, Duke, Postdoc', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bb9322c61e320363317d_Jessica-Pic.jpg'), ('Harold Nguyen', 'Data Scientist', 'Proofpoint', 'Analysis of New York Stop-and-Frisk Data', 'Physics, UC Riverside, PhD', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576855b4df388b30315c45b0_Harold.jpg'), ('Sebastien de Larquier ', 'Data Scientist', 'Netflix', 'CouchTube: YouTube TV shows in one click', 'Space Physics, Virgina Tech, PhD', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ada79680f7412500914dd_Sebastien2.jpg'), ('Paula Therese Lang', 'Senior Data Scientist', 'CreativeLIVE', 'SchoolGeo: Empowering Parents to Make Informed Decisions', 'Computational Biology, UC Berkeley, Postdoc', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841d1e74ffc3cf55313410_terry.jpg'), ('Nan Ma', 'Data Engineer', 'Microsoft Yammer', 'Event Map: Get Local News from Twitter', 'Electrical Engineering &amp; Computer Science, UC Berkeley, Postdoc', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576971986364789c4e5893bf_NanMa.jpg'), ('Cinna Julie Wu', 'Data Scientist', 'Facebook', 'Sort My Friends: Automatically Organize your Connections', 'Applied Mathematics, UC Berkeley, PhD', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57685e33cf2f2b4d31a02788_CinnaWu.jpg'), ('Erin Summers', 'Software Engineer', 'Facebook', 'Flat Finder: Find Your Perfect Apartment', 'Electrical Engineering &amp; Computer Science, UC Berkeley, PhD', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57687784cf2f2b4d31a04fc6_ErinSummers.png'), ('Leah McGuire', 'Senior Data Scientist', 'LinkedIn', 'Kiva Loan Checker', 'Computational Neuroscience, UC Berkeley, Postdoc', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697c4622c61e320362d58d_LeahMcGuire.jpg'), ('Nick Bunch', 'Quantitative Analyst', 'YouTube', 'Arrive in Time: Airport Arrival Time Predictor', 'Space Plasma Physics, Stanford, Postdoc', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697f266364789c4e58b1f2_NickBunch.jpg'), ('Shelby Sturgis', 'Senior Data Visualization Engineer', 'Netflix', 'STARtrack: Helping Educators Track Student Performance', 'Biology, Stanford, PhD', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769831e6364789c4e58b39d_ShelbySturgis.jpg'), ('Onkar Dalal', 'Data Scientist', 'LinkedIn', 'Diverse Recipe Recommendations', 'Computational &amp; Mathematical Engineering, Stanford, PhD', 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697fc541db86a74ee10ca7_Onkar.jpg'), ('Aastha Jain', 'Data Scientist', 'LinkedIn', 'Multi-Domain Recommendations', 'Computer Vision &a ...

# %% [markdown]
# ## Converting data into orgnized dictionary structure

# %%
def get_one_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
        return None
    except RequestException:
        return None
    
def parse_one_page(html):
    pattern = re.compile('tooltip_name">(.*?)</div>.*?'
                         + 'toottip_title">(.*?)</div>.*?'
                         + 'tooltip_company">(.*?)</div>.*?'
                         + 'tooltip_project">(.*?)</div>.*?'
                         + 'tooltip_background">(.*?)</div>.*?'
                         + '&quot;(.*?)&quot;'
                         ,re.S)
    
    items = re.findall(pattern, html)
    
    for item in items:
        yield{
            'name': item[0],
            'title': item[1],
            'company': item[2],
            'project': item[3],
            'background': item[4],
            'imagelink': item[5]
        }

# %%
url = 'https://www.insightdatascience.com/fellows?61ea5d1b_page=1'
html = get_one_page(url)
# print(html)
for idx, item in enumerate(parse_one_page(html)):
    print(idx)
    print(item)
# Out:
# 0
# {'name': 'JP Bida', 'title': 'Director of Risk', 'company': 'Capital One', 'project': 'Measuring the Impact of Open Source Coders on Github', 'background': 'Bio-X Games, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576976f76364789c4e58a0e8_JP-Pic.jpg'}
# 1
# {'name': 'Douglas Mason', 'title': 'Data Scientist', 'company': 'Twitter', 'project': 'Email Searcher: Search &amp; Visualize Your Mailbox', 'background': 'Physics, Harvard University,Â\xa0PhD\n', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697251e8628b5103c6b117_Doug-Pic.jpg'}
# 2
# {'name': 'Virot Ta Chiraphadhanakul', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'Tweet Timeline: Visualizing the Impact of Social Media', 'background': 'Operations Research, MIT, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769760f6364789c4e589ce7_Ta-Pic.jpg'}
# 3
# {'name': 'Julia Viladomat', 'title': 'Data Scientist', 'company': 'Adobe', 'project': 'Sentiment Analysis Based on Social Media', 'background': 'Statistics, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57685673bc51c12e173d3ba2_Julia%20Pic.jpg'}
# 4
# {'name': 'David Freeman', 'title': 'Head of Anti-Abuse Engineering', 'company': 'LinkedIn', 'project': 'Flight Delay Predictor', 'background': 'Mathematics, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b885e8628b5103c73621_davidfreeman-main.jpg'}
# 5
# {'name': 'Jessica ZÃºÃ±iga', 'title': 'Senior Data Scientist', 'company': 'LinkedIn', 'project': 'Email Contacts Automatically Grouped &amp; Ranked', 'background': 'Mathematics, Duke, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bb9322c61e320363317d_Jessica-Pic.jpg'}
# 6
# {'name': 'Harold Nguyen', 'title': 'Data Scientist', 'company': 'Proofpoint', 'project': 'Analysis of New York Stop-and-Frisk Data', 'background': 'Physics, UC Riverside, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576855b4df388b30315c45b0_Harold.jpg'}
# 7
# {'name': 'Sebastien de Larquier ', 'title': 'Data Scientist', 'company': 'Netflix', 'project': 'CouchTube: YouTube TV shows in one click', 'background': 'Space Physics, Virgina Tech, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ada79680f7412500914dd_Sebastien2.jpg'}
# 8
# {'name': 'Paula Therese Lang', 'title': 'Senior Data Scientist', 'company': 'CreativeLIVE', 'project': 'SchoolGeo: Empowering Parents to Make Informed Decisions', 'background': 'Computational Biology, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841d1e74ffc3cf55313410_terry.jpg'}
# 9
# {'name': 'Nan Ma', 'title': 'Data Engineer', 'company': 'Microsoft Yammer', 'project': 'Event Map: Get Local News from Twitter', 'background': 'Electrical Engineering &amp; Computer Science, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576971986364789c4e5893bf_NanMa.jpg'}
# 10
# {'name': 'Cinna Julie Wu', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'Sort My Friends: Automatically Organize your Connections', 'background': 'Applied Mathematics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57685e33cf2f2b4d31a02788_CinnaWu.jpg'}
# 11
# {'name': 'Erin Summers', 'title': 'Software Engineer', 'company': 'Facebook', 'project': 'Flat Finder: Find Your Perfect Apartment', 'background': 'Electrical Engineering &amp; Computer Science, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57687784cf2f2b4d31a04fc6_ErinSummers.png'}
# 12
# {'name': 'Leah McGuire', 'title': 'Senior Data Scientist', 'company': 'LinkedIn', 'project': 'Kiva Loan Checker', 'background': 'Computational Neuroscience, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697c4622c61e320362d58d_LeahMcGuire.jpg'}
# 13
# {'name': 'Nick Bunch', 'title': 'Quantitative Analyst', 'company': 'YouTube', 'project': 'Arrive in Time: Airport Arrival Time Predictor', 'background': 'Space Plasma Physics, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697f266364789c4e58b1f2_NickBunch.jpg'}
# 14
# {'name': 'Shelby Sturgis', 'title': 'Senior Data Visualization Engineer', 'company': 'Netflix', 'project': 'STARtrack: Helping Educators Track Student Performance', 'background': 'Biology, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769831e6364789c4e58b39d_ShelbySturgis.jpg'}
# 15
# {'name': 'Onkar Dalal', 'title': 'Data Scientist', 'company': 'LinkedIn', 'project': 'Diverse Recipe Recommendations', 'background': 'Computational &amp; Mathematical Engineering, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697fc541db86a74ee10ca7_Onkar.jpg'}
# 16
# {'name': 'Aastha Jain', 'title': 'Data Scientist', 'company': 'LinkedIn', 'project': 'Multi-Domain Recommendations', 'background': 'Computer Vision &amp; Image Processing, Johns Hopkins University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576873e1cf2f2b4d31a046c3_AasthaJain.jpg'}
# 17
# {'name': 'Yan Yang', 'title': 'Data Engineer', 'company': 'Microsoft Yammer', 'project': 'Stock Volatility PredictorÂ\xa0', 'background': 'Computational &amp; Mathematical Engineering, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769819041db86a74ee10ddb_YanYang.jpg'}
# 18
# {'name': 'Puneeth Kalavase', 'title': 'Algorithm Developer', 'company': 'PlotWatt', 'project': 'Lower Your Electricity Bill', 'background': 'Environmental Energy, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576879b7bc51c12e173d60f6_PuneethKalavase.jpg'}
# 19
# {'name': 'Efraim Feinstein', 'title': 'Data Scientist', 'company': 'Level Up Analytics', 'project': 'Find the Expert on Stack Overflow', 'background': 'Computational Biophysics, Harvard University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57687a939c47002117a7b562_EfraimFeinstein.jpg'}
# 20
# {'name': 'Joe Gallagher', 'title': 'Data Lead', 'company': 'Reddit', 'project': 'RewindX: Rediscover Music From Your Youth', 'background': 'Computational Neuroscience, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576982c4e8628b5103c6dfc2_Joe-1318.jpg'}
# 21
# {'name': 'Justin Parella', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'HipHopper: Find The Musicians You Have Been Missing', 'background': 'Atmospheric Chemistry, Harvard, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b52922c61e32036328c6_justinp-main.jpg'}
# 22
# {'name': 'Andre Bach', 'title': 'Data Scientist', 'company': 'Uber', 'project': 'RouteAroundCrime: The Path Less MuggedÂ\xa0', 'background': 'Experimental Particle Physics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697e1622c61e320362d76c_andre_bach.jpg'}
# 23
# {'name': 'Keoki Seu', 'title': 'Data Engineer', 'company': 'Facebook', 'project': 'FlockThink: Twitter Search Engine For Instant Sentiment AnalysisÂ\xa0', 'background': 'Condensed Matter Physics,Â\xa0Lawrence Berkeley National Laboratory, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784167241bc74f670c14955_IMG_2403.JPG'}
# 24
# {'name': 'Prakhar Mehirotra', 'title': 'Quantitative Analytics Finance Lead', 'company': 'Uber', 'project': 'News Now: Scrapes the RSS feeds from popular news websites (CNN, FOX, etc.) in real time', 'background': 'Aeronautics, California Institute of Technology, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841a4041bc74f670c14996_prakhar.jpg'}
# 25
# {'name': 'Vincent Fusaro', 'title': 'Senior Software Engineer Technical Lead', 'company': 'InVitae', 'project': 'RxDiscovery: Mining the FDA&#x27;s adverse event database to identify common side-effects for drug-drug interactions', 'background': 'Clinical Translational Informatics, Harvard Medical School, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b3c2e8628b5103c72989_vincent_fusaro.jpg'}
# 26
# {'name': 'Diane Wu', 'title': 'Founder', 'company': 'Trace Genomics ', 'project': 'BakeSearch: Stop Searching &amp; Start Baking', 'background': 'Genetics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819259c76751bb2c54a6cd_Diane%20Wu.jpg'}
# 27
# {'name': 'Giovanna Miritello', 'title': 'Data Scientist', 'company': 'Telefonica ', 'project': 'ReadTweetApp: The Tweets That Matter', 'background': 'Mathematical Engineering,Â\xa0University Carlos III of Madrid, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697bf56364789c4e58aa37_Giovanna.jpg'}
# 28
# {'name': 'Dominique Van de Sompel', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'TwinkedIn: Follow LinkedIn Contacts on TwitterÂ\xa0', 'background': 'Molecular Imaging, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697d2841db86a74ee102ad_Dominiquevds.jpg'}
# 29
# {'name': 'Colin Dillard', 'title': 'Data Scientist ', 'company': 'Level Up Analytics', 'project': 'CrimeVis: Visualization of Oakland Crime Rates', 'background': 'Physics, Harvard University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784191a137d7fea5500158e_colin.jpg'}
# 30
# {'name': 'Brian Boates', 'title': 'Data Science Lead', 'company': 'Square', 'project': 'SkillRankApp: What You Need to Know For Your Dream Job', 'background': 'Physics, Dalhousie University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576980d46364789c4e58b392_BrianBoates.jpg'}
# 31
# {'name': 'Adrian Kuhn', 'title': 'Data Engineer', 'company': 'Facebook', 'project': 'SerendipityEngineApp: Your Personal Travel Assistant', 'background': 'Computer Science, University of British Columbia, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784186c41bc74f670c14987_adrian.jpg'}
# 32
# {'name': 'George Lewis', 'title': 'Head of Risk &amp; Analytics', 'company': 'LendUp', 'project': 'Barkov Chain: Bar &amp; Restaurant Recommendation Engine', 'background': 'Experimental Particle Physics, New York University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5768735fdf388b30315c6901_george.jpg'}
# 33
# {'name': 'Berian James', 'title': 'Data Scientist', 'company': 'Square', 'project': 'Predicting Startup Outcomes on Crunchbase. Silicon Valley, Summer 2012', 'background': 'Astrophysics, UC Berkeley,Â\xa0Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b90b6364789c4e592e86_Berian-Pic.jpg'}
# 34
# {'name': 'David Lopes Pegna', 'title': 'Director of Data Science', 'company': 'Vectra', 'project': 'MyFacebookDigest: What You Have Missed on Facebook?Â\xa0', 'background': 'Particle Physics, Princeton, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841ed774ffc3cf55314118_David%20Lopez.jpg'}
# 35
# {'name': 'Christina Whittle', 'title': 'Staff, Business Analytics', 'company': 'NerdWallet', 'project': 'Neighbor Flavor', 'background': 'Genomics, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819216f8b83e5b135cd5c8_Christina%20Whittle.jpg'}
# 36
# {'name': 'Megan Cartwright', 'title': 'Manager of Marketing Analytics &amp; Data Science', 'company': 'Eventbrite', 'project': 'Stay Connected: The People You Remember Not to Forget', 'background': 'Space Plasma Physics, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bd736364789c4e592e9b_megan-main.jpg'}
# 37
# {'name': 'Warren Mar', 'title': 'Data Scientist', 'company': 'BloomReach', 'project': 'FlixPixie: &quot;Automagically&quot; Sort Photos', 'background': 'Electrical Engineering, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bf81e8628b5103c74574_warrenmar.jpg'}
# 38
# {'name': 'Eric Zilli', 'title': 'Software Engineer', 'company': 'Facebook', 'project': 'Sandwichly: Make The Perfect Sandwich', 'background': 'Neuroscience, Boston University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784198e137d7fea55001593_ericz.jpg'}
# 39
# {'name': 'Lisa Qian', 'title': 'Data Science Manager', 'company': 'Airbnb', 'project': 'Yelp Personal: Personalized Yelp recommendations', 'background': 'Applied Physics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bf21e8628b5103c74573_LisaQian.jpg'}
# 40
# {'name': 'Krystal St. Julien', 'title': 'Operations Analyst', 'company': 'Facebook', 'project': 'GeoJobr: Finding a job in today&#x27;s economy', 'background': 'Biomedical Genetics, Biochemistry, and Organogenesis, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576972bf6364789c4e5893c5_Krystal.jpg'}
# 41
# {'name': 'Daniel Silverstein', 'title': 'Data Scientist', 'company': 'Microsoft Yammer', 'project': 'Dine-amic Food: Making food decisions easy using dynamic data', 'background': 'High Energy Physics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576882eecf2f2b4d31a0567f_Dan.jpg'}
# 42
# {'name': 'Matthew Folz', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'GameChooser: Intelligent viewing recommendations for NBA games,Â\xa0The University of British Columbia, PhD', 'background': 'Probability Theory and Stochastic Processes,Â\xa0', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b990e8628b5103c736e0_Matt-F.jpg'}
# 43
# {'name': 'Praveen Kundurthy', 'title': 'Data Scientist', 'company': 'Microsoft Yammer', 'project': 'Flop Buster: The box-office prediction app', 'background': 'Astronomy,Â\xa0University of Washington, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bc886364789c4e592e97_Praveen.jpg'}
# 44
# {'name': 'Lauren Porter', 'title': 'Senior Data Scientist', 'company': 'Snapdeal', 'project': 'Off the Beaten Path: Your personalized vacation planner', 'background': 'Theoretical and Computational Astrophysics, UC Santa Cruz, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576884239c47002117a7b8ac_Lauren.jpg'}
# 45
# {'name': 'Aaron Keys', 'title': 'Data Architect', 'company': 'Aiirbnb', 'project': 'Gener-Rec: Greed is not good (at least for recommendation engines)', 'background': 'Chemical Engineering, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769790f41db86a74ee0fa60_Aaron.jpg'}
# 46
# {'name': 'Kevin Schaeffer', 'title': 'Technical Lead', 'company': 'Facebook', 'project': 'NewsTweet: Discover what&#x27;s happening right now anywhere in the world', 'background': 'Theoretical High Energy Physics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bb2922c61e320363317b_KevinS.jpg'}
# 47
# {'name': 'Shih-Ho Cheng', 'title': 'Data Scientist', 'company': 'Airbnb', 'project': 'Less-Sketchy: An early fraud detection web-app for apartment classifieds', 'background': 'Computational Astro-particle Physics,Â\xa0The Pennsylvania State University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57687f01cf2f2b4d31a055c8_Shih-ho.jpg'}
# 48
# {'name': 'Xiaoying Xu', 'title': 'Data Scientist', 'company': 'Zillabyte', 'project': 'Job Link: Find and Connect with Potential New Careers', 'background': 'Astrophysics/Cosmology,Â\xa0Carnegie Mellon University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841aae74ffc3cf55312be1_Xiao.jpg'}
# 49
# {'name': 'Nicholas Tomko', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'Reddibility: Just the Q&#x27;s &amp; A&#x27;s, none of the BS', 'background': 'Artificial Intelligence - Evolutionary Computation,Â\xa0University of Sussex, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769be17e8628b5103c73cce_nicholas_tomko.jpg'}
# 50
# {'name': 'Mio Alter', 'title': 'Data Scientist', 'company': '6Sense', 'project': 'Flava: Find your Flava', 'background': 'Mathematics (Geometry/Topology), University of Texas at Austin, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57688532bc51c12e173d6ec2_Mio.jpg'}
# 51
# {'name': 'Wei Zhang', 'title': 'Data Scientist/Software Engineer', 'company': 'Walmart Labs', 'project': 'Startup Sniffer: Transform gut-driven to data-driven investmentÂ\xa0', 'background': 'Computer Science and Engineering, University of Notre Dame, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5781919a025cfc7613d5d159_Wei.jpg'}
# 52
# {'name': 'Jingjing Huang', 'title': 'Sr. Associate, Business Analytics', 'company': 'LinkedIn', 'project': 'NuTube: Classifying recent YouTube videosÂ\xa0', 'background': 'Mathematics/Electrical Engineering, California Institute of Technology, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57688265bc51c12e173d6ddf_Jingjing.jpg'}
# 53
# {'name': 'Joshua Lande', 'title': 'Senior Data Scientist', 'company': 'Twitter', 'project': 'ReviewSkimmer: Find what&#x27;s good or bad in a movie, before it&#x27;s too late!', 'background': 'Astrophysics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5768832dbc51c12e173d6e18_Josh.jpg'}
# 54
# {'name': 'Eli Bressert', 'title': 'Data Scientist ', 'company': 'Netflix', 'project': 'InspectorGit: Discover Github&#x27;s awesome repositories', 'background': 'Astrophysics, University of Exeter, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769733ce8628b5103c6b124_Eli.jpg'}
# 55
# {'name': 'Jenelle Bray', 'title': 'Manager, Security Data Science', 'company': 'LinkedIn', 'project': 'PlacePickr: Helping couples decide where to liveÂ\xa0', 'background': 'Computational Structural Biology &lt;br&gt; Stanford University &lt;br&gt; Postdoct', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696df86364789c4e588546_Jenelle2.jpg'}
# 56
# {'name': 'Shanshan Ding', 'title': 'Data Scientist ', 'company': 'Compass', 'project': 'Who&#x27;s On First: Predicting the outcomes of baseball&#x27;s batter-pitcher matchups', 'background': 'Mathematics, University of Pennsylvania, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769746041db86a74ee0f159_Shanshan.jpg'}
# 57
# {'name': 'Elizabeth Leicht', 'title': 'Data Engineer, Analytics', 'company': 'Facebook', 'project': 'DinnerDetente: Easing the strained relationship between healthy and delicious', 'background': 'Statistical Physics/Complex Systems, University of Oxford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769702522c61e320362c20d_Elizabeth2.jpg'}
# 58
# {'name': 'Chris Said', 'title': 'Data Scientist', 'company': 'Twitter', 'project': 'DealSpotter: Find rare deals on Craigslist... the easy way', 'background': 'Neuroscience, Princeton, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769758141db86a74ee0f1bb_ChrisS.jpg'}
# 59
# {'name': 'Steven Herrin', 'title': 'Software Engineer', 'company': '23andMe', 'project': 'ParkSafely: Bicycling in San Francisco? Park where theft is less likely', 'background': 'Experimental Neutrino Physics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769782f41db86a74ee0f658_Steve.jpg'}
# 60
# {'name': 'Aristotle Socrates', 'title': 'Senior Data Scientist', 'company': 'Juvo', 'project': 'Tweather: Current local weather tweets', 'background': 'Theoretical Astrophysics, Institute for Advanced Study, Princeton, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576968616364789c4e588031_Ari2.jpg'}
# 61
# {'name': 'Alexander Tronchin-James', 'title': 'Data Engineer', 'company': 'Facebook', 'project': 'BeerInsight: Recommending exploration of obscure craft beer', 'background': 'Engineering-Physics, UC San Diego, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696c5a6364789c4e588497_Alex.jpg'}
# 62
# {'name': 'Slater Stich', 'title': 'Data Scientist', 'company': 'Square', 'project': 'TopOfTheStack: Find Stack Overflow questions to answerÂ\xa0', 'background': 'Mathematics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696cd941db86a74ee0e405_Slater.jpg'}
# 63
# {'name': 'John Joo', 'title': 'Data Scientist Evangelist', 'company': 'Domino Data Lab', 'project': 'HypeControl: Identify bias in the news you readÂ\xa0', 'background': 'Applied Physics, Harvard, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696d5a22c61e320362bb60_JohnJ.jpg'}
# 64
# {'name': 'Kevin Wheeler', 'title': 'Data Engineer', 'company': 'Facebook', 'project': 'PredictMyLineup: A fantasy football lineup optimization engine', 'background': 'Materials Science/Engineering (Protein biophysics), Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841e0841bc74f670c14df0_Kevin%20Wheeler.jpg'}
# 65
# {'name': 'John McDonnell', 'title': 'Data Scientist', 'company': 'Stitch Fix', 'project': 'HotHoods: Forecasting neighborhood trends in housing prices', 'background': 'Cognitive Science, New York University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576984426364789c4e58b83b_JohnM2.jpg'}
# 66
# {'name': 'Cristian Figueroa', 'title': 'Data Engineer', 'company': 'Facebook', 'project': 'BargainMeal: Great deals on top rated dishesÂ\xa0', 'background': 'Operations Research, MIT, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819014f8b83e5b135cd5c5_Cristian.jpg'}
# 67
# {'name': 'Michael Kuhlen', 'title': 'Data Scientist', 'company': 'LendUp', 'project': 'Delay Me Not! Providing flight day predictions at ticket purchase time', 'background': 'Astronomy &amp; Astrophysics, UC Santa Cruz, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576973b622c61e320362c6ac_Mike.jpg'}
# 68
# {'name': 'Shu Liu', 'title': 'Data Engineer II', 'company': 'Microsoft Yammer', 'project': 'HummingBirds: Getting the latest news about trends on TwitterÂ\xa0', 'background': 'Computer Science, University of Notre Dame, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576974d2e8628b5103c6b452_Shu2.jpg'}
# 69
# {'name': 'Christopher Miller', 'title': 'Data Scientist ', 'company': 'Hipmunk', 'project': 'AmazonComparer: Short &amp; sweet product reviews', 'background': 'Physics, UC David, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818fb69c205dc62cd227d6_chrismiller.jpg'}
# 70
# {'name': 'Christopher Moody', 'title': 'Data Scientist', 'company': 'Stitch Fix', 'project': 'ThisPlusThat: Amazing conceptual searching with natural languageÂ\xa0', 'background': 'Physics, UC Santa Cruz, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5781907fc76751bb2c54a69b_ChrisMo.jpg'}
# 71
# {'name': 'Anna Szostek', 'title': 'Data Scientist / R&amp;D Engineer', 'company': 'Probayes', 'project': 'PopularNow: Get great content from Twitter NOW!', 'background': 'Astrophysics, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696a4522c61e320362ba09_Anna.jpg'}
# 72
# {'name': 'Matt Smith', 'title': 'Director of Product', 'company': 'Insight Data Science', 'project': 'DailyFaces: The people in today&#x27;s news.', 'background': 'Computational Protein Engineering, California Institute of Technology, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576afae8caca498c1ef32d5b_Matt%20Smith.jpg'}
# 73
# {'name': 'Ahmet Bakan', 'title': 'Data Scientist', 'company': 'Kabbage', 'project': 'EURoute.me: Make the most out of your Europe trip!Â\xa0', 'background': 'Computational Biology, University of Pittsburgh, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b2086364789c4e591c63_Ahmet%20Bakan.jpg'}
# 74
# {'name': 'Chris Farrell', 'title': 'Engineering Manager', 'company': 'Yelp', 'project': 'OldFaveNewPlace: Find restaurants in a new city similar to ones you like in a different city', 'background': 'Experimental Particle Physics, University of California, Los Angeles, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818f06025cfc7613d5d047_Chris%20Farrell.jpg'}
# 75
# {'name': 'Alan Wilson', 'title': 'Senior Data Scientist', 'company': 'Glassdoor', 'project': 'NewsSpectra: Find news at your level.Â\xa0', 'background': 'Particle Physics,Â\xa0University of Michigan, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696f2041db86a74ee0e809_Alan%20Wilson.jpg'}
# 76
# {'name': 'Bharat Kunduri', 'title': 'Data Scientist', 'company': 'rocQ', 'project': 'Git-A-Friend: Find friends/collaborators on Github', 'background': 'Space Physics, Virginia Tech, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5768867a9c47002117a7c0c7_Bharat%20Kunduri.jpg'}
# 77
# {'name': 'Matt Gibb', 'title': 'EDU Specialist', 'company': 'Affirm, Inc.', 'project': 'CrowdMinr: Make a great return on your investment with peer-to-peer lending', 'background': 'Computational Biology, University of Oxford, PhDÂ\xa0', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697aee6364789c4e58a62b_Matt%20Gibb.jpg'}
# 78
# {'name': 'Becky Tucker', 'title': 'Sr. Data Scientist', 'company': 'Netflix', 'project': 'OnLocation: How to see where your favorite movies were filmed.Â\xa0', 'background': 'Experimental Astrophysics, California Institute of Technology, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818d569c205dc62cd22745_Becky%20Tucker.jpg'}
# 79
# {'name': 'Saba Zuberi', 'title': 'Data Scientist', 'company': 'TaskRabbit', 'project': 'WhatGives: Predicting the funding success of Kiva loans.Â\xa0', 'background': 'Theoretical Particle Physics,Â\xa0Lawrence Berkeley National Lab, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818e19f8b83e5b135ccf58_Saba%20Zuberi.jpg'}
# 80
# {'name': 'AJ Ribeiro', 'title': 'Software Engineer', 'company': 'Uber', 'project': 'ForecastingTomatoes: Predict how your film will be received', 'background': 'Space Science, Virginia Tech, PhDÂ\xa0', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576afda3504913a71e826326_AJ%20Ribeiro.jpg'}
# 81
# {'name': 'Nhung Ho', 'title': 'Sr. Data Scientist', 'company': 'Intuit', 'project': 'Healthy-Me: Making health discovery easy', 'background': 'Observational Astrophysics, Yale, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818ea0025cfc7613d5c9db_Nhung%20Ho.jpg'}
# 82
# {'name': 'Cian Menzel-Jones', 'title': 'Manager of Data Science', 'company': 'Stitch Fix', 'project': 'LinkedInsight: Find the skills and connections that matter', 'background': 'Computational Atomic, Molecular and Optical Physics,Â\xa0The University of British Columbia, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576968ec6364789c4e58807d_Cian-Menzel-Jones.jpg'}
# 83
# {'name': 'Joy Rimchala', 'title': 'Data Scientist', 'company': 'Intuit', 'project': 'InvestWiser: Predicting series A crunch outcome.', 'background': 'Biological Engineering, Computation &amp; Neural Systems, MIT, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696b0941db86a74ee0e365_Joy-Rimchala.jpg'}
# 84
# {'name': 'Jun Yan', 'title': 'Senior Data Scientist', 'company': 'AT&amp;T', 'project': 'NewsLine: Automated timeline that provides you context of news topics.', 'background': 'Chemical Engineering, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696f556364789c4e588ded_Jun%20Yan.jpg'}
# 85
# {'name': 'Ricardo Pinho', 'title': 'Data Scientist', 'company': 'Grand Rounds', 'project': 'Happy.li: Helping couples decide where to work and live together... and live happily ever after', 'background': 'Computational Biology/Physics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697a8a6364789c4e58a625_Ricardo-Pinho.jpg'}
# 86
# {'name': 'Daniel Perez-Becker ', 'title': 'Data Scientist', 'company': 'Microsoft Yammer', 'project': 'FareBeast: On the prowl for the lowest airfares', 'background': 'Theoretical Astrophysics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697abb6364789c4e58a628_Daniel%20Perez-Becker.jpg'}
# 87
# {'name': 'Lauren Nicolaisen', 'title': 'Data Scientist', 'company': 'Khan Academy', 'project': 'PickYourFiction: Find a book you&#x27;ll love!', 'background': 'Physics (Theoretical Population Genetics), Harvard, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769838ee8628b5103c6dfca_Lauren-Nicolaisen.jpg'}
# 88
# {'name': 'Natalie Han', 'title': 'Manager of Data Science, Business Analytics', 'company': 'LinkedIn', 'project': 'DJ-Cloud: Discover popular music albums with cloud computing', 'background': 'Medical Image Analysis, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bbd26364789c4e592e95_Natalie%20Han.jpg'}
# 89
# {'name': 'Allen Sussman', 'title': 'Data Scientist Engineer', 'company': 'Sojern', 'project': 'Two-lu: Movie recommendations for two!Â\xa0', 'background': 'Experimental Condensed Matter Physics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818b40c76751bb2c54a57e_Allen%20Sussman.jpg'}
# 90
# {'name': 'Jeff Seifried', 'title': 'Software Engineer - Data-Mining', 'company': 'Yelp', 'project': 'dogWalkScore: Find the neighborhood for you and your dog.Â\xa0', 'background': 'Nuclear Engineering, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818dc4f8b83e5b135ccf57_Jeff%20Seifried.jpg'}
# 91
# {'name': 'Shelly Jang', 'title': 'Data Scientist', 'company': 'Athos', 'project': 'BeeHealthy: Join the hive, get healthy!Â\xa0', 'background': 'Synthetic Biology, University of Washington, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5764488de4cff9a81929e317_Shelly-Jang.jpg'}
# 92
# {'name': 'Javiera Guedes', 'title': 'Data Scientist', 'company': 'Teralytics', 'project': '$trategy: Get notifications on when to buy/sell a stock.', 'background': 'Computational Astrophysics, ETH Zurich, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818f47c76751bb2c54a699_Javiera%20Guedes.jpg'}
# 93
# {'name': 'Mike Grinolds', 'title': 'Technical Lead and Staff Engineer for Data Products', 'company': 'SalesforceIQ', 'project': 'KickFinder: Kickstart the perfect project', 'background': 'Experimental physics, Harvard, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576b0146504913a71e827654_Mike%20Grinolds.jpg'}
# 94
# {'name': 'Adel Dayarian', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'RelaxedParking: Parking assistant to avoid traffic tickets and car-related crimes', 'background': 'Computational Biology and Biophysics, Kavli Institute for Theoretical Physics, UC Santa Barbara, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b2306364789c4e591c66_Adel%20Dayarian.jpg'}
# 95
# {'name': 'Burcu Baran', 'title': 'Senior Data Scientist, Business Analytics (Data Mining)', 'company': '6Sense Insights', 'project': 'GroupDine: Giving restaurant suggestions to a group of people based on their Instagram posts', 'background': 'Mathematics, Stanford/University of Michigan, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b2626364789c4e591c68_Burcu%20Baran.jpg'}
# 96
# {'name': 'Nancy Ru', 'title': 'Principal Programmer/Analyst', 'company': 'Sling Media', 'project': 'BurstingTheBubble: Recommending news articles from outside your bubble', 'background': 'Applied Physics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b288e8628b5103c72984_Nancy%20Ru.jpg'}
# 97
# {'name': 'Ahna Girshick', 'title': 'Head of Product', 'company': 'Enlitic', 'project': 'Wikiphilia: Scoring Wikipedia Page Quality', 'background': 'Vision Science &amp; Computer Science, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ace80b493c92d50f3eea2_Ahna-0306.jpg'}
# 98
# {'name': 'Heather Shapiro', 'title': 'Data Mining Engineer', 'company': 'Pebble', 'project': 'HealthImpact: Expediting medical care for those in need', 'background': 'Cognitive Neuroscience, UC Davis, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a7cae8628b5103c71fc4_Heather-0301.jpg'}
# 99
# {'name': 'Jesus Martinez', 'title': 'Data Scientist', 'company': 'Capital One', 'project': 'EdXPredictor: Predict your performance on edX courses', 'background': 'Astrophysics, University of Florida, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a5d041db86a74ee125aa_Jesus-0274.jpg'}

# %% [markdown]
# ## Storing data as json + Scraping multiple pages

# %%
import requests
from requests.exceptions import RequestException
import re
import json

from multiprocessing import Pool

# %%
def get_one_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
        return None
    except RequestException:
        return None
    
def parse_one_page(html):
    pattern = re.compile('tooltip_name">(.*?)</div>.*?'
                         + 'toottip_title">(.*?)</div>.*?'
                         + 'tooltip_company">(.*?)</div>.*?'
                         + 'tooltip_project">(.*?)</div>.*?'
                         + 'tooltip_background">(.*?)</div>.*?'
                         + '&quot;(.*?)&quot;'
                         ,re.S)
    
    items = re.findall(pattern, html)
    
    for item in items:
        yield{
            'name': item[0],
            'title': item[1],
            'company': item[2],
            'project': item[3],
            'background': item[4],
            'imagelink': item[5]
        }
        
def write_to_file(content):
    with open('./FellowInfo8Page_v1.json', 'a', encoding='utf-8') as f:
        f.write(json.dumps(content, ensure_ascii=False) + ',\n')
        f.close()
        
def get_content(offset):
    print('page_' + str(offset))
    url = 'https://www.insightdatascience.com/fellows?61ea5d1b_page=' + str(offset)
    html = get_one_page(url)
    for idx, item in enumerate(parse_one_page(html)):
        print(idx)
        print(item)
        datalist.append(item)
        write_to_file(item)

# %%
Insight = {}
Insight['fellows'] = []
datalist = Insight['fellows']
    
for i in range(1,9):
    get_content(i)
    
with open('./FellowInfo8Page_v2.txt', 'w', encoding='utf-8') as f:
    json.dump(Insight, f)
# Out:
# page_1
# 0
# {'name': 'JP Bida', 'title': 'Director of Risk', 'company': 'Capital One', 'project': 'Measuring the Impact of Open Source Coders on Github', 'background': 'Bio-X Games, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576976f76364789c4e58a0e8_JP-Pic.jpg'}
# 1
# {'name': 'Douglas Mason', 'title': 'Data Scientist', 'company': 'Twitter', 'project': 'Email Searcher: Search &amp; Visualize Your Mailbox', 'background': 'Physics, Harvard University,Â\xa0PhD\n', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697251e8628b5103c6b117_Doug-Pic.jpg'}
# 2
# {'name': 'Virot Ta Chiraphadhanakul', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'Tweet Timeline: Visualizing the Impact of Social Media', 'background': 'Operations Research, MIT, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769760f6364789c4e589ce7_Ta-Pic.jpg'}
# 3
# {'name': 'Julia Viladomat', 'title': 'Data Scientist', 'company': 'Adobe', 'project': 'Sentiment Analysis Based on Social Media', 'background': 'Statistics, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57685673bc51c12e173d3ba2_Julia%20Pic.jpg'}
# 4
# {'name': 'David Freeman', 'title': 'Head of Anti-Abuse Engineering', 'company': 'LinkedIn', 'project': 'Flight Delay Predictor', 'background': 'Mathematics, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b885e8628b5103c73621_davidfreeman-main.jpg'}
# 5
# {'name': 'Jessica ZÃºÃ±iga', 'title': 'Senior Data Scientist', 'company': 'LinkedIn', 'project': 'Email Contacts Automatically Grouped &amp; Ranked', 'background': 'Mathematics, Duke, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bb9322c61e320363317d_Jessica-Pic.jpg'}
# 6
# {'name': 'Harold Nguyen', 'title': 'Data Scientist', 'company': 'Proofpoint', 'project': 'Analysis of New York Stop-and-Frisk Data', 'background': 'Physics, UC Riverside, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576855b4df388b30315c45b0_Harold.jpg'}
# 7
# {'name': 'Sebastien de Larquier ', 'title': 'Data Scientist', 'company': 'Netflix', 'project': 'CouchTube: YouTube TV shows in one click', 'background': 'Space Physics, Virgina Tech, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ada79680f7412500914dd_Sebastien2.jpg'}
# 8
# {'name': 'Paula Therese Lang', 'title': 'Senior Data Scientist', 'company': 'CreativeLIVE', 'project': 'SchoolGeo: Empowering Parents to Make Informed Decisions', 'background': 'Computational Biology, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841d1e74ffc3cf55313410_terry.jpg'}
# 9
# {'name': 'Nan Ma', 'title': 'Data Engineer', 'company': 'Microsoft Yammer', 'project': 'Event Map: Get Local News from Twitter', 'background': 'Electrical Engineering &amp; Computer Science, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576971986364789c4e5893bf_NanMa.jpg'}
# 10
# {'name': 'Cinna Julie Wu', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'Sort My Friends: Automatically Organize your Connections', 'background': 'Applied Mathematics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57685e33cf2f2b4d31a02788_CinnaWu.jpg'}
# 11
# {'name': 'Erin Summers', 'title': 'Software Engineer', 'company': 'Facebook', 'project': 'Flat Finder: Find Your Perfect Apartment', 'background': 'Electrical Engineering &amp; Computer Science, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57687784cf2f2b4d31a04fc6_ErinSummers.png'}
# 12
# {'name': 'Leah McGuire', 'title': 'Senior Data Scientist', 'company': 'LinkedIn', 'project': 'Kiva Loan Checker', 'background': 'Computational Neuroscience, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697c4622c61e320362d58d_LeahMcGuire.jpg'}
# 13
# {'name': 'Nick Bunch', 'title': 'Quantitative Analyst', 'company': 'YouTube', 'project': 'Arrive in Time: Airport Arrival Time Predictor', 'background': 'Space Plasma Physics, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697f266364789c4e58b1f2_NickBunch.jpg'}
# 14
# {'name': 'Shelby Sturgis', 'title': 'Senior Data Visualization Engineer', 'company': 'Netflix', 'project': 'STARtrack: Helping Educators Track Student Performance', 'background': 'Biology, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769831e6364789c4e58b39d_ShelbySturgis.jpg'}
# 15
# {'name': 'Onkar Dalal', 'title': 'Data Scientist', 'company': 'LinkedIn', 'project': 'Diverse Recipe Recommendations', 'background': 'Computational &amp; Mathematical Engineering, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697fc541db86a74ee10ca7_Onkar.jpg'}
# 16
# {'name': 'Aastha Jain', 'title': 'Data Scientist', 'company': 'LinkedIn', 'project': 'Multi-Domain Recommendations', 'background': 'Computer Vision &amp; Image Processing, Johns Hopkins University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576873e1cf2f2b4d31a046c3_AasthaJain.jpg'}
# 17
# {'name': 'Yan Yang', 'title': 'Data Engineer', 'company': 'Microsoft Yammer', 'project': 'Stock Volatility PredictorÂ\xa0', 'background': 'Computational &amp; Mathematical Engineering, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769819041db86a74ee10ddb_YanYang.jpg'}
# 18
# {'name': 'Puneeth Kalavase', 'title': 'Algorithm Developer', 'company': 'PlotWatt', 'project': 'Lower Your Electricity Bill', 'background': 'Environmental Energy, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576879b7bc51c12e173d60f6_PuneethKalavase.jpg'}
# 19
# {'name': 'Efraim Feinstein', 'title': 'Data Scientist', 'company': 'Level Up Analytics', 'project': 'Find the Expert on Stack Overflow', 'background': 'Computational Biophysics, Harvard University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57687a939c47002117a7b562_EfraimFeinstein.jpg'}
# 20
# {'name': 'Joe Gallagher', 'title': 'Data Lead', 'company': 'Reddit', 'project': 'RewindX: Rediscover Music From Your Youth', 'background': 'Computational Neuroscience, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576982c4e8628b5103c6dfc2_Joe-1318.jpg'}
# 21
# {'name': 'Justin Parella', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'HipHopper: Find The Musicians You Have Been Missing', 'background': 'Atmospheric Chemistry, Harvard, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b52922c61e32036328c6_justinp-main.jpg'}
# 22
# {'name': 'Andre Bach', 'title': 'Data Scientist', 'company': 'Uber', 'project': 'RouteAroundCrime: The Path Less MuggedÂ\xa0', 'background': 'Experimental Particle Physics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697e1622c61e320362d76c_andre_bach.jpg'}
# 23
# {'name': 'Keoki Seu', 'title': 'Data Engineer', 'company': 'Facebook', 'project': 'FlockThink: Twitter Search Engine For Instant Sentiment AnalysisÂ\xa0', 'background': 'Condensed Matter Physics,Â\xa0Lawrence Berkeley National Laboratory, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784167241bc74f670c14955_IMG_2403.JPG'}
# 24
# {'name': 'Prakhar Mehirotra', 'title': 'Quantitative Analytics Finance Lead', 'company': 'Uber', 'project': 'News Now: Scrapes the RSS feeds from popular news websites (CNN, FOX, etc.) in real time', 'background': 'Aeronautics, California Institute of Technology, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841a4041bc74f670c14996_prakhar.jpg'}
# 25
# {'name': 'Vincent Fusaro', 'title': 'Senior Software Engineer Technical Lead', 'company': 'InVitae', 'project': 'RxDiscovery: Mining the FDA&#x27;s adverse event database to identify common side-effects for drug-drug interactions', 'background': 'Clinical Translational Informatics, Harvard Medical School, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b3c2e8628b5103c72989_vincent_fusaro.jpg'}
# 26
# {'name': 'Diane Wu', 'title': 'Founder', 'company': 'Trace Genomics ', 'project': 'BakeSearch: Stop Searching &amp; Start Baking', 'background': 'Genetics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819259c76751bb2c54a6cd_Diane%20Wu.jpg'}
# 27
# {'name': 'Giovanna Miritello', 'title': 'Data Scientist', 'company': 'Telefonica ', 'project': 'ReadTweetApp: The Tweets That Matter', 'background': 'Mathematical Engineering,Â\xa0University Carlos III of Madrid, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697bf56364789c4e58aa37_Giovanna.jpg'}
# 28
# {'name': 'Dominique Van de Sompel', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'TwinkedIn: Follow LinkedIn Contacts on TwitterÂ\xa0', 'background': 'Molecular Imaging, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697d2841db86a74ee102ad_Dominiquevds.jpg'}
# 29
# {'name': 'Colin Dillard', 'title': 'Data Scientist ', 'company': 'Level Up Analytics', 'project': 'CrimeVis: Visualization of Oakland Crime Rates', 'background': 'Physics, Harvard University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784191a137d7fea5500158e_colin.jpg'}
# 30
# {'name': 'Brian Boates', 'title': 'Data Science Lead', 'company': 'Square', 'project': 'SkillRankApp: What You Need to Know For Your Dream Job', 'background': 'Physics, Dalhousie University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576980d46364789c4e58b392_BrianBoates.jpg'}
# 31
# {'name': 'Adrian Kuhn', 'title': 'Data Engineer', 'company': 'Facebook', 'project': 'SerendipityEngineApp: Your Personal Travel Assistant', 'background': 'Computer Science, University of British Columbia, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784186c41bc74f670c14987_adrian.jpg'}
# 32
# {'name': 'George Lewis', 'title': 'Head of Risk &amp; Analytics', 'company': 'LendUp', 'project': 'Barkov Chain: Bar &amp; Restaurant Recommendation Engine', 'background': 'Experimental Particle Physics, New York University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5768735fdf388b30315c6901_george.jpg'}
# 33
# {'name': 'Berian James', 'title': 'Data Scientist', 'company': 'Square', 'project': 'Predicting Startup Outcomes on Crunchbase. Silicon Valley, Summer 2012', 'background': 'Astrophysics, UC Berkeley,Â\xa0Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b90b6364789c4e592e86_Berian-Pic.jpg'}
# 34
# {'name': 'David Lopes Pegna', 'title': 'Director of Data Science', 'company': 'Vectra', 'project': 'MyFacebookDigest: What You Have Missed on Facebook?Â\xa0', 'background': 'Particle Physics, Princeton, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841ed774ffc3cf55314118_David%20Lopez.jpg'}
# 35
# {'name': 'Christina Whittle', 'title': 'Staff, Business Analytics', 'company': 'NerdWallet', 'project': 'Neighbor Flavor', 'background': 'Genomics, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819216f8b83e5b135cd5c8_Christina%20Whittle.jpg'}
# 36
# {'name': 'Megan Cartwright', 'title': 'Manager of Marketing Analytics &amp; Data Science', 'company': 'Eventbrite', 'project': 'Stay Connected: The People You Remember Not to Forget', 'background': 'Space Plasma Physics, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bd736364789c4e592e9b_megan-main.jpg'}
# 37
# {'name': 'Warren Mar', 'title': 'Data Scientist', 'company': 'BloomReach', 'project': 'FlixPixie: &quot;Automagically&quot; Sort Photos', 'background': 'Electrical Engineering, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bf81e8628b5103c74574_warrenmar.jpg'}
# 38
# {'name': 'Eric Zilli', 'title': 'Software Engineer', 'company': 'Facebook', 'project': 'Sandwichly: Make The Perfect Sandwich', 'background': 'Neuroscience, Boston University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784198e137d7fea55001593_ericz.jpg'}
# 39
# {'name': 'Lisa Qian', 'title': 'Data Science Manager', 'company': 'Airbnb', 'project': 'Yelp Personal: Personalized Yelp recommendations', 'background': 'Applied Physics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bf21e8628b5103c74573_LisaQian.jpg'}
# 40
# {'name': 'Krystal St. Julien', 'title': 'Operations Analyst', 'company': 'Facebook', 'project': 'GeoJobr: Finding a job in today&#x27;s economy', 'background': 'Biomedical Genetics, Biochemistry, and Organogenesis, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576972bf6364789c4e5893c5_Krystal.jpg'}
# 41
# {'name': 'Daniel Silverstein', 'title': 'Data Scientist', 'company': 'Microsoft Yammer', 'project': 'Dine-amic Food: Making food decisions easy using dynamic data', 'background': 'High Energy Physics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576882eecf2f2b4d31a0567f_Dan.jpg'}
# 42
# {'name': 'Matthew Folz', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'GameChooser: Intelligent viewing recommendations for NBA games,Â\xa0The University of British Columbia, PhD', 'background': 'Probability Theory and Stochastic Processes,Â\xa0', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b990e8628b5103c736e0_Matt-F.jpg'}
# 43
# {'name': 'Praveen Kundurthy', 'title': 'Data Scientist', 'company': 'Microsoft Yammer', 'project': 'Flop Buster: The box-office prediction app', 'background': 'Astronomy,Â\xa0University of Washington, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bc886364789c4e592e97_Praveen.jpg'}
# 44
# {'name': 'Lauren Porter', 'title': 'Senior Data Scientist', 'company': 'Snapdeal', 'project': 'Off the Beaten Path: Your personalized vacation planner', 'background': 'Theoretical and Computational Astrophysics, UC Santa Cruz, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576884239c47002117a7b8ac_Lauren.jpg'}
# 45
# {'name': 'Aaron Keys', 'title': 'Data Architect', 'company': 'Aiirbnb', 'project': 'Gener-Rec: Greed is not good (at least for recommendation engines)', 'background': 'Chemical Engineering, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769790f41db86a74ee0fa60_Aaron.jpg'}
# 46
# {'name': 'Kevin Schaeffer', 'title': 'Technical Lead', 'company': 'Facebook', 'project': 'NewsTweet: Discover what&#x27;s happening right now anywhere in the world', 'background': 'Theoretical High Energy Physics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bb2922c61e320363317b_KevinS.jpg'}
# 47
# {'name': 'Shih-Ho Cheng', 'title': 'Data Scientist', 'company': 'Airbnb', 'project': 'Less-Sketchy: An early fraud detection web-app for apartment classifieds', 'background': 'Computational Astro-particle Physics,Â\xa0The Pennsylvania State University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57687f01cf2f2b4d31a055c8_Shih-ho.jpg'}
# 48
# {'name': 'Xiaoying Xu', 'title': 'Data Scientist', 'company': 'Zillabyte', 'project': 'Job Link: Find and Connect with Potential New Careers', 'background': 'Astrophysics/Cosmology,Â\xa0Carnegie Mellon University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841aae74ffc3cf55312be1_Xiao.jpg'}
# 49
# {'name': 'Nicholas Tomko', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'Reddibility: Just the Q&#x27;s &amp; A&#x27;s, none of the BS', 'background': 'Artificial Intelligence - Evolutionary Computation,Â\xa0University of Sussex, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769be17e8628b5103c73cce_nicholas_tomko.jpg'}
# 50
# {'name': 'Mio Alter', 'title': 'Data Scientist', 'company': '6Sense', 'project': 'Flava: Find your Flava', 'background': 'Mathematics (Geometry/Topology), University of Texas at Austin, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57688532bc51c12e173d6ec2_Mio.jpg'}
# 51
# {'name': 'Wei Zhang', 'title': 'Data Scientist/Software Engineer', 'company': 'Walmart Labs', 'project': 'Startup Sniffer: Transform gut-driven to data-driven investmentÂ\xa0', 'background': 'Computer Science and Engineering, University of Notre Dame, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5781919a025cfc7613d5d159_Wei.jpg'}
# 52
# {'name': 'Jingjing Huang', 'title': 'Sr. Associate, Business Analytics', 'company': 'LinkedIn', 'project': 'NuTube: Classifying recent YouTube videosÂ\xa0', 'background': 'Mathematics/Electrical Engineering, California Institute of Technology, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57688265bc51c12e173d6ddf_Jingjing.jpg'}
# 53
# {'name': 'Joshua Lande', 'title': 'Senior Data Scientist', 'company': 'Twitter', 'project': 'ReviewSkimmer: Find what&#x27;s good or bad in a movie, before it&#x27;s too late!', 'background': 'Astrophysics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5768832dbc51c12e173d6e18_Josh.jpg'}
# 54
# {'name': 'Eli Bressert', 'title': 'Data Scientist ', 'company': 'Netflix', 'project': 'InspectorGit: Discover Github&#x27;s awesome repositories', 'background': 'Astrophysics, University of Exeter, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769733ce8628b5103c6b124_Eli.jpg'}
# 55
# {'name': 'Jenelle Bray', 'title': 'Manager, Security Data Science', 'company': 'LinkedIn', 'project': 'PlacePickr: Helping couples decide where to liveÂ\xa0', 'background': 'Computational Structural Biology &lt;br&gt; Stanford University &lt;br&gt; Postdoct', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696df86364789c4e588546_Jenelle2.jpg'}
# 56
# {'name': 'Shanshan Ding', 'title': 'Data Scientist ', 'company': 'Compass', 'project': 'Who&#x27;s On First: Predicting the outcomes of baseball&#x27;s batter-pitcher matchups', 'background': 'Mathematics, University of Pennsylvania, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769746041db86a74ee0f159_Shanshan.jpg'}
# 57
# {'name': 'Elizabeth Leicht', 'title': 'Data Engineer, Analytics', 'company': 'Facebook', 'project': 'DinnerDetente: Easing the strained relationship between healthy and delicious', 'background': 'Statistical Physics/Complex Systems, University of Oxford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769702522c61e320362c20d_Elizabeth2.jpg'}
# 58
# {'name': 'Chris Said', 'title': 'Data Scientist', 'company': 'Twitter', 'project': 'DealSpotter: Find rare deals on Craigslist... the easy way', 'background': 'Neuroscience, Princeton, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769758141db86a74ee0f1bb_ChrisS.jpg'}
# 59
# {'name': 'Steven Herrin', 'title': 'Software Engineer', 'company': '23andMe', 'project': 'ParkSafely: Bicycling in San Francisco? Park where theft is less likely', 'background': 'Experimental Neutrino Physics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769782f41db86a74ee0f658_Steve.jpg'}
# 60
# {'name': 'Aristotle Socrates', 'title': 'Senior Data Scientist', 'company': 'Juvo', 'project': 'Tweather: Current local weather tweets', 'background': 'Theoretical Astrophysics, Institute for Advanced Study, Princeton, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576968616364789c4e588031_Ari2.jpg'}
# 61
# {'name': 'Alexander Tronchin-James', 'title': 'Data Engineer', 'company': 'Facebook', 'project': 'BeerInsight: Recommending exploration of obscure craft beer', 'background': 'Engineering-Physics, UC San Diego, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696c5a6364789c4e588497_Alex.jpg'}
# 62
# {'name': 'Slater Stich', 'title': 'Data Scientist', 'company': 'Square', 'project': 'TopOfTheStack: Find Stack Overflow questions to answerÂ\xa0', 'background': 'Mathematics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696cd941db86a74ee0e405_Slater.jpg'}
# 63
# {'name': 'John Joo', 'title': 'Data Scientist Evangelist', 'company': 'Domino Data Lab', 'project': 'HypeControl: Identify bias in the news you readÂ\xa0', 'background': 'Applied Physics, Harvard, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696d5a22c61e320362bb60_JohnJ.jpg'}
# 64
# {'name': 'Kevin Wheeler', 'title': 'Data Engineer', 'company': 'Facebook', 'project': 'PredictMyLineup: A fantasy football lineup optimization engine', 'background': 'Materials Science/Engineering (Protein biophysics), Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841e0841bc74f670c14df0_Kevin%20Wheeler.jpg'}
# 65
# {'name': 'John McDonnell', 'title': 'Data Scientist', 'company': 'Stitch Fix', 'project': 'HotHoods: Forecasting neighborhood trends in housing prices', 'background': 'Cognitive Science, New York University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576984426364789c4e58b83b_JohnM2.jpg'}
# 66
# {'name': 'Cristian Figueroa', 'title': 'Data Engineer', 'company': 'Facebook', 'project': 'BargainMeal: Great deals on top rated dishesÂ\xa0', 'background': 'Operations Research, MIT, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819014f8b83e5b135cd5c5_Cristian.jpg'}
# 67
# {'name': 'Michael Kuhlen', 'title': 'Data Scientist', 'company': 'LendUp', 'project': 'Delay Me Not! Providing flight day predictions at ticket purchase time', 'background': 'Astronomy &amp; Astrophysics, UC Santa Cruz, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576973b622c61e320362c6ac_Mike.jpg'}
# 68
# {'name': 'Shu Liu', 'title': 'Data Engineer II', 'company': 'Microsoft Yammer', 'project': 'HummingBirds: Getting the latest news about trends on TwitterÂ\xa0', 'background': 'Computer Science, University of Notre Dame, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576974d2e8628b5103c6b452_Shu2.jpg'}
# 69
# {'name': 'Christopher Miller', 'title': 'Data Scientist ', 'company': 'Hipmunk', 'project': 'AmazonComparer: Short &amp; sweet product reviews', 'background': 'Physics, UC David, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818fb69c205dc62cd227d6_chrismiller.jpg'}
# 70
# {'name': 'Christopher Moody', 'title': 'Data Scientist', 'company': 'Stitch Fix', 'project': 'ThisPlusThat: Amazing conceptual searching with natural languageÂ\xa0', 'background': 'Physics, UC Santa Cruz, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5781907fc76751bb2c54a69b_ChrisMo.jpg'}
# 71
# {'name': 'Anna Szostek', 'title': 'Data Scientist / R&amp;D Engineer', 'company': 'Probayes', 'project': 'PopularNow: Get great content from Twitter NOW!', 'background': 'Astrophysics, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696a4522c61e320362ba09_Anna.jpg'}
# 72
# {'name': 'Matt Smith', 'title': 'Director of Product', 'company': 'Insight Data Science', 'project': 'DailyFaces: The people in today&#x27;s news.', 'background': 'Computational Protein Engineering, California Institute of Technology, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576afae8caca498c1ef32d5b_Matt%20Smith.jpg'}
# 73
# {'name': 'Ahmet Bakan', 'title': 'Data Scientist', 'company': 'Kabbage', 'project': 'EURoute.me: Make the most out of your Europe trip!Â\xa0', 'background': 'Computational Biology, University of Pittsburgh, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b2086364789c4e591c63_Ahmet%20Bakan.jpg'}
# 74
# {'name': 'Chris Farrell', 'title': 'Engineering Manager', 'company': 'Yelp', 'project': 'OldFaveNewPlace: Find restaurants in a new city similar to ones you like in a different city', 'background': 'Experimental Particle Physics, University of California, Los Angeles, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818f06025cfc7613d5d047_Chris%20Farrell.jpg'}
# 75
# {'name': 'Alan Wilson', 'title': 'Senior Data Scientist', 'company': 'Glassdoor', 'project': 'NewsSpectra: Find news at your level.Â\xa0', 'background': 'Particle Physics,Â\xa0University of Michigan, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696f2041db86a74ee0e809_Alan%20Wilson.jpg'}
# 76
# {'name': 'Bharat Kunduri', 'title': 'Data Scientist', 'company': 'rocQ', 'project': 'Git-A-Friend: Find friends/collaborators on Github', 'background': 'Space Physics, Virginia Tech, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5768867a9c47002117a7c0c7_Bharat%20Kunduri.jpg'}
# 77
# {'name': 'Matt Gibb', 'title': 'EDU Specialist', 'company': 'Affirm, Inc.', 'project': 'CrowdMinr: Make a great return on your investment with peer-to-peer lending', 'background': 'Computational Biology, University of Oxford, PhDÂ\xa0', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697aee6364789c4e58a62b_Matt%20Gibb.jpg'}
# 78
# {'name': 'Becky Tucker', 'title': 'Sr. Data Scientist', 'company': 'Netflix', 'project': 'OnLocation: How to see where your favorite movies were filmed.Â\xa0', 'background': 'Experimental Astrophysics, California Institute of Technology, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818d569c205dc62cd22745_Becky%20Tucker.jpg'}
# 79
# {'name': 'Saba Zuberi', 'title': 'Data Scientist', 'company': 'TaskRabbit', 'project': 'WhatGives: Predicting the funding success of Kiva loans.Â\xa0', 'background': 'Theoretical Particle Physics,Â\xa0Lawrence Berkeley National Lab, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818e19f8b83e5b135ccf58_Saba%20Zuberi.jpg'}
# 80
# {'name': 'AJ Ribeiro', 'title': 'Software Engineer', 'company': 'Uber', 'project': 'ForecastingTomatoes: Predict how your film will be received', 'background': 'Space Science, Virginia Tech, PhDÂ\xa0', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576afda3504913a71e826326_AJ%20Ribeiro.jpg'}
# 81
# {'name': 'Nhung Ho', 'title': 'Sr. Data Scientist', 'company': 'Intuit', 'project': 'Healthy-Me: Making health discovery easy', 'background': 'Observational Astrophysics, Yale, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818ea0025cfc7613d5c9db_Nhung%20Ho.jpg'}
# 82
# {'name': 'Cian Menzel-Jones', 'title': 'Manager of Data Science', 'company': 'Stitch Fix', 'project': 'LinkedInsight: Find the skills and connections that matter', 'background': 'Computational Atomic, Molecular and Optical Physics,Â\xa0The University of British Columbia, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576968ec6364789c4e58807d_Cian-Menzel-Jones.jpg'}
# 83
# {'name': 'Joy Rimchala', 'title': 'Data Scientist', 'company': 'Intuit', 'project': 'InvestWiser: Predicting series A crunch outcome.', 'background': 'Biological Engineering, Computation &amp; Neural Systems, MIT, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696b0941db86a74ee0e365_Joy-Rimchala.jpg'}
# 84
# {'name': 'Jun Yan', 'title': 'Senior Data Scientist', 'company': 'AT&amp;T', 'project': 'NewsLine: Automated timeline that provides you context of news topics.', 'background': 'Chemical Engineering, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696f556364789c4e588ded_Jun%20Yan.jpg'}
# 85
# {'name': 'Ricardo Pinho', 'title': 'Data Scientist', 'company': 'Grand Rounds', 'project': 'Happy.li: Helping couples decide where to work and live together... and live happily ever after', 'background': 'Computational Biology/Physics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697a8a6364789c4e58a625_Ricardo-Pinho.jpg'}
# 86
# {'name': 'Daniel Perez-Becker ', 'title': 'Data Scientist', 'company': 'Microsoft Yammer', 'project': 'FareBeast: On the prowl for the lowest airfares', 'background': 'Theoretical Astrophysics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697abb6364789c4e58a628_Daniel%20Perez-Becker.jpg'}
# 87
# {'name': 'Lauren Nicolaisen', 'title': 'Data Scientist', 'company': 'Khan Academy', 'project': 'PickYourFiction: Find a book you&#x27;ll love!', 'background': 'Physics (Theoretical Population Genetics), Harvard, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769838ee8628b5103c6dfca_Lauren-Nicolaisen.jpg'}
# 88
# {'name': 'Natalie Han', 'title': 'Manager of Data Science, Business Analytics', 'company': 'LinkedIn', 'project': 'DJ-Cloud: Discover popular music albums with cloud computing', 'background': 'Medical Image Analysis, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bbd26364789c4e592e95_Natalie%20Han.jpg'}
# 89
# {'name': 'Allen Sussman', 'title': 'Data Scientist Engineer', 'company': 'Sojern', 'project': 'Two-lu: Movie recommendations for two!Â\xa0', 'background': 'Experimental Condensed Matter Physics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818b40c76751bb2c54a57e_Allen%20Sussman.jpg'}
# 90
# {'name': 'Jeff Seifried', 'title': 'Software Engineer - Data-Mining', 'company': 'Yelp', 'project': 'dogWalkScore: Find the neighborhood for you and your dog.Â\xa0', 'background': 'Nuclear Engineering, UC Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818dc4f8b83e5b135ccf57_Jeff%20Seifried.jpg'}
# 91
# {'name': 'Shelly Jang', 'title': 'Data Scientist', 'company': 'Athos', 'project': 'BeeHealthy: Join the hive, get healthy!Â\xa0', 'background': 'Synthetic Biology, University of Washington, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5764488de4cff9a81929e317_Shelly-Jang.jpg'}
# 92
# {'name': 'Javiera Guedes', 'title': 'Data Scientist', 'company': 'Teralytics', 'project': '$trategy: Get notifications on when to buy/sell a stock.', 'background': 'Computational Astrophysics, ETH Zurich, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818f47c76751bb2c54a699_Javiera%20Guedes.jpg'}
# 93
# {'name': 'Mike Grinolds', 'title': 'Technical Lead and Staff Engineer for Data Products', 'company': 'SalesforceIQ', 'project': 'KickFinder: Kickstart the perfect project', 'background': 'Experimental physics, Harvard, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576b0146504913a71e827654_Mike%20Grinolds.jpg'}
# 94
# {'name': 'Adel Dayarian', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'RelaxedParking: Parking assistant to avoid traffic tickets and car-related crimes', 'background': 'Computational Biology and Biophysics, Kavli Institute for Theoretical Physics, UC Santa Barbara, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b2306364789c4e591c66_Adel%20Dayarian.jpg'}
# 95
# {'name': 'Burcu Baran', 'title': 'Senior Data Scientist, Business Analytics (Data Mining)', 'company': '6Sense Insights', 'project': 'GroupDine: Giving restaurant suggestions to a group of people based on their Instagram posts', 'background': 'Mathematics, Stanford/University of Michigan, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b2626364789c4e591c68_Burcu%20Baran.jpg'}
# 96
# {'name': 'Nancy Ru', 'title': 'Principal Programmer/Analyst', 'company': 'Sling Media', 'project': 'BurstingTheBubble: Recommending news articles from outside your bubble', 'background': 'Applied Physics, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b288e8628b5103c72984_Nancy%20Ru.jpg'}
# 97
# {'name': 'Ahna Girshick', 'title': 'Head of Product', 'company': 'Enlitic', 'project': 'Wikiphilia: Scoring Wikipedia Page Quality', 'background': 'Vision Science &amp; Computer Science, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ace80b493c92d50f3eea2_Ahna-0306.jpg'}
# 98
# {'name': 'Heather Shapiro', 'title': 'Data Mining Engineer', 'company': 'Pebble', 'project': 'HealthImpact: Expediting medical care for those in need', 'background': 'Cognitive Neuroscience, UC Davis, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a7cae8628b5103c71fc4_Heather-0301.jpg'}
# 99
# {'name': 'Jesus Martinez', 'title': 'Data Scientist', 'company': 'Capital One', 'project': 'EdXPredictor: Predict your performance on edX courses', 'background': 'Astrophysics, University of Florida, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a5d041db86a74ee125aa_Jesus-0274.jpg'}
# page_2
# 0
# {'name': 'Matt George', 'title': 'Data Scientist', 'company': 'Square', 'project': 'StreetsAhead: Image recognition with deep learning in Street View', 'background': 'Astrophysics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769ae8f6364789c4e5919c5_Matt-0288.jpg'}
# 1
# {'name': 'Carlos Cunha', 'title': 'Senior Data Scientist', 'company': 'Bosch', 'project': 'Jaunt: Recommendations along the way!', 'background': 'Cosmology and Astrophysics, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769af69e8628b5103c72979_Carlos-0332.jpg'}
# 2
# {'name': 'Adam Morgan', 'title': 'Lead Data Scientist', 'company': 'Target', 'project': 'CharityVerity: Predicting charity ratings to guide effective altruism', 'background': 'Astrophysics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819415c76751bb2c54a6cf_adammorgan.jpg'}
# 3
# {'name': 'Wafa Soofi', 'title': 'Data Scientist', 'company': 'Square', 'project': 'CrowdSkippr: Minimize crowds, maximize joy', 'background': 'Biomedical Engineering/ Computational Neuroscience, Georgia Institute of Technology/Emory University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769c978e8628b5103c75259_Wafa-0963.jpg'}
# 4
# {'name': 'David Paulsen', 'title': 'Director of Data and Analytics', 'company': 'Prosper', 'project': 'RxFX: Prescription Drug Recommendations &amp; Side Effect Discovery', 'background': 'Cognitive Neuroscience, University of Pittsburgh, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a4f7e8628b5103c71591_David-0327-2.jpg'}
# 5
# {'name': 'Nicholas Peterson', 'title': 'Data Scientist', 'company': 'Electronic Arts', 'project': 'Math.StackExpert: Finding you high-quality questions on Math', 'background': 'Mathematics, The Ohio State University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769ac5822c61e32036319f5_Nicholas-0280.jpg'}
# 6
# {'name': 'Vanessa Heckman', 'title': 'Data Mining Scientist', 'company': 'Apple', 'project': 'Lenderstanding: Helping lenders help', 'background': 'Civil Engineering, Geophysics, Caltech/California Institute of Technology', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769ca2b22c61e3203633335_Vanessa-0222.jpg'}
# 7
# {'name': 'Aparupa Das Gupta', 'title': 'Data Scientist', 'company': 'Cisco', 'project': 'Price Wizard: Recommends the highest price to post on Craigslist for selling furniture items', 'background': 'Operations Research, UCLA, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad06930d4453860317966_Aparupa-0226.jpg'}
# 8
# {'name': 'Kevin Teh', 'title': 'Data Scientist / Software Engineer', 'company': 'Opendoor Labs', 'project': 'Cluster-Pluck: Disambiguating Twitter Search', 'background': 'Mathematics, Caltech, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/578194769c205dc62cd234c1_kevinteh.jpg'}
# 9
# {'name': 'Zack Chadick', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'Steal-This-House!: Crime doesn&#x27;t pay...&#x27;cept for your bottom line!', 'background': 'Systems Neuroscience, UCSF, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769cb3f22c61e320363333c_ZackC.jpg'}
# 10
# {'name': 'Kevin Ford', 'title': 'Data Scientist', 'company': 'Counsyl', 'project': 'TapMapper: Find out what the locals are drinking/tweeting', 'background': 'Biophysics/Neuroscience, UCSF, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697b5b6364789c4e58a62e_Kevin-0292.jpg'}
# 11
# {'name': 'Kelty Allen', 'title': 'Data Scientist', 'company': 'Microsoft', 'project': 'AmazonExplorer.info: A deeper look into Amazon product review history', 'background': 'Mathematical Logic, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a8b641db86a74ee12f20_Kelty-0264.jpg'}
# 12
# {'name': 'Jason French', 'title': 'Data Scientist', 'company': 'Rise Interactive', 'project': 'Green Machine: Removing the barrier to solar energy estimation', 'background': 'Differential Psychology, Northwestern University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a63a41db86a74ee125af_Jason-0282.jpg'}
# 13
# {'name': 'Asif Imran', 'title': 'Tech Lead, Programmatic Optimization &amp; Fraud Prevention', 'company': 'AdRoll', 'project': 'git-discover: Unlock the potential of Github', 'background': 'High Energy Astrophysics, Wisconsin IceCube Particle Astrophysics Center, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a6bee8628b5103c715a0_Asif-0253.jpg'}
# 14
# {'name': 'Meredith Trotter', 'title': 'Data Scientist', 'company': 'Lumiata', 'project': 'Should I Kick or Should I Go?: Optimize your crowdfunding campaign', 'background': 'Biology: Evolutionary and Demographic Theory, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769acdc6364789c4e5919ba_Meredith-0193.jpg'}
# 15
# {'name': 'Nicholas Tilmans', 'title': 'Data Scientist', 'company': 'Lumiata', 'project': 'DrugScope: Scope out your medicine before taking it!', 'background': 'Biochemistry, Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769ad5322c61e32036319fc_Nicolas-0234.jpg'}
# 16
# {'name': 'Christopher Klein', 'title': 'Siri Data Scientist', 'company': 'Apple', 'project': 'What&#x27;s for Dinner: Dinner recommendations to meet daily nutrition goals', 'background': 'Astronomy, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769adf922c61e32036319ff_Chris-0257.jpg'}
# 17
# {'name': 'Igor Bespamyatnov', 'title': 'Data Scientist ', 'company': 'Apple', 'project': 'AdNet: Graph recommender for news domains', 'background': 'Plasma Physics, University of Texas, Austin, PostdocÂ\xa0', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a57041db86a74ee125a9_Igor-0404.jpg'}
# 18
# {'name': 'Benoit Dherin', 'title': 'Watson Senior Software Engineer', 'company': 'IBM', 'project': 'GradeExpectation: Piazza forum analyzer', 'background': 'Mathematics and Statistics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769aef96364789c4e5919c9_Benoit-0199.jpg'}
# 19
# {'name': 'Monica Hsu', 'title': 'Data Scientist', 'company': 'Intuit', 'project': 'TruValuation: Predict the true value of your home', 'background': 'Biophysics, UCSF, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769afd9e8628b5103c7297a_Monica-0186.jpg'}
# 20
# {'name': 'Michael Woods', 'title': 'Software Engineer Data Mining', 'company': 'Yelp', 'project': 'MelodyMapr: Improving the road trip experience', 'background': 'Physics, UC Davis, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b0386364789c4e591ba6_Michael.Woods-0298.jpg'}
# 21
# {'name': 'Ravi Menon', 'title': 'Director of Data and Analytics', 'company': 'Brilliant.org', 'project': 'SearchPy: Search for related python code on Stack Overflow', 'background': 'Earth &amp; Ocean Sciences/Signal Processing, UCSD, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576b00a6caca498c1ef34253_Ravi-0402.jpg'}
# 22
# {'name': 'Meng (Ray) Gao', 'title': 'Sr. Data Scientist', 'company': 'Pilot AI Labs', 'project': 'UpFindr: Find the best activity partners on Meetup.com!', 'background': 'Â\xa0Physics, University of Toronto, PhDÂ\xa0', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b0a1e8628b5103c7297d_Ray-0240.jpg'}
# 23
# {'name': 'Nicole Romano', 'title': 'Data Scientist', 'company': 'RadiumOne', 'project': 'SetList: Set your life to music', 'background': 'Materials Engineering (Neural Regeneration), Stanford, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b0f322c61e320363227d_Nicole-0211.jpg'}
# 24
# {'name': 'Michael Ramm', 'title': 'Senior Data Scientist', 'company': 'Netflix', 'project': 'Hoppr: Optimize route for running errands', 'background': 'Physics, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b16741db86a74ee13193_Michael.Ramm--0198.jpg'}
# 25
# {'name': 'Sumin Tang', 'title': 'Ads Analytics', 'company': 'Facebook', 'project': 'LinkBooksMovies: Book recommendations if you like a certain movie', 'background': 'Astrophysics,Â\xa0Caltech/University of California, Santa Barbara, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576acf5eec69725360fc175b_Sumin-0260.jpg'}
# 26
# {'name': 'Vickie Zhang', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'VentureNetwork: Recommend high potential startups based on investor&#x27;s portfolio', 'background': 'Bioengineering, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576acfc2680f74125009020a_Vickie-0323.jpg'}
# 27
# {'name': 'Leifur Thorbergsson', 'title': 'Data Scientist', 'company': 'Memorial Sloan Kettering', 'project': 'FindMyPoem: Finding the poem that fits your mood and preference', 'background': 'Statistics, Cornell University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad24330d4453860317d96_Leifur.jpg'}
# 28
# {'name': 'Daniel Fernandez', 'title': 'Data Scientist', 'company': 'Encompass Capital', 'project': 'abstrART: Bringing price transparency to the art market', 'background': 'Statistics, Harvard, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576af3c6caca498c1ef31be6_DanielF.jpg'}
# 29
# {'name': 'Josh Ainsley', 'title': 'Director, Customer Intelligence &amp; Data Science', 'company': 'Coach', 'project': 'childHood: Finding a kid-friendly place to live', 'background': 'Neuroscience, Tufts University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad28130d4453860317d98_Joshua.jpg'}
# 30
# {'name': 'Robert Amanfu', 'title': 'Data Scientist', 'company': 'Capital One', 'project': 'CraigFlagr: Check flag potential of Craigslist posts', 'background': 'Biomedical Engineering, University of Virginia, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad216b493c92d50f3f0b4_RobertA.jpg'}
# 31
# {'name': 'Friederike Schueuer', 'title': 'Data Scientist', 'company': 'Fast Forward Labs', 'project': 'Drugged-up: Know what&#x27;s in your drugs and how that might make you feel', 'background': 'Cognitive Science, New York University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad169680f7412500902b2_Friederike.jpg'}
# 32
# {'name': 'Anita Schmid', 'title': 'Senior Data Scientist', 'company': 'Credit Suisse', 'project': 'Q-Schools: Learn English through Sign LanguageÂ\xa0', 'background': 'Systems Neuroscience, Weill Cornell Medical College, Faculty', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576af48bcaca498c1ef31bf9_Anita.jpg'}
# 33
# {'name': 'Andrew Zirm', 'title': 'Data Scientist', 'company': 'Greenhouse', 'project': 'nimi: Everyone has a name, your kid needs a great one!', 'background': 'Astrophysics, Niels Bohr Institute, Copenhagen University, FacultyÂ\xa0', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576af4571c81b68b70f3ee89_Andrew.jpg'}
# 34
# {'name': 'Divyanshu Vats', 'title': 'Quantitative Researcher', 'company': 'Two Sigma', 'project': 'cities4me: Discover cities based on your interests!', 'background': 'Machine Learning, Rice University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576af4151c81b68b70f3ee87_Divyanshu.jpg'}
# 35
# {'name': 'Yiping Yuan', 'title': 'Machine Learning Researcher', 'company': 'LinkedIn', 'project': 'Career Wizard: A career path recommender', 'background': 'Statistics, University of Minnesota, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad84330d44538603187af_Yiping.jpg'}
# 36
# {'name': 'Pouria Fewzee', 'title': 'Senior Data Scientist', 'company': 'Zoom.ai', 'project': 'HOSPARENCIE: Transparency in hospitalization fees', 'background': 'Electrical &amp; Computer Engineering, University of Waterloo, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576c8279a2b1564932b1112a_Pouria.jpg'}
# 37
# {'name': 'Genevieve Smith', 'title': 'Director of Product', 'company': 'Insight Data Science', 'project': 'Neutral_Opinion: Visualizing opinions on net neutrality', 'background': 'Ecology &amp; Evolution, The University of Texas at Austin, PostdocÂ\xa0', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576acef530d44538603174c0_Genevieve.jpg'}
# 38
# {'name': 'Ethan Geil', 'title': 'Technical Director, Big Data', 'company': 'BitSight', 'project': 'Rain: Real-time radar-based precipitation forecasting', 'background': 'Physics, Cornell University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad7ee680f741250091049_Ethan.jpg'}
# 39
# {'name': 'Brandon Kelly', 'title': 'Big Data Engineer/Analyst', 'company': 'Goodyear', 'project': 'The Flavory: An ingredient recommendation factory', 'background': 'Astrophysics, UCSB, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad79830d44538603187ae_Brandon.jpg'}
# 40
# {'name': 'Alex Ruiz-Euler', 'title': 'Senior Data Scientist, Audience Science', 'company': 'Viacom', 'project': 'Yelper Helper: An engine for tailored Yelp Reviews', 'background': 'Political Economy, UCSD, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad749ec69725360fc2348_AlexanderRuiz.jpg'}
# 41
# {'name': 'Yannan Zheng', 'title': 'Quantitative Researcher', 'company': 'Citadel', 'project': 'Customized running route recommendation system', 'background': 'Systems Biology, MIT, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad6eab493c92d50f3fb41_Yannan.jpg'}
# 42
# {'name': 'Courtney Epstein', 'title': 'Senior Data Scientist', 'company': 'ZocDoc', 'project': 'okmeeple: Don&#x27;t leave it to chance; find your perfect board game match', 'background': 'Astronomy, The Ohio State University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad008ec69725360fc1968_Courtney.jpg'}
# 43
# ...
# 47
# {'name': 'Fazel Anjomshoa ', 'title': 'Data Scientist ', 'company': 'DataXu', 'project': 'Start-up Secrets: Enhance decision-making to improve portfolio yields', 'background': 'Electrical and Computer Engineering, Clarkson University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea2a3489272e494f6592ed_Fazel3.jpg'}
# 48
# {'name': 'Andrew Chegwidden', 'title': 'Engineering Staff - Data Scientist', 'company': 'Goodyear Tire and Rubber Company', 'project': 'AutoPrice: What the vehicle will REALLY cost you', 'background': 'Particle Physics, Michigan State University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5ab93dd2de71f3e68fe70d71_Andrew_Chegwidden.jpg'}
# 49
# {'name': 'Antonio Ordonez', 'title': 'Data Scientist', 'company': 'Apple', 'project': 'MatchTheVote: Matching advocacy group members with voters using machine learning', 'background': 'Astronomy, NASA Frontier Development Lab, Ph.D.', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5ab93eb6440d641859662214_Antonio_Ordonez.jpg'}
# 50
# {'name': 'Denis Voytenko', 'title': 'Senior Data Scientist', 'company': 'Nielsen', 'project': 'FareHarrier: Predicting NYC subway wait times so taxi drivers get more business ', 'background': 'Geophysics, New York University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5ab93f27440d64999d662226_denis_voytenko_headshot.jpg'}
# 51
# {'name': 'Louis Antonelli', 'title': 'Data Scientist', 'company': 'Vizient', 'project': 'SilverTongue: Helping you nail that next big presentation', 'background': 'Experimental Particle Physics, The Ohio State University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5ab94019b07e8222cfd31fc0_Jamie%20Antonelli%20headshot.jpg'}
# 52
# {'name': 'Patrick Long', 'title': 'Data Scientist', 'company': 'IQVIA', 'project': 'enCard: Predicting credit card transaction failures', 'background': 'Neuroscience, University of Michigan, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5abb8d58de71f34d6de73e42_Patrick_Long.jpg'}
# 53
# {'name': 'Peter Tsai', 'title': 'Data Engineer', 'company': 'MOCAP Analytics', 'project': 'NBATicketSavant: Buy tickets without regret!', 'background': 'Materials Science &amp; Engineering, Washington University in St. Louis, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5abb8dcb4c436c39f25132a0_Peter_Tsai_%20Headshot.jpg'}
# 54
# {'name': 'Sean Tauber', 'title': 'Senior Analytics Software Developer ', 'company': 'Boston Consulting Group', 'project': 'DishSTARS: The best dishes and where to get them', 'background': 'Cognitive Science, University of New South Wales, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5abb8e2c440d6472ae6652d1_Sean_Tauber_Headshot.jpg'}
# 55
# {'name': 'Wesley Clark', 'title': 'Data Scientist', 'company': 'Goodyear Tire and Rubber Company', 'project': 'Panoptica: Gaining Insight into and Predicting Youtube Audience Demographics', 'background': 'Biochemistry and Bioinformatics, University of Chicago, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5abb8e99a291289de7e406ff_Wesley%20Clark.jpg'}
# 56
# {'name': 'Elahe Farahzadeh', 'title': 'Data Scientist', 'company': 'IBM', 'project': 'EscapeDisaster: Travel to the right place at the right time', 'background': 'Computer Vision, University of North Carolina at Chapel Hill, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5abbfb1c7eb5a76373dfc3f2_Ella.jpg'}
# 57
# {'name': 'Lisa Rayle', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'NexIQ: Improving flight search for busy travelers', 'background': 'City &amp; Regional Planning, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a9f129f09700016fd859_Lisa%20Rayle.jpg'}
# 58
# {'name': 'Tahlia DeMaio', 'title': 'Data Scientist', 'company': 'Second Measure', 'project': 'Finding Who FLEX Fits: Refining target demographics for The FLEX Company', 'background': 'Astronomy, University of Florida, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61ac0ea7da9e000103d90b_Tahlia%20DeMaio.jpg'}
# 59
# {'name': 'Chandra Natarajan', 'title': 'Data Scientist', 'company': 'C3 IoT', 'project': 'VerifyDocs: Keep it confidential', 'background': 'Applied Physics, University of Glasgow, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a707cef26c00010d6f4b_Chandra%20Natarajan.jpg'}
# 60
# {'name': 'Claire Kunesh', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'Babble: Language detection with half a second of sound', 'background': 'Human Cognition and Development, UC Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a77199f89b0001b53073_Claire%20Kunesh.jpg'}
# 61
# {'name': 'Di Mo', 'title': 'Data Scientist', 'company': 'LinkedIn', 'project': 'Startup Telescope: Future is now', 'background': 'Economics, Stanford University, Research Associate', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a807a7da9e000103d8af_Di%20Mo.jpg'}
# 62
# {'name': 'Michael Bellato', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'RateMate: Bias estimator for online reviews', 'background': 'Cognitive Science, University of California, Irvine, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61aac2af17ff000151846e_Michael%20Bellato.jpg'}
# 63
# {'name': 'Sabrina Aliyeva', 'title': 'Data Scientist', 'company': 'Synopsys', 'project': 'SmartAID: Poverty prediction from satellite images', 'background': 'Geophysics, Stanford University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61ab4cb318e10001feeb89_Sabrina%20Aliyeva-.jpg'}
# 64
# {'name': 'David Cameron', 'title': 'Data Scientist', 'company': 'Netflix', 'project': 'Awesome Hockey: What to skip and what to watch in NHL videos', 'background': 'Energy Resources Engineering, Stanford, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a79caf17ff000151841c_Dave%20Cameron.jpg'}
# 65
# {'name': 'Amruta Varudkar', 'title': 'Data Scientist', 'company': 'Acxiom', 'project': 'Evolutionary Biology &amp; Population Genetics, Stanford University, Postdoc\t', 'background': 'ArtPricer: Sell it already!', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a5edcef26c00010d6f31_Amruta%20Varudkar.jpg'}
# 66
# {'name': 'Yvonne Lin', 'title': 'Data Scientist', 'company': 'Social Capital', 'project': 'BeautyExtract: A data product to empower customized skincare recommendations', 'background': 'Statistics, University of Waterloo, B.Math', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61acac55260a0001f3a1c2_Yvonne%20Lin.jpg'}
# 67
# {'name': 'Adam Jacoby', 'title': 'Data Scientist', 'company': 'LinkedIn', 'project': 'Rapid Chat Made Slow: Extracting content from the chaos of Twitch chat', 'background': 'Mathematics, Temple University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a545af17ff00015183f7_Adam%20Jacoby.jpg'}
# 68
# {'name': 'Alexey Shmelev', 'title': 'Data Scientist', 'company': 'Bosch', 'project': 'TireCheck: Check your tire wear in seconds', 'background': 'Mechanical Engineering, MIT, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a5b4b318e10001feeaff_Alexey%20Shmelev.jpg'}
# 69
# {'name': 'Bahar Zarin', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'SignatureFood: Make sure you enjoy your meal!', 'background': 'Civil Engineering (Transportation), University of Maryland, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a6259cc897000135a5fc_Bahar%20Zarin.jpg'}
# 70
# {'name': 'Chalence Safranek-Shrader', 'title': 'Data Scientist', 'company': 'FiveStars', 'project': 'TexanTurnout: Predicting the Voter Turnout Rate in Texas Elections', 'background': 'Astrophysics, University of California, Berkeley, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a6ccb318e10001feeb12_Chalence%20Safranek-Shrader.jpg'}
# 71
# {'name': 'Charlie Hogg', 'title': 'Data Scientist', 'company': 'Rasa Networks', 'project': 'Pic My Plant: Growing a garden rooted in deep learning', 'background': 'Mathematics/Environmental Engineering, Stanford University, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a73229f09700016fd806_Charlie%20Hogg.jpg'}
# 72
# {'name': 'David Christle', 'title': 'Data Scientist', 'company': 'LinkedIn', 'project': 'HitCoin!: Data mining Internet hype to find the next big cryptocurrency', 'background': 'Quantum Science &amp; Engineering, University of Chicago, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a7d1af17ff000151841f_David%20Christle.jpg'}
# 73
# {'name': 'Jason Kamin', 'title': 'Data Scientist', 'company': 'Mercedes R&amp;D', 'project': 'Cairnfinder: An Alpinist&#x27;s Guide', 'background': 'Nuclear Particle Physics, CERN, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a8b7b318e10001feeb52_Jason%20Kamin.jpg'}
# 74
# {'name': 'Jeff Camp', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'DiversifyMe: Interactive visualization of correlation between exchange traded funds', 'background': 'Chemical Engineering, Lawrence Berkeley National Laboratory, Postdoc', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a8ebaf17ff0001518446_Jeff%20Camp.jpg'}
# 75
# {'name': 'Jon Witte', 'title': 'Data Scientist', 'company': 'Indeed', 'project': 'LiFT: The Lifting Form Trainer', 'background': 'Theoretical Chemistry, University of California, Berkeley, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a95255260a0001f3a192_Jon%20Witte.jpg'}
# 76
# {'name': 'Ketki Sharma', 'title': 'Data Scientist', 'company': 'Remind', 'project': 'Q-tagger: Tag your questions', 'background': 'Environmental Engineering, Georgia Institute of Technology, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a989b318e10001feeb6e_Ketki%20Sharma.jpg'}
# 77
# {'name': 'Kirsten Smayda', 'title': 'Data Scientist', 'company': 'Pear Therapeutics', 'project': 'Gobble: Cookin&#x27; with data', 'background': 'Cognitive Neuroscience, The University of Texas, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61aa6699f89b0001b530e3_Matt%20Sims.jpg'}
# 78
# {'name': 'Meghan Frate', 'title': 'Data Scientist', 'company': 'LinkedIn', 'project': 'InstaStudio: Instantly Find a Studio You&#x27;ll Love', 'background': 'Experimental Particle Physics, UC Irvine, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61aa9129f09700016fd85b_Meghan%20Frate.jpg'}
# 79
# {'name': 'Michael Saha', 'title': 'Data Scientist', 'company': 'Facebook', 'project': 'LegalTech: Startup Consulting Project', 'background': 'Environmental Sciences, The University of Virginia, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61aaf4cef26c00010d6fad_Michael%20Saha.jpg'}
# 80
# {'name': 'Yuwen Wu', 'title': 'Data Scientist', 'company': 'Intuit', 'project': 'EmailViz: Identifying employee relationships from digital communications', 'background': 'Neuroscience, Harvard University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61ac8099f89b0001b5310f_Yuwen%20Wu.jpg'}
# 81
# {'name': 'Liz Baldo ', 'title': 'Data Scientist', 'company': 'Indigo ', 'project': 'Find Your Art: Discover artwork around you using transfer learning', 'background': 'Hydrology and Water Resources Engineering, UCLA, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea0bb0c496d138b7737895_Liz.jpg'}
# 82
# {'name': 'Stephanie Sorenson ', 'title': 'Data Scientist ', 'company': 'Wayfair ', 'project': 'Churn-No-More: Discovering what drives customer churn vs. retention', 'background': 'Psychology, Stanford University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea0edb15754b2b27b0a8d5_Steph.jpg'}
# 83
# {'name': 'Steven Felix ', 'title': 'Research Analyst ', 'company': 'Wellington ', 'project': 'Search Suggestor: Improving Stack Overflow search queries with natural language processing', 'background': 'Experimental Psychopathology, Harvard University PhD ', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea0f9be1278a491437b2d4_Steven%20.jpg'}
# 84
# {'name': 'Tatyana Perlova ', 'title': 'Data Scientist ', 'company': 'Indigo ', 'project': 'MicrobeX: Exploring microbes across the globe', 'background': 'Physics, University of Illinois at Urbana-Champaign, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea108d33982ea4548eda7e_Tanya.jpg'}
# 85
# {'name': 'Bridget Salna ', 'title': 'Data Scientist ', 'company': 'Cinch ', 'project': 'AdviceDice: Board game recommendations that leave nothing to chance', 'background': 'Physics, Northeastern University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea149815754b5960b0a958_Bridget.jpg'}
# 86
# {'name': 'Esteban Urdiales ', 'title': 'Data Scientist ', 'company': 'IvySys', 'project': 'AirbnMe: Predicting Airbnb Occupancy Rates for Private Rooms in Chicago ', 'background': 'Applied Mathematics, Northwestern University, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea153a28214c2b52132d05_Esteban.jpg'}
# 87
# {'name': 'Jason Rute ', 'title': 'Data Scientist ', 'company': 'CiBO', 'project': 'CallMeBackMaybe: Using natural language processing to classify call center phone conversations', 'background': 'Mathematical Sciences, Carnegie Mellon, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea15fd31c0a5f8ebd58802_Jason.jpg'}
# 88
# {'name': 'Samta Shukla ', 'title': 'Data Scientist ', 'company': 'CVS Health ', 'project': 'SaReGaMood: Mood-based playlists for Indian classical music', 'background': 'Computer Systems, Rensselaer Polytechnic, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea2f96dc67fe0b51118364_Sam.jpg'}
# 89
# {'name': 'Yossi Cohen ', 'title': 'Research Analyst ', 'company': 'Wellington ', 'project': 'Flightstitute: Risk management for flight disruption', 'background': 'Theoretical Physics, Weizmann Institute, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea31eaf11f7145b4269177_Yossi.jpg'}
# 90
# {'name': 'Pawan Nandakishore', 'title': 'Data Scientist ', 'company': 'Colaberry ', 'project': 'Joke&#x27;s on you!: Identifying humor and inappropriate material in text', 'background': 'Fracture Mechanics, Max Planck Institute for Dynamics and Self Organization, PhD ', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea33ab94ab8a62e54dc571_Pawan.jpg'}
# 91
# {'name': 'Margaret Kosmala', 'title': 'Data Scientist ', 'company': 'CiBO', 'project': 'Mountain Bike Forecast: Predicting riding conditions using weather data ', 'background': 'Ecology, University of Minnesota, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea38dadc67fe7114118436_Margaret.jpg'}
# 92
# {'name': 'Wei He ', 'title': 'Data Scientist ', 'company': 'CVS Health ', 'project': 'Customer prioritization: Predicting a consumer&#x27;s propensity to buy', 'background': 'Physics, University of Massachusetts Amherst, PhD', 'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea3c5d7c0e4551ce0def14_Wei%20He.jpg'}

# %% [markdown]
# ## Data Examination

# %%
import pandas as pd
import json

# %%
with open('./FellowInfo8Page_v2.txt') as json_file:
    insight = json.load(json_file)

# %%
insight['fellows']
# Out:
# [{'name': 'JP Bida',
#   'title': 'Director of Risk',
#   'company': 'Capital One',
#   'project': 'Measuring the Impact of Open Source Coders on Github',
#   'background': 'Bio-X Games, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576976f76364789c4e58a0e8_JP-Pic.jpg'},
#  {'name': 'Douglas Mason',
#   'title': 'Data Scientist',
#   'company': 'Twitter',
#   'project': 'Email Searcher: Search &amp; Visualize Your Mailbox',
#   'background': 'Physics, Harvard University,Â\xa0PhD\n',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697251e8628b5103c6b117_Doug-Pic.jpg'},
#  {'name': 'Virot Ta Chiraphadhanakul',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'Tweet Timeline: Visualizing the Impact of Social Media',
#   'background': 'Operations Research, MIT, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769760f6364789c4e589ce7_Ta-Pic.jpg'},
#  {'name': 'Julia Viladomat',
#   'title': 'Data Scientist',
#   'company': 'Adobe',
#   'project': 'Sentiment Analysis Based on Social Media',
#   'background': 'Statistics, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57685673bc51c12e173d3ba2_Julia%20Pic.jpg'},
#  {'name': 'David Freeman',
#   'title': 'Head of Anti-Abuse Engineering',
#   'company': 'LinkedIn',
#   'project': 'Flight Delay Predictor',
#   'background': 'Mathematics, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b885e8628b5103c73621_davidfreeman-main.jpg'},
#  {'name': 'Jessica ZÃºÃ±iga',
#   'title': 'Senior Data Scientist',
#   'company': 'LinkedIn',
#   'project': 'Email Contacts Automatically Grouped &amp; Ranked',
#   'background': 'Mathematics, Duke, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bb9322c61e320363317d_Jessica-Pic.jpg'},
#  {'name': 'Harold Nguyen',
#   'title': 'Data Scientist',
#   'company': 'Proofpoint',
#   'project': 'Analysis of New York Stop-and-Frisk Data',
#   'background': 'Physics, UC Riverside, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576855b4df388b30315c45b0_Harold.jpg'},
#  {'name': 'Sebastien de Larquier ',
#   'title': 'Data Scientist',
#   'company': 'Netflix',
#   'project': 'CouchTube: YouTube TV shows in one click',
#   'background': 'Space Physics, Virgina Tech, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ada79680f7412500914dd_Sebastien2.jpg'},
#  {'name': 'Paula Therese Lang',
#   'title': 'Senior Data Scientist',
#   'company': 'CreativeLIVE',
#   'project': 'SchoolGeo: Empowering Parents to Make Informed Decisions',
#   'background': 'Computational Biology, UC Berkeley, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841d1e74ffc3cf55313410_terry.jpg'},
#  {'name': 'Nan Ma',
#   'title': 'Data Engineer',
#   'company': 'Microsoft Yammer',
#   'project': 'Event Map: Get Local News from Twitter',
#   'background': 'Electrical Engineering &amp; Computer Science, UC Berkeley, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576971986364789c4e5893bf_NanMa.jpg'},
#  {'name': 'Cinna Julie Wu',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'Sort My Friends: Automatically Organize your Connections',
#   'background': 'Applied Mathematics, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57685e33cf2f2b4d31a02788_CinnaWu.jpg'},
#  {'name': 'Erin Summers',
#   'title': 'Software Engineer',
#   'company': 'Facebook',
#   'project': 'Flat Finder: Find Your Perfect Apartment',
#   'background': 'Electrical Engineering &amp; Computer Science, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57687784cf2f2b4d31a04fc6_ErinSummers.png'},
#  {'name': 'Leah McGuire',
#   'title': 'Senior Data Scientist',
#   'company': 'LinkedIn',
#   'project': 'Kiva Loan Checker',
#   'background': 'Computational Neuroscience, UC Berkeley, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697c4622c61e320362d58d_LeahMcGuire.jpg'},
#  {'name': 'Nick Bunch',
#   'title': 'Quantitative Analyst',
#   'company': 'YouTube',
#   'project': 'Arrive in Time: Airport Arrival Time Predictor',
#   'background': 'Space Plasma Physics, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697f266364789c4e58b1f2_NickBunch.jpg'},
#  {'name': 'Shelby Sturgis',
#   'title': 'Senior Data Visualization Engineer',
#   'company': 'Netflix',
#   'project': 'STARtrack: Helping Educators Track Student Performance',
#   'background': 'Biology, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769831e6364789c4e58b39d_ShelbySturgis.jpg'},
#  {'name': 'Onkar Dalal',
#   'title': 'Data Scientist',
#   'company': 'LinkedIn',
#   'project': 'Diverse Recipe Recommendations',
#   'background': 'Computational &amp; Mathematical Engineering, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697fc541db86a74ee10ca7_Onkar.jpg'},
#  {'name': 'Aastha Jain',
#   'title': 'Data Scientist',
#   'company': 'LinkedIn',
#   'project': 'Multi-Domain Recommendations',
#   'background': 'Computer Vision &amp; Image Processing, Johns Hopkins University, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576873e1cf2f2b4d31a046c3_AasthaJain.jpg'},
#  {'name': 'Yan Yang',
#   'title': 'Data Engineer',
#   'company': 'Microsoft Yammer',
#   'project': 'Stock Volatility PredictorÂ\xa0',
#   'background': 'Computational &amp; Mathematical Engineering, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769819041db86a74ee10ddb_YanYang.jpg'},
#  {'name': 'Puneeth Kalavase',
#   'title': 'Algorithm Developer',
#   'company': 'PlotWatt',
#   'project': 'Lower Your Electricity Bill',
#   'background': 'Environmental Energy, UC Berkeley, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576879b7bc51c12e173d60f6_PuneethKalavase.jpg'},
#  {'name': 'Efraim Feinstein',
#   'title': 'Data Scientist',
#   'company': 'Level Up Analytics',
#   'project': 'Find the Expert on Stack Overflow',
#   'background': 'Computational Biophysics, Harvard University, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57687a939c47002117a7b562_EfraimFeinstein.jpg'},
#  {'name': 'Joe Gallagher',
#   'title': 'Data Lead',
#   'company': 'Reddit',
#   'project': 'RewindX: Rediscover Music From Your Youth',
#   'background': 'Computational Neuroscience, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576982c4e8628b5103c6dfc2_Joe-1318.jpg'},
#  {'name': 'Justin Parella',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'HipHopper: Find The Musicians You Have Been Missing',
#   'background': 'Atmospheric Chemistry, Harvard, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b52922c61e32036328c6_justinp-main.jpg'},
#  {'name': 'Andre Bach',
#   'title': 'Data Scientist',
#   'company': 'Uber',
#   'project': 'RouteAroundCrime: The Path Less MuggedÂ\xa0',
#   'background': 'Experimental Particle Physics, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697e1622c61e320362d76c_andre_bach.jpg'},
#  {'name': 'Keoki Seu',
#   'title': 'Data Engineer',
#   'company': 'Facebook',
#   'project': 'FlockThink: Twitter Search Engine For Instant Sentiment AnalysisÂ\xa0',
#   'background': 'Condensed Matter Physics,Â\xa0Lawrence Berkeley National Laboratory, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784167241bc74f670c14955_IMG_2403.JPG'},
#  {'name': 'Prakhar Mehirotra',
#   'title': 'Quantitative Analytics Finance Lead',
#   'company': 'Uber',
#   'project': 'News Now: Scrapes the RSS feeds from popular news websites (CNN, FOX, etc.) in real time',
#   'background': 'Aeronautics, California Institute of Technology, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841a4041bc74f670c14996_prakhar.jpg'},
#  {'name': 'Vincent Fusaro',
#   'title': 'Senior Software Engineer Technical Lead',
#   'company': 'InVitae',
#   'project': 'RxDiscovery: Mining the FDA&#x27;s adverse event database to identify common side-effects for drug-drug interactions',
#   'background': 'Clinical Translational Informatics, Harvard Medical School, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b3c2e8628b5103c72989_vincent_fusaro.jpg'},
#  {'name': 'Diane Wu',
#   'title': 'Founder',
#   'company': 'Trace Genomics ',
#   'project': 'BakeSearch: Stop Searching &amp; Start Baking',
#   'background': 'Genetics, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819259c76751bb2c54a6cd_Diane%20Wu.jpg'},
#  {'name': 'Giovanna Miritello',
#   'title': 'Data Scientist',
#   'company': 'Telefonica ',
#   'project': 'ReadTweetApp: The Tweets That Matter',
#   'background': 'Mathematical Engineering,Â\xa0University Carlos III of Madrid, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697bf56364789c4e58aa37_Giovanna.jpg'},
#  {'name': 'Dominique Van de Sompel',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'TwinkedIn: Follow LinkedIn Contacts on TwitterÂ\xa0',
#   'background': 'Molecular Imaging, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697d2841db86a74ee102ad_Dominiquevds.jpg'},
#  {'name': 'Colin Dillard',
#   'title': 'Data Scientist ',
#   'company': 'Level Up Analytics',
#   'project': 'CrimeVis: Visualization of Oakland Crime Rates',
#   'background': 'Physics, Harvard University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784191a137d7fea5500158e_colin.jpg'},
#  {'name': 'Brian Boates',
#   'title': 'Data Science Lead',
#   'company': 'Square',
#   'project': 'SkillRankApp: What You Need to Know For Your Dream Job',
#   'background': 'Physics, Dalhousie University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576980d46364789c4e58b392_BrianBoates.jpg'},
#  {'name': 'Adrian Kuhn',
#   'title': 'Data Engineer',
#   'company': 'Facebook',
#   'project': 'SerendipityEngineApp: Your Personal Travel Assistant',
#   'background': 'Computer Science, University of British Columbia, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784186c41bc74f670c14987_adrian.jpg'},
#  {'name': 'George Lewis',
#   'title': 'Head of Risk &amp; Analytics',
#   'company': 'LendUp',
#   'project': 'Barkov Chain: Bar &amp; Restaurant Recommendation Engine',
#   'background': 'Experimental Particle Physics, New York University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5768735fdf388b30315c6901_george.jpg'},
#  {'name': 'Berian James',
#   'title': 'Data Scientist',
#   'company': 'Square',
#   'project': 'Predicting Startup Outcomes on Crunchbase. Silicon Valley, Summer 2012',
#   'background': 'Astrophysics, UC Berkeley,Â\xa0Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b90b6364789c4e592e86_Berian-Pic.jpg'},
#  {'name': 'David Lopes Pegna',
#   'title': 'Director of Data Science',
#   'company': 'Vectra',
#   'project': 'MyFacebookDigest: What You Have Missed on Facebook?Â\xa0',
#   'background': 'Particle Physics, Princeton, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841ed774ffc3cf55314118_David%20Lopez.jpg'},
#  {'name': 'Christina Whittle',
#   'title': 'Staff, Business Analytics',
#   'company': 'NerdWallet',
#   'project': 'Neighbor Flavor',
#   'background': 'Genomics, UC Berkeley, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819216f8b83e5b135cd5c8_Christina%20Whittle.jpg'},
#  {'name': 'Megan Cartwright',
#   'title': 'Manager of Marketing Analytics &amp; Data Science',
#   'company': 'Eventbrite',
#   'project': 'Stay Connected: The People You Remember Not to Forget',
#   'background': 'Space Plasma Physics, UC Berkeley, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bd736364789c4e592e9b_megan-main.jpg'},
#  {'name': 'Warren Mar',
#   'title': 'Data Scientist',
#   'company': 'BloomReach',
#   'project': 'FlixPixie: &quot;Automagically&quot; Sort Photos',
#   'background': 'Electrical Engineering, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bf81e8628b5103c74574_warrenmar.jpg'},
#  {'name': 'Eric Zilli',
#   'title': 'Software Engineer',
#   'company': 'Facebook',
#   'project': 'Sandwichly: Make The Perfect Sandwich',
#   'background': 'Neuroscience, Boston University, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5784198e137d7fea55001593_ericz.jpg'},
#  {'name': 'Lisa Qian',
#   'title': 'Data Science Manager',
#   'company': 'Airbnb',
#   'project': 'Yelp Personal: Personalized Yelp recommendations',
#   'background': 'Applied Physics, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bf21e8628b5103c74573_LisaQian.jpg'},
#  {'name': 'Krystal St. Julien',
#   'title': 'Operations Analyst',
#   'company': 'Facebook',
#   'project': 'GeoJobr: Finding a job in today&#x27;s economy',
#   'background': 'Biomedical Genetics, Biochemistry, and Organogenesis, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576972bf6364789c4e5893c5_Krystal.jpg'},
#  {'name': 'Daniel Silverstein',
#   'title': 'Data Scientist',
#   'company': 'Microsoft Yammer',
#   'project': 'Dine-amic Food: Making food decisions easy using dynamic data',
#   'background': 'High Energy Physics, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576882eecf2f2b4d31a0567f_Dan.jpg'},
#  {'name': 'Matthew Folz',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'GameChooser: Intelligent viewing recommendations for NBA games,Â\xa0The University of British Columbia, PhD',
#   'background': 'Probability Theory and Stochastic Processes,Â\xa0',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b990e8628b5103c736e0_Matt-F.jpg'},
#  {'name': 'Praveen Kundurthy',
#   'title': 'Data Scientist',
#   'company': 'Microsoft Yammer',
#   'project': 'Flop Buster: The box-office prediction app',
#   'background': 'Astronomy,Â\xa0University of Washington, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bc886364789c4e592e97_Praveen.jpg'},
#  {'name': 'Lauren Porter',
#   'title': 'Senior Data Scientist',
#   'company': 'Snapdeal',
#   'project': 'Off the Beaten Path: Your personalized vacation planner',
#   'background': 'Theoretical and Computational Astrophysics, UC Santa Cruz, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576884239c47002117a7b8ac_Lauren.jpg'},
#  {'name': 'Aaron Keys',
#   'title': 'Data Architect',
#   'company': 'Aiirbnb',
#   'project': 'Gener-Rec: Greed is not good (at least for recommendation engines)',
#   'background': 'Chemical Engineering, UC Berkeley, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769790f41db86a74ee0fa60_Aaron.jpg'},
#  {'name': 'Kevin Schaeffer',
#   'title': 'Technical Lead',
#   'company': 'Facebook',
#   'project': 'NewsTweet: Discover what&#x27;s happening right now anywhere in the world',
#   'background': 'Theoretical High Energy Physics, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bb2922c61e320363317b_KevinS.jpg'},
#  {'name': 'Shih-Ho Cheng',
#   'title': 'Data Scientist',
#   'company': 'Airbnb',
#   'project': 'Less-Sketchy: An early fraud detection web-app for apartment classifieds',
#   'background': 'Computational Astro-particle Physics,Â\xa0The Pennsylvania State University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57687f01cf2f2b4d31a055c8_Shih-ho.jpg'},
#  {'name': 'Xiaoying Xu',
#   'title': 'Data Scientist',
#   'company': 'Zillabyte',
#   'project': 'Job Link: Find and Connect with Potential New Careers',
#   'background': 'Astrophysics/Cosmology,Â\xa0Carnegie Mellon University, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841aae74ffc3cf55312be1_Xiao.jpg'},
#  {'name': 'Nicholas Tomko',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'Reddibility: Just the Q&#x27;s &amp; A&#x27;s, none of the BS',
#   'background': 'Artificial Intelligence - Evolutionary Computation,Â\xa0University of Sussex, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769be17e8628b5103c73cce_nicholas_tomko.jpg'},
#  {'name': 'Mio Alter',
#   'title': 'Data Scientist',
#   'company': '6Sense',
#   'project': 'Flava: Find your Flava',
#   'background': 'Mathematics (Geometry/Topology), University of Texas at Austin, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57688532bc51c12e173d6ec2_Mio.jpg'},
#  {'name': 'Wei Zhang',
#   'title': 'Data Scientist/Software Engineer',
#   'company': 'Walmart Labs',
#   'project': 'Startup Sniffer: Transform gut-driven to data-driven investmentÂ\xa0',
#   'background': 'Computer Science and Engineering, University of Notre Dame, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5781919a025cfc7613d5d159_Wei.jpg'},
#  {'name': 'Jingjing Huang',
#   'title': 'Sr. Associate, Business Analytics',
#   'company': 'LinkedIn',
#   'project': 'NuTube: Classifying recent YouTube videosÂ\xa0',
#   'background': 'Mathematics/Electrical Engineering, California Institute of Technology, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57688265bc51c12e173d6ddf_Jingjing.jpg'},
#  {'name': 'Joshua Lande',
#   'title': 'Senior Data Scientist',
#   'company': 'Twitter',
#   'project': 'ReviewSkimmer: Find what&#x27;s good or bad in a movie, before it&#x27;s too late!',
#   'background': 'Astrophysics, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5768832dbc51c12e173d6e18_Josh.jpg'},
#  {'name': 'Eli Bressert',
#   'title': 'Data Scientist ',
#   'company': 'Netflix',
#   'project': 'InspectorGit: Discover Github&#x27;s awesome repositories',
#   'background': 'Astrophysics, University of Exeter, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769733ce8628b5103c6b124_Eli.jpg'},
#  {'name': 'Jenelle Bray',
#   'title': 'Manager, Security Data Science',
#   'company': 'LinkedIn',
#   'project': 'PlacePickr: Helping couples decide where to liveÂ\xa0',
#   'background': 'Computational Structural Biology &lt;br&gt; Stanford University &lt;br&gt; Postdoct',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696df86364789c4e588546_Jenelle2.jpg'},
#  {'name': 'Shanshan Ding',
#   'title': 'Data Scientist ',
#   'company': 'Compass',
#   'project': 'Who&#x27;s On First: Predicting the outcomes of baseball&#x27;s batter-pitcher matchups',
#   'background': 'Mathematics, University of Pennsylvania, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769746041db86a74ee0f159_Shanshan.jpg'},
#  {'name': 'Elizabeth Leicht',
#   'title': 'Data Engineer, Analytics',
#   'company': 'Facebook',
#   'project': 'DinnerDetente: Easing the strained relationship between healthy and delicious',
#   'background': 'Statistical Physics/Complex Systems, University of Oxford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769702522c61e320362c20d_Elizabeth2.jpg'},
#  {'name': 'Chris Said',
#   'title': 'Data Scientist',
#   'company': 'Twitter',
#   'project': 'DealSpotter: Find rare deals on Craigslist... the easy way',
#   'background': 'Neuroscience, Princeton, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769758141db86a74ee0f1bb_ChrisS.jpg'},
#  {'name': 'Steven Herrin',
#   'title': 'Software Engineer',
#   'company': '23andMe',
#   'project': 'ParkSafely: Bicycling in San Francisco? Park where theft is less likely',
#   'background': 'Experimental Neutrino Physics, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769782f41db86a74ee0f658_Steve.jpg'},
#  {'name': 'Aristotle Socrates',
#   'title': 'Senior Data Scientist',
#   'company': 'Juvo',
#   'project': 'Tweather: Current local weather tweets',
#   'background': 'Theoretical Astrophysics, Institute for Advanced Study, Princeton, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576968616364789c4e588031_Ari2.jpg'},
#  {'name': 'Alexander Tronchin-James',
#   'title': 'Data Engineer',
#   'company': 'Facebook',
#   'project': 'BeerInsight: Recommending exploration of obscure craft beer',
#   'background': 'Engineering-Physics, UC San Diego, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696c5a6364789c4e588497_Alex.jpg'},
#  {'name': 'Slater Stich',
#   'title': 'Data Scientist',
#   'company': 'Square',
#   'project': 'TopOfTheStack: Find Stack Overflow questions to answerÂ\xa0',
#   'background': 'Mathematics, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696cd941db86a74ee0e405_Slater.jpg'},
#  {'name': 'John Joo',
#   'title': 'Data Scientist Evangelist',
#   'company': 'Domino Data Lab',
#   'project': 'HypeControl: Identify bias in the news you readÂ\xa0',
#   'background': 'Applied Physics, Harvard, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696d5a22c61e320362bb60_JohnJ.jpg'},
#  {'name': 'Kevin Wheeler',
#   'title': 'Data Engineer',
#   'company': 'Facebook',
#   'project': 'PredictMyLineup: A fantasy football lineup optimization engine',
#   'background': 'Materials Science/Engineering (Protein biophysics), Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57841e0841bc74f670c14df0_Kevin%20Wheeler.jpg'},
#  {'name': 'John McDonnell',
#   'title': 'Data Scientist',
#   'company': 'Stitch Fix',
#   'project': 'HotHoods: Forecasting neighborhood trends in housing prices',
#   'background': 'Cognitive Science, New York University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576984426364789c4e58b83b_JohnM2.jpg'},
#  {'name': 'Cristian Figueroa',
#   'title': 'Data Engineer',
#   'company': 'Facebook',
#   'project': 'BargainMeal: Great deals on top rated dishesÂ\xa0',
#   'background': 'Operations Research, MIT, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819014f8b83e5b135cd5c5_Cristian.jpg'},
#  {'name': 'Michael Kuhlen',
#   'title': 'Data Scientist',
#   'company': 'LendUp',
#   'project': 'Delay Me Not! Providing flight day predictions at ticket purchase time',
#   'background': 'Astronomy &amp; Astrophysics, UC Santa Cruz, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576973b622c61e320362c6ac_Mike.jpg'},
#  {'name': 'Shu Liu',
#   'title': 'Data Engineer II',
#   'company': 'Microsoft Yammer',
#   'project': 'HummingBirds: Getting the latest news about trends on TwitterÂ\xa0',
#   'background': 'Computer Science, University of Notre Dame, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576974d2e8628b5103c6b452_Shu2.jpg'},
#  {'name': 'Christopher Miller',
#   'title': 'Data Scientist ',
#   'company': 'Hipmunk',
#   'project': 'AmazonComparer: Short &amp; sweet product reviews',
#   'background': 'Physics, UC David, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818fb69c205dc62cd227d6_chrismiller.jpg'},
#  {'name': 'Christopher Moody',
#   'title': 'Data Scientist',
#   'company': 'Stitch Fix',
#   'project': 'ThisPlusThat: Amazing conceptual searching with natural languageÂ\xa0',
#   'background': 'Physics, UC Santa Cruz, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5781907fc76751bb2c54a69b_ChrisMo.jpg'},
#  {'name': 'Anna Szostek',
#   'title': 'Data Scientist / R&amp;D Engineer',
#   'company': 'Probayes',
#   'project': 'PopularNow: Get great content from Twitter NOW!',
#   'background': 'Astrophysics, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696a4522c61e320362ba09_Anna.jpg'},
#  {'name': 'Matt Smith',
#   'title': 'Director of Product',
#   'company': 'Insight Data Science',
#   'project': 'DailyFaces: The people in today&#x27;s news.',
#   'background': 'Computational Protein Engineering, California Institute of Technology, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576afae8caca498c1ef32d5b_Matt%20Smith.jpg'},
#  {'name': 'Ahmet Bakan',
#   'title': 'Data Scientist',
#   'company': 'Kabbage',
#   'project': 'EURoute.me: Make the most out of your Europe trip!Â\xa0',
#   'background': 'Computational Biology, University of Pittsburgh, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b2086364789c4e591c63_Ahmet%20Bakan.jpg'},
#  {'name': 'Chris Farrell',
#   'title': 'Engineering Manager',
#   'company': 'Yelp',
#   'project': 'OldFaveNewPlace: Find restaurants in a new city similar to ones you like in a different city',
#   'background': 'Experimental Particle Physics, University of California, Los Angeles, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818f06025cfc7613d5d047_Chris%20Farrell.jpg'},
#  {'name': 'Alan Wilson',
#   'title': 'Senior Data Scientist',
#   'company': 'Glassdoor',
#   'project': 'NewsSpectra: Find news at your level.Â\xa0',
#   'background': 'Particle Physics,Â\xa0University of Michigan, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696f2041db86a74ee0e809_Alan%20Wilson.jpg'},
#  {'name': 'Bharat Kunduri',
#   'title': 'Data Scientist',
#   'company': 'rocQ',
#   'project': 'Git-A-Friend: Find friends/collaborators on Github',
#   'background': 'Space Physics, Virginia Tech, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5768867a9c47002117a7c0c7_Bharat%20Kunduri.jpg'},
#  {'name': 'Matt Gibb',
#   'title': 'EDU Specialist',
#   'company': 'Affirm, Inc.',
#   'project': 'CrowdMinr: Make a great return on your investment with peer-to-peer lending',
#   'background': 'Computational Biology, University of Oxford, PhDÂ\xa0',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697aee6364789c4e58a62b_Matt%20Gibb.jpg'},
#  {'name': 'Becky Tucker',
#   'title': 'Sr. Data Scientist',
#   'company': 'Netflix',
#   'project': 'OnLocation: How to see where your favorite movies were filmed.Â\xa0',
#   'background': 'Experimental Astrophysics, California Institute of Technology, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818d569c205dc62cd22745_Becky%20Tucker.jpg'},
#  {'name': 'Saba Zuberi',
#   'title': 'Data Scientist',
#   'company': 'TaskRabbit',
#   'project': 'WhatGives: Predicting the funding success of Kiva loans.Â\xa0',
#   'background': 'Theoretical Particle Physics,Â\xa0Lawrence Berkeley National Lab, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818e19f8b83e5b135ccf58_Saba%20Zuberi.jpg'},
#  {'name': 'AJ Ribeiro',
#   'title': 'Software Engineer',
#   'company': 'Uber',
#   'project': 'ForecastingTomatoes: Predict how your film will be received',
#   'background': 'Space Science, Virginia Tech, PhDÂ\xa0',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576afda3504913a71e826326_AJ%20Ribeiro.jpg'},
#  {'name': 'Nhung Ho',
#   'title': 'Sr. Data Scientist',
#   'company': 'Intuit',
#   'project': 'Healthy-Me: Making health discovery easy',
#   'background': 'Observational Astrophysics, Yale, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818ea0025cfc7613d5c9db_Nhung%20Ho.jpg'},
#  {'name': 'Cian Menzel-Jones',
#   'title': 'Manager of Data Science',
#   'company': 'Stitch Fix',
#   'project': 'LinkedInsight: Find the skills and connections that matter',
#   'background': 'Computational Atomic, Molecular and Optical Physics,Â\xa0The University of British Columbia, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576968ec6364789c4e58807d_Cian-Menzel-Jones.jpg'},
#  {'name': 'Joy Rimchala',
#   'title': 'Data Scientist',
#   'company': 'Intuit',
#   'project': 'InvestWiser: Predicting series A crunch outcome.',
#   'background': 'Biological Engineering, Computation &amp; Neural Systems, MIT, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696b0941db86a74ee0e365_Joy-Rimchala.jpg'},
#  {'name': 'Jun Yan',
#   'title': 'Senior Data Scientist',
#   'company': 'AT&amp;T',
#   'project': 'NewsLine: Automated timeline that provides you context of news topics.',
#   'background': 'Chemical Engineering, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57696f556364789c4e588ded_Jun%20Yan.jpg'},
#  {'name': 'Ricardo Pinho',
#   'title': 'Data Scientist',
#   'company': 'Grand Rounds',
#   'project': 'Happy.li: Helping couples decide where to work and live together... and live happily ever after',
#   'background': 'Computational Biology/Physics, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697a8a6364789c4e58a625_Ricardo-Pinho.jpg'},
#  {'name': 'Daniel Perez-Becker ',
#   'title': 'Data Scientist',
#   'company': 'Microsoft Yammer',
#   'project': 'FareBeast: On the prowl for the lowest airfares',
#   'background': 'Theoretical Astrophysics, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697abb6364789c4e58a628_Daniel%20Perez-Becker.jpg'},
#  {'name': 'Lauren Nicolaisen',
#   'title': 'Data Scientist',
#   'company': 'Khan Academy',
#   'project': 'PickYourFiction: Find a book you&#x27;ll love!',
#   'background': 'Physics (Theoretical Population Genetics), Harvard, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769838ee8628b5103c6dfca_Lauren-Nicolaisen.jpg'},
#  {'name': 'Natalie Han',
#   'title': 'Manager of Data Science, Business Analytics',
#   'company': 'LinkedIn',
#   'project': 'DJ-Cloud: Discover popular music albums with cloud computing',
#   'background': 'Medical Image Analysis, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769bbd26364789c4e592e95_Natalie%20Han.jpg'},
#  {'name': 'Allen Sussman',
#   'title': 'Data Scientist Engineer',
#   'company': 'Sojern',
#   'project': 'Two-lu: Movie recommendations for two!Â\xa0',
#   'background': 'Experimental Condensed Matter Physics, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818b40c76751bb2c54a57e_Allen%20Sussman.jpg'},
#  {'name': 'Jeff Seifried',
#   'title': 'Software Engineer - Data-Mining',
#   'company': 'Yelp',
#   'project': 'dogWalkScore: Find the neighborhood for you and your dog.Â\xa0',
#   'background': 'Nuclear Engineering, UC Berkeley, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818dc4f8b83e5b135ccf57_Jeff%20Seifried.jpg'},
#  {'name': 'Shelly Jang',
#   'title': 'Data Scientist',
#   'company': 'Athos',
#   'project': 'BeeHealthy: Join the hive, get healthy!Â\xa0',
#   'background': 'Synthetic Biology, University of Washington, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5764488de4cff9a81929e317_Shelly-Jang.jpg'},
#  {'name': 'Javiera Guedes',
#   'title': 'Data Scientist',
#   'company': 'Teralytics',
#   'project': '$trategy: Get notifications on when to buy/sell a stock.',
#   'background': 'Computational Astrophysics, ETH Zurich, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57818f47c76751bb2c54a699_Javiera%20Guedes.jpg'},
#  {'name': 'Mike Grinolds',
#   'title': 'Technical Lead and Staff Engineer for Data Products',
#   'company': 'SalesforceIQ',
#   'project': 'KickFinder: Kickstart the perfect project',
#   'background': 'Experimental physics, Harvard, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576b0146504913a71e827654_Mike%20Grinolds.jpg'},
#  {'name': 'Adel Dayarian',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'RelaxedParking: Parking assistant to avoid traffic tickets and car-related crimes',
#   'background': 'Computational Biology and Biophysics, Kavli Institute for Theoretical Physics, UC Santa Barbara, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b2306364789c4e591c66_Adel%20Dayarian.jpg'},
#  {'name': 'Burcu Baran',
#   'title': 'Senior Data Scientist, Business Analytics (Data Mining)',
#   'company': '6Sense Insights',
#   'project': 'GroupDine: Giving restaurant suggestions to a group of people based on their Instagram posts',
#   'background': 'Mathematics, Stanford/University of Michigan, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b2626364789c4e591c68_Burcu%20Baran.jpg'},
#  {'name': 'Nancy Ru',
#   'title': 'Principal Programmer/Analyst',
#   'company': 'Sling Media',
#   'project': 'BurstingTheBubble: Recommending news articles from outside your bubble',
#   'background': 'Applied Physics, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b288e8628b5103c72984_Nancy%20Ru.jpg'},
#  {'name': 'Ahna Girshick',
#   'title': 'Head of Product',
#   'company': 'Enlitic',
#   'project': 'Wikiphilia: Scoring Wikipedia Page Quality',
#   'background': 'Vision Science &amp; Computer Science, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ace80b493c92d50f3eea2_Ahna-0306.jpg'},
#  {'name': 'Heather Shapiro',
#   'title': 'Data Mining Engineer',
#   'company': 'Pebble',
#   'project': 'HealthImpact: Expediting medical care for those in need',
#   'background': 'Cognitive Neuroscience, UC Davis, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a7cae8628b5103c71fc4_Heather-0301.jpg'},
#  {'name': 'Jesus Martinez',
#   'title': 'Data Scientist',
#   'company': 'Capital One',
#   'project': 'EdXPredictor: Predict your performance on edX courses',
#   'background': 'Astrophysics, University of Florida, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a5d041db86a74ee125aa_Jesus-0274.jpg'},
#  {'name': 'Matt George',
#   'title': 'Data Scientist',
#   'company': 'Square',
#   'project': 'StreetsAhead: Image recognition with deep learning in Street View',
#   'background': 'Astrophysics, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769ae8f6364789c4e5919c5_Matt-0288.jpg'},
#  {'name': 'Carlos Cunha',
#   'title': 'Senior Data Scientist',
#   'company': 'Bosch',
#   'project': 'Jaunt: Recommendations along the way!',
#   'background': 'Cosmology and Astrophysics, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769af69e8628b5103c72979_Carlos-0332.jpg'},
#  {'name': 'Adam Morgan',
#   'title': 'Lead Data Scientist',
#   'company': 'Target',
#   'project': 'CharityVerity: Predicting charity ratings to guide effective altruism',
#   'background': 'Astrophysics, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57819415c76751bb2c54a6cf_adammorgan.jpg'},
#  {'name': 'Wafa Soofi',
#   'title': 'Data Scientist',
#   'company': 'Square',
#   'project': 'CrowdSkippr: Minimize crowds, maximize joy',
#   'background': 'Biomedical Engineering/ Computational Neuroscience, Georgia Institute of Technology/Emory University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769c978e8628b5103c75259_Wafa-0963.jpg'},
#  {'name': 'David Paulsen',
#   'title': 'Director of Data and Analytics',
#   'company': 'Prosper',
#   'project': 'RxFX: Prescription Drug Recommendations &amp; Side Effect Discovery',
#   'background': 'Cognitive Neuroscience, University of Pittsburgh, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a4f7e8628b5103c71591_David-0327-2.jpg'},
#  {'name': 'Nicholas Peterson',
#   'title': 'Data Scientist',
#   'company': 'Electronic Arts',
#   'project': 'Math.StackExpert: Finding you high-quality questions on Math',
#   'background': 'Mathematics, The Ohio State University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769ac5822c61e32036319f5_Nicholas-0280.jpg'},
#  {'name': 'Vanessa Heckman',
#   'title': 'Data Mining Scientist',
#   'company': 'Apple',
#   'project': 'Lenderstanding: Helping lenders help',
#   'background': 'Civil Engineering, Geophysics, Caltech/California Institute of Technology',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769ca2b22c61e3203633335_Vanessa-0222.jpg'},
#  {'name': 'Aparupa Das Gupta',
#   'title': 'Data Scientist',
#   'company': 'Cisco',
#   'project': 'Price Wizard: Recommends the highest price to post on Craigslist for selling furniture items',
#   'background': 'Operations Research, UCLA, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad06930d4453860317966_Aparupa-0226.jpg'},
#  {'name': 'Kevin Teh',
#   'title': 'Data Scientist / Software Engineer',
#   'company': 'Opendoor Labs',
#   'project': 'Cluster-Pluck: Disambiguating Twitter Search',
#   'background': 'Mathematics, Caltech, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/578194769c205dc62cd234c1_kevinteh.jpg'},
#  {'name': 'Zack Chadick',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'Steal-This-House!: Crime doesn&#x27;t pay...&#x27;cept for your bottom line!',
#   'background': 'Systems Neuroscience, UCSF, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769cb3f22c61e320363333c_ZackC.jpg'},
#  {'name': 'Kevin Ford',
#   'title': 'Data Scientist',
#   'company': 'Counsyl',
#   'project': 'TapMapper: Find out what the locals are drinking/tweeting',
#   'background': 'Biophysics/Neuroscience, UCSF, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/57697b5b6364789c4e58a62e_Kevin-0292.jpg'},
#  {'name': 'Kelty Allen',
#   'title': 'Data Scientist',
#   'company': 'Microsoft',
#   'project': 'AmazonExplorer.info: A deeper look into Amazon product review history',
#   'background': 'Mathematical Logic, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a8b641db86a74ee12f20_Kelty-0264.jpg'},
#  {'name': 'Jason French',
#   'title': 'Data Scientist',
#   'company': 'Rise Interactive',
#   'project': 'Green Machine: Removing the barrier to solar energy estimation',
#   'background': 'Differential Psychology, Northwestern University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a63a41db86a74ee125af_Jason-0282.jpg'},
#  {'name': 'Asif Imran',
#   'title': 'Tech Lead, Programmatic Optimization &amp; Fraud Prevention',
#   'company': 'AdRoll',
#   'project': 'git-discover: Unlock the potential of Github',
#   'background': 'High Energy Astrophysics, Wisconsin IceCube Particle Astrophysics Center, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a6bee8628b5103c715a0_Asif-0253.jpg'},
#  {'name': 'Meredith Trotter',
#   'title': 'Data Scientist',
#   'company': 'Lumiata',
#   'project': 'Should I Kick or Should I Go?: Optimize your crowdfunding campaign',
#   'background': 'Biology: Evolutionary and Demographic Theory, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769acdc6364789c4e5919ba_Meredith-0193.jpg'},
#  {'name': 'Nicholas Tilmans',
#   'title': 'Data Scientist',
#   'company': 'Lumiata',
#   'project': 'DrugScope: Scope out your medicine before taking it!',
#   'background': 'Biochemistry, Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769ad5322c61e32036319fc_Nicolas-0234.jpg'},
#  {'name': 'Christopher Klein',
#   'title': 'Siri Data Scientist',
#   'company': 'Apple',
#   'project': 'What&#x27;s for Dinner: Dinner recommendations to meet daily nutrition goals',
#   'background': 'Astronomy, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769adf922c61e32036319ff_Chris-0257.jpg'},
#  {'name': 'Igor Bespamyatnov',
#   'title': 'Data Scientist ',
#   'company': 'Apple',
#   'project': 'AdNet: Graph recommender for news domains',
#   'background': 'Plasma Physics, University of Texas, Austin, PostdocÂ\xa0',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769a57041db86a74ee125a9_Igor-0404.jpg'},
#  {'name': 'Benoit Dherin',
#   'title': 'Watson Senior Software Engineer',
#   'company': 'IBM',
#   'project': 'GradeExpectation: Piazza forum analyzer',
#   'background': 'Mathematics and Statistics, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769aef96364789c4e5919c9_Benoit-0199.jpg'},
#  {'name': 'Monica Hsu',
#   'title': 'Data Scientist',
#   'company': 'Intuit',
#   'project': 'TruValuation: Predict the true value of your home',
#   'background': 'Biophysics, UCSF, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769afd9e8628b5103c7297a_Monica-0186.jpg'},
#  {'name': 'Michael Woods',
#   'title': 'Software Engineer Data Mining',
#   'company': 'Yelp',
#   'project': 'MelodyMapr: Improving the road trip experience',
#   'background': 'Physics, UC Davis, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b0386364789c4e591ba6_Michael.Woods-0298.jpg'},
#  {'name': 'Ravi Menon',
#   'title': 'Director of Data and Analytics',
#   'company': 'Brilliant.org',
#   'project': 'SearchPy: Search for related python code on Stack Overflow',
#   'background': 'Earth &amp; Ocean Sciences/Signal Processing, UCSD, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576b00a6caca498c1ef34253_Ravi-0402.jpg'},
#  {'name': 'Meng (Ray) Gao',
#   'title': 'Sr. Data Scientist',
#   'company': 'Pilot AI Labs',
#   'project': 'UpFindr: Find the best activity partners on Meetup.com!',
#   'background': 'Â\xa0Physics, University of Toronto, PhDÂ\xa0',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b0a1e8628b5103c7297d_Ray-0240.jpg'},
#  {'name': 'Nicole Romano',
#   'title': 'Data Scientist',
#   'company': 'RadiumOne',
#   'project': 'SetList: Set your life to music',
#   'background': 'Materials Engineering (Neural Regeneration), Stanford, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b0f322c61e320363227d_Nicole-0211.jpg'},
#  {'name': 'Michael Ramm',
#   'title': 'Senior Data Scientist',
#   'company': 'Netflix',
#   'project': 'Hoppr: Optimize route for running errands',
#   'background': 'Physics, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/5769b16741db86a74ee13193_Michael.Ramm--0198.jpg'},
#  {'name': 'Sumin Tang',
#   'title': 'Ads Analytics',
#   'company': 'Facebook',
#   'project': 'LinkBooksMovies: Book recommendations if you like a certain movie',
#   'background': 'Astrophysics,Â\xa0Caltech/University of California, Santa Barbara, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576acf5eec69725360fc175b_Sumin-0260.jpg'},
#  {'name': 'Vickie Zhang',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'VentureNetwork: Recommend high potential startups based on investor&#x27;s portfolio',
#   'background': 'Bioengineering, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576acfc2680f74125009020a_Vickie-0323.jpg'},
#  {'name': 'Leifur Thorbergsson',
#   'title': 'Data Scientist',
#   'company': 'Memorial Sloan Kettering',
#   'project': 'FindMyPoem: Finding the poem that fits your mood and preference',
#   'background': 'Statistics, Cornell University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad24330d4453860317d96_Leifur.jpg'},
#  {'name': 'Daniel Fernandez',
#   'title': 'Data Scientist',
#   'company': 'Encompass Capital',
#   'project': 'abstrART: Bringing price transparency to the art market',
#   'background': 'Statistics, Harvard, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576af3c6caca498c1ef31be6_DanielF.jpg'},
#  {'name': 'Josh Ainsley',
#   'title': 'Director, Customer Intelligence &amp; Data Science',
#   'company': 'Coach',
#   'project': 'childHood: Finding a kid-friendly place to live',
#   'background': 'Neuroscience, Tufts University, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad28130d4453860317d98_Joshua.jpg'},
#  {'name': 'Robert Amanfu',
#   'title': 'Data Scientist',
#   'company': 'Capital One',
#   'project': 'CraigFlagr: Check flag potential of Craigslist posts',
#   'background': 'Biomedical Engineering, University of Virginia, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad216b493c92d50f3f0b4_RobertA.jpg'},
#  {'name': 'Friederike Schueuer',
#   'title': 'Data Scientist',
#   'company': 'Fast Forward Labs',
#   'project': 'Drugged-up: Know what&#x27;s in your drugs and how that might make you feel',
#   'background': 'Cognitive Science, New York University, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad169680f7412500902b2_Friederike.jpg'},
#  {'name': 'Anita Schmid',
#   'title': 'Senior Data Scientist',
#   'company': 'Credit Suisse',
#   'project': 'Q-Schools: Learn English through Sign LanguageÂ\xa0',
#   'background': 'Systems Neuroscience, Weill Cornell Medical College, Faculty',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576af48bcaca498c1ef31bf9_Anita.jpg'},
#  {'name': 'Andrew Zirm',
#   'title': 'Data Scientist',
#   'company': 'Greenhouse',
#   'project': 'nimi: Everyone has a name, your kid needs a great one!',
#   'background': 'Astrophysics, Niels Bohr Institute, Copenhagen University, FacultyÂ\xa0',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576af4571c81b68b70f3ee89_Andrew.jpg'},
#  {'name': 'Divyanshu Vats',
#   'title': 'Quantitative Researcher',
#   'company': 'Two Sigma',
#   'project': 'cities4me: Discover cities based on your interests!',
#   'background': 'Machine Learning, Rice University, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576af4151c81b68b70f3ee87_Divyanshu.jpg'},
#  {'name': 'Yiping Yuan',
#   'title': 'Machine Learning Researcher',
#   'company': 'LinkedIn',
#   'project': 'Career Wizard: A career path recommender',
#   'background': 'Statistics, University of Minnesota, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad84330d44538603187af_Yiping.jpg'},
#  {'name': 'Pouria Fewzee',
#   'title': 'Senior Data Scientist',
#   'company': 'Zoom.ai',
#   'project': 'HOSPARENCIE: Transparency in hospitalization fees',
#   'background': 'Electrical &amp; Computer Engineering, University of Waterloo, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576c8279a2b1564932b1112a_Pouria.jpg'},
#  {'name': 'Genevieve Smith',
#   'title': 'Director of Product',
#   'company': 'Insight Data Science',
#   'project': 'Neutral_Opinion: Visualizing opinions on net neutrality',
#   'background': 'Ecology &amp; Evolution, The University of Texas at Austin, PostdocÂ\xa0',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576acef530d44538603174c0_Genevieve.jpg'},
#  {'name': 'Ethan Geil',
#   'title': 'Technical Director, Big Data',
#   'company': 'BitSight',
#   'project': 'Rain: Real-time radar-based precipitation forecasting',
#   'background': 'Physics, Cornell University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de45/576ad7ee680f741250091049_Ethan.jpg'},
#  {'name': 'Brandon Kelly',
#   'title': 'Big Data Engineer/Analyst',
#   'company': 'Goodyear',
#   'project': 'The Flavory: An ingredient recommendation factory',
#   'background': 'Astrophysics, UCSB, Postdoc',
# ...
#   'background': 'Electrical and Computer Engineering, Clarkson University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea2a3489272e494f6592ed_Fazel3.jpg'},
#  {'name': 'Andrew Chegwidden',
#   'title': 'Engineering Staff - Data Scientist',
#   'company': 'Goodyear Tire and Rubber Company',
#   'project': 'AutoPrice: What the vehicle will REALLY cost you',
#   'background': 'Particle Physics, Michigan State University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5ab93dd2de71f3e68fe70d71_Andrew_Chegwidden.jpg'},
#  {'name': 'Antonio Ordonez',
#   'title': 'Data Scientist',
#   'company': 'Apple',
#   'project': 'MatchTheVote: Matching advocacy group members with voters using machine learning',
#   'background': 'Astronomy, NASA Frontier Development Lab, Ph.D.',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5ab93eb6440d641859662214_Antonio_Ordonez.jpg'},
#  {'name': 'Denis Voytenko',
#   'title': 'Senior Data Scientist',
#   'company': 'Nielsen',
#   'project': 'FareHarrier: Predicting NYC subway wait times so taxi drivers get more business ',
#   'background': 'Geophysics, New York University, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5ab93f27440d64999d662226_denis_voytenko_headshot.jpg'},
#  {'name': 'Louis Antonelli',
#   'title': 'Data Scientist',
#   'company': 'Vizient',
#   'project': 'SilverTongue: Helping you nail that next big presentation',
#   'background': 'Experimental Particle Physics, The Ohio State University, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5ab94019b07e8222cfd31fc0_Jamie%20Antonelli%20headshot.jpg'},
#  {'name': 'Patrick Long',
#   'title': 'Data Scientist',
#   'company': 'IQVIA',
#   'project': 'enCard: Predicting credit card transaction failures',
#   'background': 'Neuroscience, University of Michigan, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5abb8d58de71f34d6de73e42_Patrick_Long.jpg'},
#  {'name': 'Peter Tsai',
#   'title': 'Data Engineer',
#   'company': 'MOCAP Analytics',
#   'project': 'NBATicketSavant: Buy tickets without regret!',
#   'background': 'Materials Science &amp; Engineering, Washington University in St. Louis, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5abb8dcb4c436c39f25132a0_Peter_Tsai_%20Headshot.jpg'},
#  {'name': 'Sean Tauber',
#   'title': 'Senior Analytics Software Developer ',
#   'company': 'Boston Consulting Group',
#   'project': 'DishSTARS: The best dishes and where to get them',
#   'background': 'Cognitive Science, University of New South Wales, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5abb8e2c440d6472ae6652d1_Sean_Tauber_Headshot.jpg'},
#  {'name': 'Wesley Clark',
#   'title': 'Data Scientist',
#   'company': 'Goodyear Tire and Rubber Company',
#   'project': 'Panoptica: Gaining Insight into and Predicting Youtube Audience Demographics',
#   'background': 'Biochemistry and Bioinformatics, University of Chicago, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5abb8e99a291289de7e406ff_Wesley%20Clark.jpg'},
#  {'name': 'Elahe Farahzadeh',
#   'title': 'Data Scientist',
#   'company': 'IBM',
#   'project': 'EscapeDisaster: Travel to the right place at the right time',
#   'background': 'Computer Vision, University of North Carolina at Chapel Hill, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5abbfb1c7eb5a76373dfc3f2_Ella.jpg'},
#  {'name': 'Lisa Rayle',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'NexIQ: Improving flight search for busy travelers',
#   'background': 'City &amp; Regional Planning, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a9f129f09700016fd859_Lisa%20Rayle.jpg'},
#  {'name': 'Tahlia DeMaio',
#   'title': 'Data Scientist',
#   'company': 'Second Measure',
#   'project': 'Finding Who FLEX Fits: Refining target demographics for The FLEX Company',
#   'background': 'Astronomy, University of Florida, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61ac0ea7da9e000103d90b_Tahlia%20DeMaio.jpg'},
#  {'name': 'Chandra Natarajan',
#   'title': 'Data Scientist',
#   'company': 'C3 IoT',
#   'project': 'VerifyDocs: Keep it confidential',
#   'background': 'Applied Physics, University of Glasgow, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a707cef26c00010d6f4b_Chandra%20Natarajan.jpg'},
#  {'name': 'Claire Kunesh',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'Babble: Language detection with half a second of sound',
#   'background': 'Human Cognition and Development, UC Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a77199f89b0001b53073_Claire%20Kunesh.jpg'},
#  {'name': 'Di Mo',
#   'title': 'Data Scientist',
#   'company': 'LinkedIn',
#   'project': 'Startup Telescope: Future is now',
#   'background': 'Economics, Stanford University, Research Associate',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a807a7da9e000103d8af_Di%20Mo.jpg'},
#  {'name': 'Michael Bellato',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'RateMate: Bias estimator for online reviews',
#   'background': 'Cognitive Science, University of California, Irvine, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61aac2af17ff000151846e_Michael%20Bellato.jpg'},
#  {'name': 'Sabrina Aliyeva',
#   'title': 'Data Scientist',
#   'company': 'Synopsys',
#   'project': 'SmartAID: Poverty prediction from satellite images',
#   'background': 'Geophysics, Stanford University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61ab4cb318e10001feeb89_Sabrina%20Aliyeva-.jpg'},
#  {'name': 'David Cameron',
#   'title': 'Data Scientist',
#   'company': 'Netflix',
#   'project': 'Awesome Hockey: What to skip and what to watch in NHL videos',
#   'background': 'Energy Resources Engineering, Stanford, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a79caf17ff000151841c_Dave%20Cameron.jpg'},
#  {'name': 'Amruta Varudkar',
#   'title': 'Data Scientist',
#   'company': 'Acxiom',
#   'project': 'Evolutionary Biology &amp; Population Genetics, Stanford University, Postdoc\t',
#   'background': 'ArtPricer: Sell it already!',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a5edcef26c00010d6f31_Amruta%20Varudkar.jpg'},
#  {'name': 'Yvonne Lin',
#   'title': 'Data Scientist',
#   'company': 'Social Capital',
#   'project': 'BeautyExtract: A data product to empower customized skincare recommendations',
#   'background': 'Statistics, University of Waterloo, B.Math',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61acac55260a0001f3a1c2_Yvonne%20Lin.jpg'},
#  {'name': 'Adam Jacoby',
#   'title': 'Data Scientist',
#   'company': 'LinkedIn',
#   'project': 'Rapid Chat Made Slow: Extracting content from the chaos of Twitch chat',
#   'background': 'Mathematics, Temple University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a545af17ff00015183f7_Adam%20Jacoby.jpg'},
#  {'name': 'Alexey Shmelev',
#   'title': 'Data Scientist',
#   'company': 'Bosch',
#   'project': 'TireCheck: Check your tire wear in seconds',
#   'background': 'Mechanical Engineering, MIT, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a5b4b318e10001feeaff_Alexey%20Shmelev.jpg'},
#  {'name': 'Bahar Zarin',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'SignatureFood: Make sure you enjoy your meal!',
#   'background': 'Civil Engineering (Transportation), University of Maryland, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a6259cc897000135a5fc_Bahar%20Zarin.jpg'},
#  {'name': 'Chalence Safranek-Shrader',
#   'title': 'Data Scientist',
#   'company': 'FiveStars',
#   'project': 'TexanTurnout: Predicting the Voter Turnout Rate in Texas Elections',
#   'background': 'Astrophysics, University of California, Berkeley, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a6ccb318e10001feeb12_Chalence%20Safranek-Shrader.jpg'},
#  {'name': 'Charlie Hogg',
#   'title': 'Data Scientist',
#   'company': 'Rasa Networks',
#   'project': 'Pic My Plant: Growing a garden rooted in deep learning',
#   'background': 'Mathematics/Environmental Engineering, Stanford University, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a73229f09700016fd806_Charlie%20Hogg.jpg'},
#  {'name': 'David Christle',
#   'title': 'Data Scientist',
#   'company': 'LinkedIn',
#   'project': 'HitCoin!: Data mining Internet hype to find the next big cryptocurrency',
#   'background': 'Quantum Science &amp; Engineering, University of Chicago, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a7d1af17ff000151841f_David%20Christle.jpg'},
#  {'name': 'Jason Kamin',
#   'title': 'Data Scientist',
#   'company': 'Mercedes R&amp;D',
#   'project': 'Cairnfinder: An Alpinist&#x27;s Guide',
#   'background': 'Nuclear Particle Physics, CERN, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a8b7b318e10001feeb52_Jason%20Kamin.jpg'},
#  {'name': 'Jeff Camp',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'DiversifyMe: Interactive visualization of correlation between exchange traded funds',
#   'background': 'Chemical Engineering, Lawrence Berkeley National Laboratory, Postdoc',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a8ebaf17ff0001518446_Jeff%20Camp.jpg'},
#  {'name': 'Jon Witte',
#   'title': 'Data Scientist',
#   'company': 'Indeed',
#   'project': 'LiFT: The Lifting Form Trainer',
#   'background': 'Theoretical Chemistry, University of California, Berkeley, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a95255260a0001f3a192_Jon%20Witte.jpg'},
#  {'name': 'Ketki Sharma',
#   'title': 'Data Scientist',
#   'company': 'Remind',
#   'project': 'Q-tagger: Tag your questions',
#   'background': 'Environmental Engineering, Georgia Institute of Technology, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61a989b318e10001feeb6e_Ketki%20Sharma.jpg'},
#  {'name': 'Kirsten Smayda',
#   'title': 'Data Scientist',
#   'company': 'Pear Therapeutics',
#   'project': 'Gobble: Cookin&#x27; with data',
#   'background': 'Cognitive Neuroscience, The University of Texas, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61aa6699f89b0001b530e3_Matt%20Sims.jpg'},
#  {'name': 'Meghan Frate',
#   'title': 'Data Scientist',
#   'company': 'LinkedIn',
#   'project': 'InstaStudio: Instantly Find a Studio You&#x27;ll Love',
#   'background': 'Experimental Particle Physics, UC Irvine, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61aa9129f09700016fd85b_Meghan%20Frate.jpg'},
#  {'name': 'Michael Saha',
#   'title': 'Data Scientist',
#   'company': 'Facebook',
#   'project': 'LegalTech: Startup Consulting Project',
#   'background': 'Environmental Sciences, The University of Virginia, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61aaf4cef26c00010d6fad_Michael%20Saha.jpg'},
#  {'name': 'Yuwen Wu',
#   'title': 'Data Scientist',
#   'company': 'Intuit',
#   'project': 'EmailViz: Identifying employee relationships from digital communications',
#   'background': 'Neuroscience, Harvard University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5a61ac8099f89b0001b5310f_Yuwen%20Wu.jpg'},
#  {'name': 'Liz Baldo ',
#   'title': 'Data Scientist',
#   'company': 'Indigo ',
#   'project': 'Find Your Art: Discover artwork around you using transfer learning',
#   'background': 'Hydrology and Water Resources Engineering, UCLA, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea0bb0c496d138b7737895_Liz.jpg'},
#  {'name': 'Stephanie Sorenson ',
#   'title': 'Data Scientist ',
#   'company': 'Wayfair ',
#   'project': 'Churn-No-More: Discovering what drives customer churn vs. retention',
#   'background': 'Psychology, Stanford University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea0edb15754b2b27b0a8d5_Steph.jpg'},
#  {'name': 'Steven Felix ',
#   'title': 'Research Analyst ',
#   'company': 'Wellington ',
#   'project': 'Search Suggestor: Improving Stack Overflow search queries with natural language processing',
#   'background': 'Experimental Psychopathology, Harvard University PhD ',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea0f9be1278a491437b2d4_Steven%20.jpg'},
#  {'name': 'Tatyana Perlova ',
#   'title': 'Data Scientist ',
#   'company': 'Indigo ',
#   'project': 'MicrobeX: Exploring microbes across the globe',
#   'background': 'Physics, University of Illinois at Urbana-Champaign, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea108d33982ea4548eda7e_Tanya.jpg'},
#  {'name': 'Bridget Salna ',
#   'title': 'Data Scientist ',
#   'company': 'Cinch ',
#   'project': 'AdviceDice: Board game recommendations that leave nothing to chance',
#   'background': 'Physics, Northeastern University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea149815754b5960b0a958_Bridget.jpg'},
#  {'name': 'Esteban Urdiales ',
#   'title': 'Data Scientist ',
#   'company': 'IvySys',
#   'project': 'AirbnMe: Predicting Airbnb Occupancy Rates for Private Rooms in Chicago ',
#   'background': 'Applied Mathematics, Northwestern University, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea153a28214c2b52132d05_Esteban.jpg'},
#  {'name': 'Jason Rute ',
#   'title': 'Data Scientist ',
#   'company': 'CiBO',
#   'project': 'CallMeBackMaybe: Using natural language processing to classify call center phone conversations',
#   'background': 'Mathematical Sciences, Carnegie Mellon, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea15fd31c0a5f8ebd58802_Jason.jpg'},
#  {'name': 'Samta Shukla ',
#   'title': 'Data Scientist ',
#   'company': 'CVS Health ',
#   'project': 'SaReGaMood: Mood-based playlists for Indian classical music',
#   'background': 'Computer Systems, Rensselaer Polytechnic, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea2f96dc67fe0b51118364_Sam.jpg'},
#  {'name': 'Yossi Cohen ',
#   'title': 'Research Analyst ',
#   'company': 'Wellington ',
#   'project': 'Flightstitute: Risk management for flight disruption',
#   'background': 'Theoretical Physics, Weizmann Institute, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea31eaf11f7145b4269177_Yossi.jpg'},
#  {'name': 'Pawan Nandakishore',
#   'title': 'Data Scientist ',
#   'company': 'Colaberry ',
#   'project': 'Joke&#x27;s on you!: Identifying humor and inappropriate material in text',
#   'background': 'Fracture Mechanics, Max Planck Institute for Dynamics and Self Organization, PhD ',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea33ab94ab8a62e54dc571_Pawan.jpg'},
#  {'name': 'Margaret Kosmala',
#   'title': 'Data Scientist ',
#   'company': 'CiBO',
#   'project': 'Mountain Bike Forecast: Predicting riding conditions using weather data ',
#   'background': 'Ecology, University of Minnesota, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea38dadc67fe7114118436_Margaret.jpg'},
#  {'name': 'Wei He ',
#   'title': 'Data Scientist ',
#   'company': 'CVS Health ',
#   'project': 'Customer prioritization: Predicting a consumer&#x27;s propensity to buy',
#   'background': 'Physics, University of Massachusetts Amherst, PhD',
#   'imagelink': 'https://assets.website-files.com/575a31d2ce5d01dc7a20de4a/5aea3c5d7c0e4551ce0def14_Wei%20He.jpg'}]

# %%
fellowInfo = pd.DataFrame(insight['fellows'], columns=['name', 'title', 'company', 
                                   'project', 'background', 'imagelink'])

# %%
fellowInfo.head()
# Out:
#                         name                           title      company  \
# 0                    JP Bida                Director of Risk  Capital One
# 1              Douglas Mason                  Data Scientist      Twitter
# 2  Virot Ta Chiraphadhanakul                  Data Scientist     Facebook
# 3            Julia Viladomat                  Data Scientist        Adobe
# 4              David Freeman  Head of Anti-Abuse Engineering     LinkedIn
#
#                                              project  \
# 0  Measuring the Impact of Open Source Coders on ...
# 1  Email Searcher: Search &amp; Visualize Your Ma...
# 2  Tweet Timeline: Visualizing the Impact of Soci...
# 3           Sentiment Analysis Based on Social Media
# 4                             Flight Delay Predictor
#
#                             background  \
# 0       Bio-X Games, Stanford, Postdoc
# 1  Physics, Harvard University,Â PhD\n
# 2        Operations Research, MIT, PhD
# 3        Statistics, Stanford, Postdoc
# 4       Mathematics, Stanford, Postdoc
#
#                                            imagelink
# 0  https://assets.website-files.com/575a31d2ce5d0...
# 1  https://assets.website-files.com/575a31d2ce5d0...
# 2  https://assets.website-files.com/575a31d2ce5d0...
# 3  https://assets.website-files.com/575a31d2ce5d0...
# 4  https://assets.website-files.com/575a31d2ce5d0...

# %%
fellowInfo.shape
# Out:
# (791, 6)

# %%
fellowInfo.describe()
# Out:
#                name           title   company  \
# count           791             791       791
# unique          791             170       409
# top     Jolene Mork  Data Scientist  Facebook
# freq              1             435        54
#
#                                                   project  \
# count                                                 791
# unique                                                790
# top     IndieRecommender: Find Indie games like video ...
# freq                                                    2
#
#                                         background  \
# count                                          791
# unique                                         731
# top     Neuroscience, New York University, Postdoc
# freq                                             5
#
#                                                 imagelink
# count                                                 791
# unique                                                791
# top     https://assets.website-files.com/575a31d2ce5d0...
# freq                                                    1

# %%
fellowInfo['project'].values
# Out:
# array(['Measuring the Impact of Open Source Coders on Github',
#        'Email Searcher: Search &amp; Visualize Your Mailbox',
#        'Tweet Timeline: Visualizing the Impact of Social Media',
#        'Sentiment Analysis Based on Social Media',
#        'Flight Delay Predictor',
#        'Email Contacts Automatically Grouped &amp; Ranked',
#        'Analysis of New York Stop-and-Frisk Data',
#        'CouchTube: YouTube TV shows in one click',
#        'SchoolGeo: Empowering Parents to Make Informed Decisions',
#        'Event Map: Get Local News from Twitter',
#        'Sort My Friends: Automatically Organize your Connections',
#        'Flat Finder: Find Your Perfect Apartment', 'Kiva Loan Checker',
#        'Arrive in Time: Airport Arrival Time Predictor',
#        'STARtrack: Helping Educators Track Student Performance',
#        'Diverse Recipe Recommendations', 'Multi-Domain Recommendations',
#        'Stock Volatility PredictorÂ\xa0', 'Lower Your Electricity Bill',
#        'Find the Expert on Stack Overflow',
#        'RewindX: Rediscover Music From Your Youth',
#        'HipHopper: Find The Musicians You Have Been Missing',
#        'RouteAroundCrime: The Path Less MuggedÂ\xa0',
#        'FlockThink: Twitter Search Engine For Instant Sentiment AnalysisÂ\xa0',
#        'News Now: Scrapes the RSS feeds from popular news websites (CNN, FOX, etc.) in real time',
#        'RxDiscovery: Mining the FDA&#x27;s adverse event database to identify common side-effects for drug-drug interactions',
#        'BakeSearch: Stop Searching &amp; Start Baking',
#        'ReadTweetApp: The Tweets That Matter',
#        'TwinkedIn: Follow LinkedIn Contacts on TwitterÂ\xa0',
#        'CrimeVis: Visualization of Oakland Crime Rates',
#        'SkillRankApp: What You Need to Know For Your Dream Job',
#        'SerendipityEngineApp: Your Personal Travel Assistant',
#        'Barkov Chain: Bar &amp; Restaurant Recommendation Engine',
#        'Predicting Startup Outcomes on Crunchbase. Silicon Valley, Summer 2012',
#        'MyFacebookDigest: What You Have Missed on Facebook?Â\xa0',
#        'Neighbor Flavor',
#        'Stay Connected: The People You Remember Not to Forget',
#        'FlixPixie: &quot;Automagically&quot; Sort Photos',
#        'Sandwichly: Make The Perfect Sandwich',
#        'Yelp Personal: Personalized Yelp recommendations',
#        'GeoJobr: Finding a job in today&#x27;s economy',
#        'Dine-amic Food: Making food decisions easy using dynamic data',
#        'GameChooser: Intelligent viewing recommendations for NBA games,Â\xa0The University of British Columbia, PhD',
#        'Flop Buster: The box-office prediction app',
#        'Off the Beaten Path: Your personalized vacation planner',
#        'Gener-Rec: Greed is not good (at least for recommendation engines)',
#        'NewsTweet: Discover what&#x27;s happening right now anywhere in the world',
#        'Less-Sketchy: An early fraud detection web-app for apartment classifieds',
#        'Job Link: Find and Connect with Potential New Careers',
#        'Reddibility: Just the Q&#x27;s &amp; A&#x27;s, none of the BS',
#        'Flava: Find your Flava',
#        'Startup Sniffer: Transform gut-driven to data-driven investmentÂ\xa0',
#        'NuTube: Classifying recent YouTube videosÂ\xa0',
#        'ReviewSkimmer: Find what&#x27;s good or bad in a movie, before it&#x27;s too late!',
#        'InspectorGit: Discover Github&#x27;s awesome repositories',
#        'PlacePickr: Helping couples decide where to liveÂ\xa0',
#        'Who&#x27;s On First: Predicting the outcomes of baseball&#x27;s batter-pitcher matchups',
#        'DinnerDetente: Easing the strained relationship between healthy and delicious',
#        'DealSpotter: Find rare deals on Craigslist... the easy way',
#        'ParkSafely: Bicycling in San Francisco? Park where theft is less likely',
#        'Tweather: Current local weather tweets',
#        'BeerInsight: Recommending exploration of obscure craft beer',
#        'TopOfTheStack: Find Stack Overflow questions to answerÂ\xa0',
#        'HypeControl: Identify bias in the news you readÂ\xa0',
#        'PredictMyLineup: A fantasy football lineup optimization engine',
#        'HotHoods: Forecasting neighborhood trends in housing prices',
#        'BargainMeal: Great deals on top rated dishesÂ\xa0',
#        'Delay Me Not! Providing flight day predictions at ticket purchase time',
#        'HummingBirds: Getting the latest news about trends on TwitterÂ\xa0',
#        'AmazonComparer: Short &amp; sweet product reviews',
#        'ThisPlusThat: Amazing conceptual searching with natural languageÂ\xa0',
#        'PopularNow: Get great content from Twitter NOW!',
#        'DailyFaces: The people in today&#x27;s news.',
#        'EURoute.me: Make the most out of your Europe trip!Â\xa0',
#        'OldFaveNewPlace: Find restaurants in a new city similar to ones you like in a different city',
#        'NewsSpectra: Find news at your level.Â\xa0',
#        'Git-A-Friend: Find friends/collaborators on Github',
#        'CrowdMinr: Make a great return on your investment with peer-to-peer lending',
#        'OnLocation: How to see where your favorite movies were filmed.Â\xa0',
#        'WhatGives: Predicting the funding success of Kiva loans.Â\xa0',
#        'ForecastingTomatoes: Predict how your film will be received',
#        'Healthy-Me: Making health discovery easy',
#        'LinkedInsight: Find the skills and connections that matter',
#        'InvestWiser: Predicting series A crunch outcome.',
#        'NewsLine: Automated timeline that provides you context of news topics.',
#        'Happy.li: Helping couples decide where to work and live together... and live happily ever after',
#        'FareBeast: On the prowl for the lowest airfares',
#        'PickYourFiction: Find a book you&#x27;ll love!',
#        'DJ-Cloud: Discover popular music albums with cloud computing',
#        'Two-lu: Movie recommendations for two!Â\xa0',
#        'dogWalkScore: Find the neighborhood for you and your dog.Â\xa0',
#        'BeeHealthy: Join the hive, get healthy!Â\xa0',
#        '$trategy: Get notifications on when to buy/sell a stock.',
#        'KickFinder: Kickstart the perfect project',
#        'RelaxedParking: Parking assistant to avoid traffic tickets and car-related crimes',
#        'GroupDine: Giving restaurant suggestions to a group of people based on their Instagram posts',
#        'BurstingTheBubble: Recommending news articles from outside your bubble',
#        'Wikiphilia: Scoring Wikipedia Page Quality',
#        'HealthImpact: Expediting medical care for those in need',
#        'EdXPredictor: Predict your performance on edX courses',
#        'StreetsAhead: Image recognition with deep learning in Street View',
#        'Jaunt: Recommendations along the way!',
#        'CharityVerity: Predicting charity ratings to guide effective altruism',
#        'CrowdSkippr: Minimize crowds, maximize joy',
#        'RxFX: Prescription Drug Recommendations &amp; Side Effect Discovery',
#        'Math.StackExpert: Finding you high-quality questions on Math',
#        'Lenderstanding: Helping lenders help',
#        'Price Wizard: Recommends the highest price to post on Craigslist for selling furniture items',
#        'Cluster-Pluck: Disambiguating Twitter Search',
#        'Steal-This-House!: Crime doesn&#x27;t pay...&#x27;cept for your bottom line!',
#        'TapMapper: Find out what the locals are drinking/tweeting',
#        'AmazonExplorer.info: A deeper look into Amazon product review history',
#        'Green Machine: Removing the barrier to solar energy estimation',
#        'git-discover: Unlock the potential of Github',
#        'Should I Kick or Should I Go?: Optimize your crowdfunding campaign',
#        'DrugScope: Scope out your medicine before taking it!',
#        'What&#x27;s for Dinner: Dinner recommendations to meet daily nutrition goals',
#        'AdNet: Graph recommender for news domains',
#        'GradeExpectation: Piazza forum analyzer',
#        'TruValuation: Predict the true value of your home',
#        'MelodyMapr: Improving the road trip experience',
#        'SearchPy: Search for related python code on Stack Overflow',
#        'UpFindr: Find the best activity partners on Meetup.com!',
#        'SetList: Set your life to music',
#        'Hoppr: Optimize route for running errands',
#        'LinkBooksMovies: Book recommendations if you like a certain movie',
#        'VentureNetwork: Recommend high potential startups based on investor&#x27;s portfolio',
#        'FindMyPoem: Finding the poem that fits your mood and preference',
#        'abstrART: Bringing price transparency to the art market',
#        'childHood: Finding a kid-friendly place to live',
#        'CraigFlagr: Check flag potential of Craigslist posts',
#        'Drugged-up: Know what&#x27;s in your drugs and how that might make you feel',
#        'Q-Schools: Learn English through Sign LanguageÂ\xa0',
#        'nimi: Everyone has a name, your kid needs a great one!',
#        'cities4me: Discover cities based on your interests!',
#        'Career Wizard: A career path recommender',
#        'HOSPARENCIE: Transparency in hospitalization fees',
#        'Neutral_Opinion: Visualizing opinions on net neutrality',
#        'Rain: Real-time radar-based precipitation forecasting',
#        'The Flavory: An ingredient recommendation factory',
#        'Yelper Helper: An engine for tailored Yelp Reviews',
#        'Customized running route recommendation system',
#        'okmeeple: Don&#x27;t leave it to chance; find your perfect board game match',
#        'edu Intervention: Identifying at-risk students to improve graduation rates',
#        'MillionDollar$tory: Maximizing the profitability of your movie',
#        'Active GitHub: Predicting future development activity of GitHub projects',
#        'HomewardBound: Helping predict and promote dog adoption',
#        'Ticket Me If You Can: Fending off parking tickets in NYC: Could you get away with it?',
#        'CrossingGuard: Routes around New York City&#x27;s most dangerous intersections',
#        'Locality Lookout: Identifying high priority complaints in your area',
#        'Basketball ROI: Assessing the risk of injury for players in the NBA',
#        'Ravel Me: Your knitting pattern recommender',
#        'YC Predictor: Predicting the likelihood of a Y Combinator participant remaining in operation',
#        'Empowering Embedding: A billion recommendations per month',
#        'MyReviewRater: Uncovering helpful Amazon reviews',
#        'WhoDoesMyHair: Find the most popular stylist in a hair salon',
#        'PicPickr: Find your best photos faster!',
#        'tripsift: TripAdvisor made simple - so you don&#x27;t have to read it all',
#        'Improving power management of Lockitron',
#        'STRAVA buddies: A workout partner recommender for runners and cyclists',
#        'Zidisha - Identifying sustainable interest rates to help small businesses grow!Â\xa0',
#        'Candidate Summary: Get a quick overview of Congressional candidates',
#        'Embarkov: Plan your whole trip in one click!Â\xa0',
#        'The Muse: Content recommendation algorithm for TheMuse.com',
#        'Churn Prediction at Strikingly: Reducing costs of retention strategies',
#        'AveNeue: A walking tour itinerary recommender',
#        'The Smarter Watch: Increasing user engagement on Pebble',
#        'Foodgroupr: Finding great local neighborhoods to eat and drink',
#        'RisingAll-star: Predicting rookie players&#x27; likelihood of becoming future NBA super stars',
#        'Run Findr: Discover running routes like a local',
#        'This is Happening: Discover social hotspots in the real world!',
#        'BookMatchr: Helping you maximize the success of your book',
#        'dr-findr: A web app that helps you find the doctor you need, and avoid the ones you don&#x27;t!',
#        'Price My Ticket: Smartly selling your SF Giants tickets',
#        'HammerPricer: Predicing auction prices for Abstract Expressionist art',
#        'Managing loan inventory at Zidisha',
#        'lastingloans: Fraud detection for Zidisha',
#        'Rewinder: Wind through your city&#x27;s history',
#        'SupremeBrief: Solution for legal case summary',
#        'How To Strike: Optimizing a directed e-mail campaign',
#        'Community Matters: Focus your outreach',
#        'Oh, The Places You&#x27;ll Go!',
#        'FantasyFilm: Can you make a better film than Hollywood?',
#        'IndieRecommender: Find Indie games like video games you already love',
#        'beautifulcity: Discover street art all around the world',
#        'eggCite: Hatching medical knowledge',
#        'stumbLr: Where will you stumbl next?',
#        'Prep Fo/r/ DIY: Find relevant content to plan your next hobby or home-improvement',
#        'runSmartr: Better running routes through data',
#        'kosha: Discover the foodie in you',
#        'Bitcrumbs: Follow the bitcoins',
#        'UnicornHuntr: Predict the success of early-stage startups',
#        'Fairbnb: Fair price for renting out your lodging!',
#        'Ovrvue: Automatic content filtering for a safer Internet',
#        'mixTunes.in: Find your new groove',
#        'Connected Graph: Identifying user connections for YesGraph',
#        'I&#x27;mfeelinghungryy: Don&#x27;t know what to eat? Food for your mood!',
#        'RespawnInto: Tired of playing your favorite game for the 10th time? Respawn into a new favorite',
#        'Analytics for Tindie.com: If you build it, will they come?Â\xa0',
#        'Inn Transit: Optimizing your accommodation options in walkable cities',
#        'ATHOS gear: Logging your workout with wearable EMG techology',
#        'the Blogtimize/r/: Find your audience and test the relevance of your blog',
#        'Food Findr: Connecting people to the dishes they love',
#        'Simterial: Empowering material scientists to change the world',
#        'Named Entity Recognition: Classify and search for that entity with conditional random fields',
#        'Zidisha: optimizing the interest rates on microloans',
#        'Next Match: Finding out how to win your next match',
#        'Pharmdout: Classifying and predicting active pharmaceutical ingredient shortages',
#        'LocalFeel: LocalFeel helps you find the places locals love',
#        'Pebble App Search: Find best apps for your Pebble watch',
#        'Analyzing Analysts: Understanding the Queriers Behind the Queries',
#        'haven&#x27;t reddit yet: A subreddit discovery engine',
#        'Lending Lounge: Saddle Up to Bigger Returns',
#        'CragCrunch: Discover new rock climbing routes for you',
#        'descri.beer: Beer discovery, not beer geekery',
#        'Check your tone!Â\xa0Assigning sentiment to anonymized and masked text messages using emoticons.',
#        'NestPricer:Â\xa0Helping new residents estimate their rent given the desired amenities.',
#        'Airbnb Local: Chrome extension to recommend nice neighborhoods for visitors',
#        'Flight or Plight: Ensuring weather, congestion, and bad luck won&#x27;t ruin your vacation',
#        'Stellar NPO: Predicting financial viability of non-profit organizations for Guidestar',
#        'FutureCast: Predicting the rate of city-wide events based on historical data',
#        'Grapevin: Your crowd-sourced sommelier',
#        'grumbl: Complaint predictor for Queens, NY',
#        'H-1B Ready: Anticipating work visa demand',
#        'instaNYC: Find live NYC events using Instagram',
#        'CourtCast: Predicting Supreme Court decisions',
#        'TutorWorthy: Know your worth',
#        'What the Hashtag: Brand Media Monitor',
#        'PebbleAppTailor: A usage-based recommendation tool',
#        'FriendYourVote: Mobilize voters in your social network',
#        'Restaurant Radar: Making Yelp reviews useful and actionable',
#        'More Matildas: Find kidlit with more girl characters',
#        'Curatir: An art recommender for NYC',
#        'onTimeTravlr: Planning around New York traffic',
#        'In Other News: Broaden your horizons by reading like a writer',
#        'shoely: Improving your online shopping experience by learning what you like',
#        'TopCop: Boston&#x27;s crime analysis and prediction program',
#        'graphshopper: A graph-based recommendation engine for a local e-commerce startup',
#        'No Parking Zone: Safer parking in Boston',
#        'Cli-Migration: A recommender for the climate exodus',
#        'beersomme: Find a bar, drink awesome beer!',
#        'SmartSourcery: Data-driven job sourcing recommendations',
#        'Kickwrangler: Predict which Kickstarter projects won&#x27;t deliver their products',
#        'Trendalyzer: Find unique and targed trending topics',
#        'Canary: The inactivity early warning system for Twitter',
#        'AdClickMe: Mobile advertising click prediction and ad recommendation',
#        'Zidisha&#x27;s Lenders: Lender retention and growth at Zidisha',
#        'Fuel Your Startup: Connect with your next investors',
#        'The Tipping point: Predict whether upcoming Congressional bills will be a close call',
#        'TLDR: The site for people that want more Karma',
#        'URX: Detecting actionable webpages',
#        'Football Fit: Discovering the winning components for an NFL team',
#        'Next Best Store: Predict where your next store should be',
#        'Riffsy&#x27;s GIF for Messenger App: User Engagement Analysis',
#        'Fantasy Forecaster: Predict NBA player performance to make better bets',
#        'Locals Know: Discovering hidden gems in Paris without speaking French',
#        'Muse.ai: Classifying scenes and tracking faces in video',
#        'Rally: Rapid protest detection',
#        'Waggle: Your personalized garden planner',
#        'TextFit: How will your comment fit in the community?',
#        'PlayPredict: Predicting performance of basketball players in real-time',
#        'Job2vec: Matching algorithm for Weave.in Concierge',
#        'VAMmer: The first cycling climb predictor based on real power-to-mass data',
#        'Scene Hash: Find live shows based on any artist',
#        'Churn Modeling: PRedicting customer churn for Salesforce usage data',
#        'WhatsInMy.pics: Finding relevant images and tags based on image content',
#        'Reputon: Rating predictions for Airbnb',
#        'Weld: Finding patterns in calendar data',
#        'WhereTo.Photo: Where is the best place to take a picture? WhereTo.Photo tells you based on Flickr Data!',
#        'We Lose It: A Social Tool for Weight Loss',
#        'Parental Guidance: Finding Yelp reviews written by parents',
#        'Campus Job: Key features in on-line job listings',
#        'Pageturner: Automated sheet music scrolling',
#        'rep-present.us: Find out what your state representative is pushing in the legislature',
#        'ListToClose: How much will a house get bid up before selling?',
#        'artumbl.r: Your personal art discovery engine',
#        'Random Walk: Find your next adventure',
#        'MeterSure: Predicting faulty water meters in North Carolina',
#        'MealTime!: Know when your food will arrive',
#        'Microlending Fee Optimizer: Optimizing a flat fee for a microlending non-profit',
#        'Can I Solar?: Helping you decide if solar power is right for you',
#        'Schoolstradamus: Forecasting a school&#x27;s future performance',
#        'underServed: Where to open a restaurant?',
#        'WillThereBeSpace: Find an estimate of future Citibike availability',
#        'ImmerseSpace: Immerse yourself in music that fits your mood and preferences',
#        'Vacadvisor: Budget based vacation recommender',
#        'ClientHuntr: Identifying target customers for a large pharmaceutical company',
#        'infervote: Democratizing democracy, a resource for political engagement',
#        'SciClarify: Scientific writing made clear',
#        'ClimbFindr: There are many ways to climb high, find the line that is right for you',
#        'Kick Stronger: Kickstarter campaign success prediction and actionable insights',
#        'wealthScore: Find prospective clients in your professional network',
#        'FundAClassroomToday: Inspire your supporters on DonorsChoose.org',
#        'HouseClickr: Finding engaged users',
#        'CraigPredict: Sell your car faster(er)',
#        'Achieve the Weave: Bringing social networks together',
#        'Renew or Cancel: Predicting the success of primetime television series',
#        'cReddit Score: Flag hurtful comments before they are posted',
#        'Call Me &#x27;Click&#x27; (Maybe): Identifying Events Across Mobile Apps',
#        'Scopos: Pandora for job search',
#        'GoodReviews: Deliver the most useful positive and negative book reviews',
#        'Virtual Wine Taster: Can we predict how good wine tastes from its chemical properties?',
#        'GetMeThere: Help people decide whether they should take a cab or a metro',
#        'PicturePerfect: Recommending images based on what a user has already seen',
#        'Count My Student: Predicting student application count based on profile information',
#        'Empower edX: Increasing student engagement in massive open online courses',
#        'Now Looking for Players: Ditch the forums and find a friend fast',
#        'Surf the Crowd: Predicting campaign outcomes on GoFundMe',
#        'Predicting Pedestrian Risk in SF: Finding out how safe it is to cross the road',
#        'Insights from DonorsChoose: Boosting funding opportunities for LA teachers and students',
#        'How to make a tailored TED talk: The secret of making a contagious TED talk',
#        'Forecasting Demand: A data-driven model to forecast the demand for the products of a subscription e-commerce startup',
#        'Self-Regulate: Your way to an informed purchase power',
#        'Talking points: Capture the conversation',
#        'Text Spotting: Facilitating computer indexing of text in images and videos',
#        'ScenicStroll: Discover the best scenic walking tours to explore your area',
#        'Game2Table: Recommending boardgames your entire group will enjoy',
#        'HealthSherpa: Predicting healthcare expenditure',
#        'Cambly: Rating English tutors with user and tutoring session data',
#        'Move Loot: A predictive model for data-driven logistics',
#        'BakeAgain: Summarizing recipe modification from comments on recipes',
#        'Ski in Solitude: Helping you find the slope less travelled',
#        'MyViewBNB: Find airbnbs with a great view',
#        'Buskerbot: Find awesome music near you',
#        'TindArt: Find your art match!Â\xa0',
#        'Sound Measure: Gecoding insights from consumer spending',
#        '#Holla-A-Hashtag: Holla Away! Search Twitter today!',
#        'YouTube Matchmaker: Recommending Youtube channels with the same &quot;IT&quot; factor, using community detection',
#        'doglodge.io: Find the best place to stay with your dog',
#        'Keyword Finder: Automatic keyword extraction- no alchemy required!',
#        'RadiumOne: Find converters through domain clustering based on network population',
#        'LifeScholar: Organize the world&#x27;s learning, one online course at a time',
#        'LazyChef: Making the most with what you&#x27;ve got',
#        'Catch-A-Catfish: Protecting you from malicious dating profiles',
#        'Wheretobiz: Where do you want to open your new business?',
#        'TaggerNews: Automatic tagging system for Hacker News',
#        'Doc Topics: Find a good doctor by summarizing Yelp reviews',
#        'GitWatch: Revealing where to contribute to open source projects',
#        'buzzeat:Â\xa0Find the dish you crave',
#        'Zidisha: Predicting microloan defaults &amp; estimating average default loss per borrower',
#        'DogHaven: Your dog will love this place',
#        'BidMeUp: Predict the probability of success of online auction bids',
#        'HackYrNews: Build your personalized feed for Hacker News',
#        'ViceMatch: Find the perfect cigar for your whisk(e)y',
#        'Balancing the Load: Optimizing the micro-finance supply and demand',
#        'That&#x27;s for dinner: Maximal inspiration in minimal time',
#        'Textbooks Unchained: Find free textbooks with the help of recommendations from Amazon',
#        'BKrawl: Krawling smarter and safer', 'LegoMe: LEGO set futures',
#        'Back Tweet Driver: Refining tweets to improve the chance of a retweet',
#        'HedgeClone: Hedge fund return predictor',
#        'LESS: Learn English smarter and swiftly',
#        'almostPerfect: Finding the worst in Amazon&#x27;s best',
#        'PBFree: Find your lead-free home',
#        'iAppreciate.NYC: NYC neighborhood real estate price appreciation predictor',
#        'FlavorFindr: Discover your flavor profile',
#        'RailActive: Empowering NJTransit with train delay forecasting',
#        'ChemCast: Predicting user experience',
#        'CrabPredictor: Predicting the blue crab population in the Chesapeake Bay',
#        'MakeMyDay: A DIY-project finder for the Maker in all of us',
#        'Feature Rank: A pipeline to analyze word features in online corpora',
#        'HealthSavR: Putting healthcare consumers in charge',
#        'BirdSpottr: Optimizing your search for bids',
#        'cityspinneret: Matching neighborhoods across cities',
#        'RideSmoothly: Avoid pothole-ridden routes on your commute',
#        'Forecast My City: A city economic predictor',
#        'CafeSnob: Finding your new favorite coffee shop',
#        'App Lift: Estimating app installation probabilities',
#        'ParkPic: Setting the scene for photographers in US National Parks',
#        'Legislator Prognosticator: Examining campaign donations to predict which laws get written',
#        'Illseeitall: Optimize your schedule to see the greatest number of sites',
#        'GoGuardian Consulting Project: Keep students on track with real-time insights into web browsing activity',
#        'NoiseFreeNYC.com: Noise free apartment finder',
#        'Churn Signals: Identifying actionable signals on churn for an e-commerce company',
#        'Understand your Brand: Understand what users are tweeting about your brand',
#        'FindYourNextShow: A Local Live Music Discovery Tool',
#        'League Coach: Play at a higher level',
#        'Sports Rankr: Improving college football ranking metrics',
#        'TaxiOrNot: Predicting the user&amp;#39;s next event location',
#        'ClickInsight: Increasing link clicks on Facebook news posts',
#        'WalkSafr: Finding safer walking routes',
#        'Smartan: A smart workout recommender',
#        'kittyTwin: Find a feline friend that looks just like you',
#        'Vacation Finder: Find vacation destinations based on your interests',
#        'GitRecruit: Finding potential recruits using Github',
#        'BackMeUP: Backing music tracks customized for emotion',
#        '@Candidates: How twitter users tweet at presidential candidates',
#        'FastMatch: Pairing Algorithm for people to extend professional network.',
#        'CleanSleep: Clean Hotel finder based on Tripadvisor reviews',
#        'Photosifter: Which images engage your customers the most?',
#        'Pony Pricer: Predicting sale prices for ponies ',
#        'Learning customer service through topic modeling of tweets: Topic learning of tweets to rank airline services',
#        'Air Gourmet: Tasting your recipe before cooking it!',
#        'Airbnb Host Helper: Find the gaps and make your place stand out on Airbnb',
#        'NameOurPrice: Price it quick and right!',
#        'EatAspex: An in-depth comparison of restaurants',
#        'Wallet.AL: Better decisions. More happiness',
#        'LendingHand: Helping you invest in Lending Club loans',
#        'Magic Bus: Visualizing demand for long-range alternatives to public transportation',
#        'Consulting with a Meeting Tool Startup: Predicting user retention when using a meeting collaboration tool',
#        'DealWheels: Used Cars Online-Great deal?',
#        'Restaurant Roulette: Take the risk out of dining!',
#        'BusUnBunchr: Optimizing transit trips on the SF Muni',
#        'Passearch: Finding passengers for taxis',
#        'MouseTrek: A real-time route optimizer for Disneyland',
#        'Second Hand Arbitrage: Finding the best arbitrage opportunities among neighboring second-hand markets',
#        'The Great Divider: Sifting conversations about politics',
#        'One Signal: Optimizing Notification Timing',
#        'Storm Sentiment: Exploring regional attitudes about weather events',
#        'Travel Safe: The safest way to travel',
#        'Aletrail: Your path to discovering beer brewed in California ',
#        'Default Detection: Predicting micro-loan fraud for Zidisha',
#        'Relevance in Ads: Prediction relevance in mobile ads',
#        'IndieRecommender: Find Indie games like video games you already love',
#        'BeerSeer: Discover what beer you should drink next',
#        'FanGuard: A Smart Spoiler Filter for Tumblr, Intelligently predicting spoilers without a &quot;spoiler warning!â\x80\x9d',
#        'ezhome: Smart Gardening: An affordable, weekly gardening service led by expert horticulturists',
#        'HomeTRAC: Find your perfect street',
#        'TakeNote: Cliffnote for video lectures',
#        'DogMeetup: Find the best dog meetup location/time',
#        'AmURA: Leveraging product review data to maximize customer satisfaction.',
#        'ResLearning: Predict your Yelp ratings and offer suggestions to improve it.',
#        'Polling Patients: Elevating the healthcare experience.',
#        'Mooditter: Tracking the pulse on Twitter mood.',
#        'Polytweet: Predicting political party allegiance from social media data.',
#        'Pivot: Build a better NBA fantasy team with science.',
#        'Abstraction: Making scientific literature accessible.',
#        'Pothole Predictor: A tool to forecast New York City&#x27;s pothole problem.',
#        'As the drone flies: A tool for drone route optimization.',
#        'Toxic Docs: Search de-classified documents on industrial poisons.',
#        'BarGraph: Measuring Brooklyn neighborhood nightlife.',
#        'A City for All Seasons: Connect with local culture any time of the year.',
#        'PhotoWalk: Get there prettier.',
#        'OptDoTa: DoTa 2 playstyle-based hero recommender.',
#        'LANDSAT-landstats: A population measure you can count on.',
#        'Trip-A-Wiser: A wise trip planner',
#        'clickMe: Improving SmartAssetâ\x80\x99s click-through rate.',
#        'PicSift: Does your photo make the cut?',
#        'Count â\x80\x98em Up: Traffic estimation for PiinPoint.',
#        'Le&#x27;ggo: Find events and venues in Manhattan',
#        'ValuesAi: Target the right voter.',
#        'StayEstimate: Predicting patient length of stay in hospitals.',
#        'Annoisy: Find a quiet spot in NYC.',
#        'Humor Me: Comedy analytics and recommendation.',
#        'Pearings: Intelligent ingredient combinations for home cooks.',
#        'memoryPower: Tracking Parkinsonâ\x80\x99s wellness using a mobile app memory game.',
#        'chooseU: Pick the best university for you',
#        'Predicting micro-credit limits: Harnessing social information to create a new form of lending',
#        'DarkNet: Tracking the underground drug trade',
#        'FriendOrMate? Where does your customer live?',
#        'FRIDAY: Predicting Saturday&#x27;s Games, Today',
#        'SafeDining: Finding safe dining places in your neighborhood',
#        'NYCeats: choose your dining crowd in New York City',
#        'SafeParking: Find a safe place to park',
#        'Keep Users: Helping a young startup grow',
#        'Multi-touch attribution with Interstate Analytics: Giving credit where it&#x27;s due',
#        'Bot Or Not: Detecting Fraud on Social Media',
#        'Adding variety to a menu: How (and why) to make a model less accurate on purpose',
#        'Thesauropod.us: A thesaurus for podcasts',
#        'Panderer&#x27;s ToolBox: Tailored messaging powered by data',
#        'CheckMyResume: make your resume stand out',
#        'PacePlannr: Personalized Pacing Strategy for Recreational Marathoners',
#        'storyStackr: fight writerâ\x80\x99s block and find your readershipâ\x80\x99s favorite topics',
#        'date|nite: find the right restaurant, for the perfect moment',
#        'Retention prediction with new Branch8 seller profiles (consulting)',
#        'FactCheckIt!: Because People are Parrots',
#        'Snotelier: Automated avalanche danger summaries',
#        'One Signal Consulting Project : OneSignal audience segmentation',
#        'mediSell',
#        'CourseBoost: Predict and improve student enrollment in online courses ',
#        'Predicting User Spending for OneSignal: Estimating using value in mobile apps &amp; determining feature importance for segmentation',
#        'Insights for All: Providing data-driven insights to non-specialists',
#        'DescribeYourBar: Search and explore bars using natural language ',
#        'NameFixer: Fixing messy merchant names in financial transactions',
#        'Underground Cellar: Finding wine enthusiasts among wine hobbyists',
#        'iSee: Deep Learning algorithm for virtual mirror eyeglass removal ',
#        'FontFinder: Search engine for fonts by similarity',
#        'BackerKit: Identifying indicators of user conversion',
#        'Punchometer: Improving classification of complex motions using accelerometer data',
#        'Truebill: Subscribe Better',
#        'Tall Idea Labs: Understand and respond intelligently to consumer questions on e-commerce websites',
#        'Find That Video: Search music videos by description of scenes in videos',
#        'Unleash Your Inner Rockstar: User retention and churn at a mobile app startup',
#        'Find My Ride: Helping bike share users find a bike when they need it',
#        '/u/Who: finding redditors who think alike',
#        '#WhatTheHash: Find relevant, trending hashtags to maximize exposure of your tweet!',
#        'Parking Predictor: Find available parking spots in San Francisco',
#        'Automatic Email Sorting: Identifying crucial emails with natural language processing at 93% recall rate',
#        'Weeding Leads: Prioritizing sales calls for ezhome gardening',
#        'SolSearcher: Solar market info from satellite imagery',
#        'Lendeviance: Fraud Detection in Lending Club Data',
#        'DeepGram: Unsupervised speaker segmentation of recorded conversations',
#        'mCeption: Machine Learning on Machine Learning',
#        'Making Universal Education a Reality: prioritize countries to increase offline access to Khan Academy courses ',
#        'Businesses on Venmo are not your â\x80\x9cfriendsâ\x80\x9d: Identify businesses posing as &quot;friends&quot; on Venmo',
#        'Virtual Mirror: The future of retail',
#        'Fly Smart, Avoid Delays: Predicting flight delays leveraging weather forecasts',
#        'Ask Stack Overflow: Help refine your to-be-posted question on Stack Overflow',
#        'Prospecting Leads Intelligently: Leveraging machine learning for B2B sales and marketing lead generation',
#        'ProductPredictr: Classifying retail products based on images and text',
#        'L&#x27; Tron - CTA: A Friendly Bot with an Eye on Chicago&#x27;s &#x27;L&#x27;',
#        'FaultFindr: How might this laptop fail?',
#        'MetaPizza: Find the best pizza in New York',
#        'nspectr: Inspecting restaurant health violations in Boston',
#        'setlistÃ¶r: Know the songs before you go',
#        'WiseWidgets: Matching readers to relevant financial tools',
#        'commentizr: Optimize borrower comments to make Zidishaâ\x80\x99s lenders lend again',
#        'Legislatr: Will a bill pass and who paid for it?',
#        'Public Comments tl;dr: Helping federal agencies summarize public comments',
#        'Toxic Docs Relationship Miner: Extracting structure from toxic text',
#        'ClassCorrect: Fixing classification errors',
#        'Meet me where? Plan less, meet there.',
#        'CovirTu: A better way to insure farmers against drought',
#        'Philanthropy Filter: Classifying news articles and extracting organization names',
#        'HigherMe Applicant Rank: Finding the best interview candidates',
#        'In Lyrical Terms: How popular are songs about [term]?',
#        'AutoProCure: Easing the pain in tagging contract-bid requests',
#        'TicketForecast: Helping baseball fans know when to buy tickets to the game',
#        'The Opinionator: How will your opinion fare?',
#        'RestaurantRev: Predicting new restaurant revenue by location',
#        'AutHER: Who gets read more in hgher education?',
#        'Song Proffr: A recomendation engine for the best place to find new music on the web',
#        'Busy Cab: An app to help yellow cab drivers pick up passengers',
#        'NYC Real Estate: Buy or Wait?',
#        'Where They Ain&#x27;t: Batted-Ball Luck in Major League Baseball',
#        'AboutFace: Identifying and tracking faces in YouTube videos',
#        'Nerdventures!: Nearby Events for Introverted People (in Seattle)',
#        'Automating Recommendation: Replacing a hand-built decision tree with a robust machine learner',
#        'polibot: Can you distinguish between our future President and a Bot?',
#        'TapPy: Predicting New Republic Brewery revenue to anticipate staffing needs',
#        'Staff-Me-Right: Optimizing Staffing at San Diego 911 Call Center',
#        'Concertrip: A road trip concert finder',
#        'theDataMuncher: Interactive Data Analytics Platform',
#        'H2OhNo!: Improving meter tampering predictions. ',
#        'ActiveMe: Combine fitness tracker data and weather for exercise optimization',
#        'GoodNews: Defining features affecting audience engagement with public radio news reporting',
#        'Coming To Terms: Recommending optimal loan terms for crowdfunded projects',
#        'ConsciousChef: Make the best of your CSA box',
#        'Venmo No-Nos: Identifying fraudulent users on Venmo',
#        'Jobmash: Job searching without the pain',
#        'SafeWalk: Find your safest route for any time of day',
#        'ToxicDocs: Unearthing history from document dumps',
#        'Market Insight: Visualise the potential of NYC restaurant markets',
#        'PolarizedText: A tool for word embedding and anonymization',
#        'Etsy Art Shark: Estimating the market value of paintings',
#        'Get the loan down: Assessing default risk for Zidisha&#x27;s microfinance borrowers',
#        'A.I.tendance: Attendance forecasting for art house movie screenings',
#        'Clever Forecasting: Predicting back-to-school user growth for Clever',
#        'Tweet Off: Classify tweets and track hashtags over time',
#        'Next Buy: Recommend your customer&#x27;s next purchase',
#        'LITALI: Legal Talk Listener: Find the right legal help',
#        'Jamify: Learn to play your new favorite songs',
#        'Bibli: Judge (and classify) a book by its cover',
#        'GrowthPoint: Find the best location to start a restaurant or retail business',
#        'IdentifyABill: Classify New York state legislation to identify bills by subject area',
#        'EngageM: Causal explanations for user engagement on social news websites',
#        'PartyPoll: A tool for campaign strategists',
#        'VanGo: Autocurating your art experience',
#        'NPO Grow: Better business decisions, faster for non-profits',
#        'whetherChannel: The coverage you want. The subjects you care about.',
#        'CrimeTime: Using historical data to predict NYC crime rates',
#        'BidPredict: Predicting the price of a defense contract',
#        'FeatureTeacher: Raising the bar on education.',
#        'Collide-O-Scope: A window into real-time traffic hazards',
#        'Homewords', 'TopicHat', 'The Antenna Landscape',
#        'The Perfect Fit', 'Spotsor', 'Find My Grub',
#        'Locate: Trending Upwards', 'CornCalc',
#        'Increasing video engagement', 'Know Thy Gardener', 'Analyze This',
#        'tweetView', 'Textmote', '&quot;Gold plated baby&quot;',
#        'DetecTrend', 'Say What?', 'SpeaKey',
#        'Predication for Non-payment Utilities Cutoff', 'Lift My Video',
#        'DressMe!', 'TargAd', 'GOATCheck', 'ArtPath', 'Image-AI',
#        'InjuryCast', 'Castle', 'WhereSIOUS', 'Freight Rate',
#        'Smooth Ride', 'CleanStreet', 'Non-trivial Pursuit', 'MusiCon',
#        'RedCarpet', 'LiveBeat', 'beaut.ai', 'Fleetr',
#        'Dupe Snoop: Identify repeated questions on Quora',
#        'Slack Police: You have the right to stay on topic',
#        'MatchMade: Practice with the best partners to ace your coding interview',
#        'Save Our Sensor: Early detection of battery failure in remote temperature sensors',
#        'News Snap: Your auto-curated daily news briefing',
#        'Sifting the Overflow: Highlight helpful parts of Stack Overflow answers',
#        'Hive Mind: Using social media data to predict if Hiveâ\x80\x99s users will buy',
#        'Predicting worker churn: Will they stay or will they go?',
#        'Anti-social capital: Flagging potential fraudsters in the Moneypool app',
#        'bigLittleTransport: A smart shuttle dispatcher',
#        'NYC Air-Traffic Control: Strategic road restrictions to improve air quality',
#        'Write right! Helping CrossLead identify successful business objectives',
#        'Fake News Checker: To be fake or not to be?',
#        'DecoRater: Automatic assessment of image quality',
#        'Bubble Popper: Breaking out of the news filter bubble',
#        'Banking Class: Teaching a model to classify transactions',
#        'What Happened There? Matching Wikipedia traffic spikes with breaking news',
#        'BayesBall: Leveraging historical data to predict performance and cost',
#        'Money Talk$: Predicting campaign contributions using demographic data',
#        'Skills Essence: Upgrade job recommendations',
#        'ClientKeeper: Engagement and churn in B2B relationships',
#        'Traffic Booster: Identifying the most engaging content',
#        'BestBnB: Find an AirBnB to match your lifestyle and wallet',
#        'TrustMePost', 'MoneyMaid', 'Deeply Sentimental', 'DigiDeej',
#        'RoboCrop', 'faceRec', 'Polyglot', 'WalkEasy', 'RoomCrawl',
#        'The Invasion of California', 'OpenJustice', 'pigiback',
#        'Tinder for Grants', 'The Movie Model', 'Story Pitch Perfect',
#        'Blue Trinket', 'Opinionated', 'BlinkCatcher', 'FranklinFinder',
#        'Bambi Finder', 'fomoji', 'Troll-dar', 'Receipt.id',
#        'Peace-of-Mind Parking', 'Win the Bidding War', 'EduCare',
#        'Best Skills To Learn', 'The GUILD', 'D.textive', 'iHeard.IT',
#        'BetterScent', 'RecommendR', 'Gumby Grades', 'Travel Smart',
#        'MakeMyRun', 'Git Triage', 'CleanMachine',
#        'TraceAI, UC Berkeley, PhD', 'InstaBoost', 'LeadScore',
#        'Anticiplay', 'Joyless', 'Adaptive 3D Printer Control',
#        '!senseViolence', 'Is BART late today?', 'JoBreaker',
#        'Patent Evaluator', 'Happy Miso', 'BikeTimizer', 'OddsCheck',
#        'Hatched News', 'Wedding Insights with Joy', 'CrossWorth',
#        'Ped Motion', 'GiTaG', 'Opinion Detector', 'Churn at Gobble',
#        'Highlightr', 'Find Your Commmunity', 'Shoes popularity predictor',
#        'Code Coach: ML-powered programming practice',
#        'Petition Predictor: How many will sign?',
#        'TeacherReel: Analyzing classroom videos to find teachers who talk too much (or too little)',
#        'Wave Machine: Determining sea conditions for cargo ships',
#        'Wise Wheels: Where will Citibike take you?',
#        'predictTix: Helping theatergoers anticipate Broadway bargains',
#        'IntuiShop: Intuitive shopping for styles',
#        'BrandID: Detecting and identifying YouTube video sponsors',
#        'Switchyard: Predicting ridership changes to inform staffing needs',
#        'SnippetIQ: Automate promo text for social media',
#        'SmartBorrow: Refinance today or tomorrow?',
#        'Mind the Gap: Identifying factors that contribute to the gender pay gap',
#        'Author Check: Analyze documents for stylistic similarity',
#        'TrollTrackr: Combating Twitter trolls with NLP',
#        'Outreach BooSTIr.: Improving sex worker health outreach with machine learning',
#        'SignWrite: Transcribing sign language with the power of deep learning',
#        'AUTOMOTIVate: Predicting public favorability of self-driving related tweets',
#        'Crash Test Genius: Data-driven car safety ratings',
#        'YelpHelp: Catch critiques in Yelp reviews before they hurt your business.',
#        '3D Forecaster: Instant predictor for 3D printing time',
#        'Hot Hub Time Machine: Anticipating Hubway Supply and Demand for your Next Trip',
#        'Paper Scraper: Automating pdf table extraction',
#        'Wellness Tracker: Analyzing user behavior on customer engagement platform',
#        'Pay It Forward: Predicting Who Will Miss a Student Loan Payment',
#        'Personalized Skincare Powered by Data: Mining Consumer Reviews for Market Analysis',
#        'Review Foundry: A review summarizing dashboard for businesses',
#        'Review Foundry: Get in on the ground floor',
#        'Better Tweet: Expand your Twitterverse ',
#        'Save me from the sewers!: A real-time combined sewer overflow and pathogen warning system',
#        'BurstMyBubble: using machine learning and NLP to match people with new sources of news',
#        'Movie Mash: Find a movie that everyone will enjoy',
#        'Concrete on Concrete: Measuring urbanization with ML and satellite images',
#        'The key to a Joyful couple: Analyzing Customer Retention Through Clickstream Data',
#        'A topic model is worth 10^n words: Classifying NIMH grant applications using LDA',
#        'Will They Pay Up?: Predicting credit card consumer segments who will not pay off their balance',
#        'NoFOMO: Using tweets to recoup highlights of past events',
#        'EscapePodBot: A twitter bot that recommends stories from EscapePod',
#        'Forecast Delays: Be on time if the flight is late',
#        'GoLorry: Long distance truck service price estimation ',
#        'Sentiment Sentinel: Crowd-sourced trading tools for the Everyday Investor',
#        'Please don&#x27;t go!: Predicting customer churn',
#        'MLS Xcite: ranking just for kicks',
#        'betterVest: Predict successful start-up founders',
#        'AutoHighlights: Simplifying the art of social media sharing',
#        'Real-time and personalized scoring of customer engagement',
#        'InstaMarketing: Predicting consumer behavior from Instagram comments',
#        'Building and Improving Fraud and Default Risk Models',
#        'Reddit Cleaner: Learning 3 Comments at a Time',
#        'Songify: Find the right song for your video',
#        'Crash Catcher: DashCam Accident Detector',
#        'The Picc: Discover new flute music to learn',
#        'PriceMyMusic: Market insights for musicians',
#        'AB-testing: Building a tool to estimate optimal experiment run time',
#        'ImageImpact: Post the most popular images',
#        'GoSolar: Predicting return on investment for your solar panels',
#        'RecuriterHacker: Predicting candidate performance using machine learning ',
#        'NHL CheapSkates: Discover undervalued talent in the NHL',
#        'cHarmony: Classifying clothes and colors with a click',
#        'QueryGene: Question classifier for scalable chatbot of genetic test',
#        'Fortune Cookie: Predicting Amazonâ\x80\x99s future best-sellers',
#        'Who&#x27;s the boss: An algorithmic approach to inferring roles in the industry.',
#        'Safer Roads: Providing data-driven solutions for city planning and police deployment',
#        'Start-up Secrets: Enhance decision-making to improve portfolio yields',
#        'AutoPrice: What the vehicle will REALLY cost you',
#        'MatchTheVote: Matching advocacy group members with voters using machine learning',
#        'FareHarrier: Predicting NYC subway wait times so taxi drivers get more business ',
#        'SilverTongue: Helping you nail that next big presentation',
#        'enCard: Predicting credit card transaction failures',
#        'NBATicketSavant: Buy tickets without regret!',
#        'DishSTARS: The best dishes and where to get them',
#        'Panoptica: Gaining Insight into and Predicting Youtube Audience Demographics',
#        'EscapeDisaster: Travel to the right place at the right time',
#        'NexIQ: Improving flight search for busy travelers',
#        'Finding Who FLEX Fits: Refining target demographics for The FLEX Company',
#        'VerifyDocs: Keep it confidential',
#        'Babble: Language detection with half a second of sound',
#        'Startup Telescope: Future is now',
#        'RateMate: Bias estimator for online reviews',
#        'SmartAID: Poverty prediction from satellite images',
#        'Awesome Hockey: What to skip and what to watch in NHL videos',
#        'Evolutionary Biology &amp; Population Genetics, Stanford University, Postdoc\t',
#        'BeautyExtract: A data product to empower customized skincare recommendations',
#        'Rapid Chat Made Slow: Extracting content from the chaos of Twitch chat',
#        'TireCheck: Check your tire wear in seconds',
#        'SignatureFood: Make sure you enjoy your meal!',
#        'TexanTurnout: Predicting the Voter Turnout Rate in Texas Elections',
#        'Pic My Plant: Growing a garden rooted in deep learning',
#        'HitCoin!: Data mining Internet hype to find the next big cryptocurrency',
#        'Cairnfinder: An Alpinist&#x27;s Guide',
#        'DiversifyMe: Interactive visualization of correlation between exchange traded funds',
#        'LiFT: The Lifting Form Trainer', 'Q-tagger: Tag your questions',
#        'Gobble: Cookin&#x27; with data',
#        'InstaStudio: Instantly Find a Studio You&#x27;ll Love',
#        'LegalTech: Startup Consulting Project',
#        'EmailViz: Identifying employee relationships from digital communications',
#        'Find Your Art: Discover artwork around you using transfer learning',
#        'Churn-No-More: Discovering what drives customer churn vs. retention',
#        'Search Suggestor: Improving Stack Overflow search queries with natural language processing',
#        'MicrobeX: Exploring microbes across the globe',
#        'AdviceDice: Board game recommendations that leave nothing to chance',
#        'AirbnMe: Predicting Airbnb Occupancy Rates for Private Rooms in Chicago ',
#        'CallMeBackMaybe: Using natural language processing to classify call center phone conversations',
#        'SaReGaMood: Mood-based playlists for Indian classical music',
#        'Flightstitute: Risk management for flight disruption',
#        'Joke&#x27;s on you!: Identifying humor and inappropriate material in text',
#        'Mountain Bike Forecast: Predicting riding conditions using weather data ',
#        'Customer prioritization: Predicting a consumer&#x27;s propensity to buy'],
#       dtype=object)
